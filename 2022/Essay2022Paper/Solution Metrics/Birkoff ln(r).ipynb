# %% [markdown]
# # Longitudinal Wave Metric Search - Birkoff
# ## Metric is always Schwarschild - with varying mass at different radius
# So the mass inside R is what matters.
#
# frequency of wave is constant, wavelength increases linearly with time

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
import einsteinpy

from sympy import symbols, sin, cos, sinh, ln
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()
print(einsteinpy.__version__)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 0.4.0

# %% [markdown]
# # one off,
#
# Mass goes from M to M - deltaM once we cross a the wave. But changing the mass changes the coordinate system! So what to do.
#
# #### Make time tick regular, waves get longer as they go to bigger r, these are waves of gravitational field energy (the energy in the grav potential field), they need to get longer to support the fact that we need to hold a fraction F of the mean mass M in the wave.

# %%
syms = sympy.symbols("t r theta phi")
G, M, F, a, w = sympy.symbols("G M F a w")
#a = M*(1 - F*sin(w*(syms[0] - 1/(w*F)*ln(syms[1])))) + M*(1 - F*sin(w*(syms[0] + 1/(w*F)*ln(syms[1]))))
# use trig identities, standing waves result from in plus out
Y = 10.0 # Y is a whacky factor - will Y != 1 make the stress energy tensor blow up?
# Logarithimic 
#a = M*(1 - F*2*sin(w*syms[0])*cos(ln(syms[1])/(Y*F)))
a = M*(1 - F*sin(w*(syms[0] - 1/(w*F)*ln(syms[1]))))

#a = M*(1 - F*2*sin(w*syms[0]))



mT = sympy.diff(a, syms[0])
print(mT)
mR = sympy.diff(a, syms[1])
print(mR)


# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]

#take your pick
#list2d[0][0] = -mT*mT/(mR*mR)/(1 - 2*a/syms[1])
#list2d[0][0] = mT/mR/(1 - 2*a/syms[1])


list2d[0][0] = (1 - 2*a/syms[1])

list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - 2*a/syms[1]) 
list2d[2][2] = (syms[1])**2
list2d[3][3] = (syms[1])**2*(sympy.sin(syms[2]) ** 2)
sch = MetricTensor(list2d, syms)
sch.tensor()
# Out:
# -F*M*w*cos(w*(t - log(r)/(F*w)))
# M*cos(w*(t - log(r)/(F*w)))/r
# ⎡      ⎛       ⎛  ⎛    log(r)⎞⎞    ⎞
# ⎢  2⋅M⋅⎜- F⋅sin⎜w⋅⎜t - ──────⎟⎟ + 1⎟
# ⎢      ⎝       ⎝  ⎝     F⋅w  ⎠⎠    ⎠
# ⎢- ───────────────────────────────── + 1                     0
# ⎢                  r
# ⎢
# ⎢                                                            1
# ⎢                   0                     ────────────────────────────────────
# ⎢                                               ⎛       ⎛  ⎛    log(r)⎞⎞    ⎞
# ⎢                                           2⋅M⋅⎜- F⋅sin⎜w⋅⎜t - ──────⎟⎟ + 1⎟
# ⎢                                               ⎝       ⎝  ⎝     F⋅w  ⎠⎠    ⎠
# ⎢                                         - ─────────────────────────────────
# ⎢                                                           r
# ⎢
# ⎢
# ⎢                   0                                        0
# ⎢
# ⎢
# ⎣                   0                                        0
#
#                    ⎤
#                    ⎥
#                    ⎥
#      0       0     ⎥
#                    ⎥
#                    ⎥
#                    ⎥
# ───  0       0     ⎥
#                    ⎥
#                    ⎥
#                    ⎥
# + 1                ⎥
#                    ⎥
#                    ⎥
#       2            ⎥
#      r       0     ⎥
#                    ⎥
#           2    2   ⎥
#      0   r ⋅sin (θ)⎦

# %% [markdown]
# #### Figure above: The velocity is with c == 1, so superluminal happens quite fast. x axis is thus in Schwarshild radii
#
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
#einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡    ⎛    ⎛       ⎛  ⎛    log(r)⎞⎞    ⎞      ⎞
# ⎢    ⎜  M⋅⎜- F⋅sin⎜w⋅⎜t - ──────⎟⎟ + 1⎟      ⎟ ⎛
# ⎢    ⎜    ⎝       ⎝  ⎝     F⋅w  ⎠⎠    ⎠      ⎟ ⎜ 2  4  2 ⎛    ⎛     ⎛      log
# ⎢  M⋅⎜- ─────────────────────────────── + 0.5⎟⋅⎜F ⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ───
# ⎢    ⎝                 r                     ⎠ ⎝         ⎝    ⎝     ⎝        F
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#               4
# (r)⎞    ⎞    ⎞  ⎛           2⎛      log(r)⎞            2⎛      log(r)⎞
# ───⎟ - 1⎟ + r⎟ ⋅⎜- 2⋅F⋅M⋅sin ⎜t⋅w - ──────⎟ - 4⋅F⋅M⋅cos ⎜t⋅w - ──────⎟ + 2⋅M⋅s
#    ⎠    ⎠    ⎠  ⎝            ⎝        F   ⎠             ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ⎛      log(r)⎞        ⎛      log(r)⎞⎞       ⎛         ⎛      log(r)⎞
# in⎜t⋅w - ──────⎟ - r⋅sin⎜t⋅w - ──────⎟⎟ + 3⋅F⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M +
#   ⎝        F   ⎠        ⎝        F   ⎠⎠       ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    7                                                        7
#   ⎞     ⎛      log(r)⎞   ⎛         ⎛      log(r)⎞          ⎞     ⎛      log(r)
#  r⎟ ⋅cos⎜t⋅w - ──────⎟ + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅sin⎜t⋅w - ──────
#   ⎠     ⎝        F   ⎠   ⎝         ⎝        F   ⎠          ⎠     ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                        2 ⎛
# ⎞   ⎛         ⎛      log(r)⎞          ⎞  ⎜ 3    4  2 ⎛    ⎛     ⎛      log(r)⎞
# ⎟ - ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅⎜F ⋅M⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟
# ⎠   ⎝         ⎝        F   ⎠          ⎠  ⎝           ⎝    ⎝     ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           2
#     ⎞    ⎞     2⎛      log(r)⎞      3    4  2 ⎛         ⎛      log(r)⎞
#  - 1⎟ + r⎟ ⋅cos ⎜t⋅w - ──────⎟ + 3⋅F ⋅M⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M +
#     ⎠    ⎠      ⎝        F   ⎠                ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                         3 ⎛
#                                                                      F⋅r ⋅⎜2⋅M
#                                                                           ⎝
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    2                                                                  3
#   ⎞     2⎛      log(r)⎞    2  4  2 ⎛         ⎛      log(r)⎞          ⎞     ⎛
#  r⎟ ⋅cos ⎜t⋅w - ──────⎟ + F ⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅sin⎜t⋅
#   ⎠      ⎝        F   ⎠            ⎝         ⎝        F   ⎠          ⎠     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                4                                    3
#  ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛         ⎛      log(r)⎞          ⎞
# ⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#  ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝         ⎝        F   ⎠          ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                2
#     log(r)⎞       ⎛     ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞  ⎛         ⎛
# w - ──────⎟ + F⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅
#       F   ⎠       ⎝     ⎝        F   ⎠      ⎝        F   ⎠    ⎠  ⎝         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                       4                                        4
#     log(r)⎞          ⎞      ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛     ⎛
# w - ──────⎟ - 2⋅M + r⎟  + F⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜F⋅sin⎜t⋅w -
#       F   ⎠          ⎠      ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                              ⎛
#                                                                  -2⋅F⋅M⋅w⋅cos⎜
#                                                                              ⎝
#                                                             ──────────────────
#                                                               ⎛         ⎛
#                                                             r⋅⎜2⋅F⋅M⋅sin⎜t⋅w -
#                                                               ⎝         ⎝
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# log(r)⎞      ⎛      log(r)⎞    ⎞ ⎛       ⎛      log(r)⎞        ⎛      log(r)⎞
# ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜F⋅M⋅sin⎜t⋅w - ──────⎟ - M⋅cos⎜t⋅w - ──────⎟
#   F   ⎠      ⎝        F   ⎠    ⎠ ⎝       ⎝        F   ⎠        ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#       log(r)⎞
# t⋅w - ──────⎟
#         F   ⎠
# ───────────────────
#  log(r)⎞          ⎞
#  ──────⎟ - 2⋅M + r⎟
#    F   ⎠          ⎠
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#
#
# 0
#
#
#
#
#
#
#
#        ⎞       ⎛     ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞ ⎛         ⎛
# - M + r⎟ - 3⋅F⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜2⋅F⋅M⋅sin⎜t⋅w -
#        ⎠       ⎝     ⎝        F   ⎠      ⎝        F   ⎠    ⎠ ⎝         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   5                                      5
# log(r)⎞          ⎞    ⎛         ⎛      log(r)⎞          ⎞  ⎛   2    ⎛      log
# ──────⎟ - 2⋅M + r⎟  + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ───
#   F   ⎠          ⎠    ⎝         ⎝        F   ⎠          ⎠  ⎝        ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                        ⎞⎞     ⎛
# (r)⎞          ⎛      log(r)⎞            ⎛      log(r)⎞⎞⎟⎟     ⎜     3    4  2
# ───⎟ + 3⋅F⋅cos⎜t⋅w - ──────⎟ - 2⋅F - sin⎜t⋅w - ──────⎟⎟⎟⎟   M⋅⎜- 5⋅F ⋅M⋅r ⋅w ⋅
#    ⎠          ⎝        F   ⎠            ⎝        F   ⎠⎠⎠⎠     ⎝
# ───────────────────────────────────────────────────────── + ──────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                    2
# ⎛         ⎛      log(r)⎞          ⎞     2⎛      log(r)⎞    2  4  2 ⎛    ⎛
# ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅cos ⎜t⋅w - ──────⎟ - F ⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin
# ⎝         ⎝        F   ⎠          ⎠      ⎝        F   ⎠            ⎝    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         2
# ⎛      log(r)⎞    ⎞    ⎞  ⎛         2⎛      log(r)⎞   ⎛         ⎛      log(r)⎞
# ⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜- F⋅M⋅cos ⎜t⋅w - ──────⎟ + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟
# ⎝        F   ⎠    ⎠    ⎠  ⎝          ⎝        F   ⎠   ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# ──────────────────────────────────────────────────────────────────────────────
#          3
#         ⎞
#  2⋅M + r⎟
#         ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    4                                        4
#  log(r)⎞          ⎞      ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛     ⎛      log
#  ──────⎟ - 2⋅M + r⎟  + F⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜F⋅sin⎜t⋅w - ───
#    F   ⎠          ⎠      ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝     ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (r)⎞      ⎛      log(r)⎞    ⎞ ⎛       ⎛      log(r)⎞        ⎛      log(r)⎞
# ───⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜F⋅M⋅sin⎜t⋅w - ──────⎟ - M⋅cos⎜t⋅w - ──────⎟ - M
#    ⎠      ⎝        F   ⎠    ⎠ ⎝       ⎝        F   ⎠        ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     ⎞       ⎛     ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞ ⎛         ⎛      log
#  + r⎟ - 3⋅F⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ───
#     ⎠       ⎝     ⎝        F   ⎠      ⎝        F   ⎠    ⎠ ⎝         ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                5                                      5
# (r)⎞          ⎞    ⎛         ⎛      log(r)⎞          ⎞  ⎛   2    ⎛      log(r)
# ───⎟ - 2⋅M + r⎟  + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ──────
#    ⎠          ⎠    ⎝         ⎝        F   ⎠          ⎠  ⎝        ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                               ⎤
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                     ⎞⎞        ⎥
# ⎞          ⎛      log(r)⎞            ⎛      log(r)⎞⎞⎟⎟    2   ⎥
# ⎟ + 3⋅F⋅cos⎜t⋅w - ──────⎟ - 2⋅F - sin⎜t⋅w - ──────⎟⎟⎟⎟⋅sin (θ)⎥
# ⎠          ⎝        F   ⎠            ⎝        F   ⎠⎠⎠⎠        ⎥
# ──────────────────────────────────────────────────────────────⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎥
#                                                               ⎦

# %%
ri = RicciTensor.from_metric(sch)
#ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡  ⎛                                                  2
# ⎢  ⎜     3    4  2 ⎛         ⎛      log(r)⎞          ⎞     2⎛      log(r)⎞
# ⎢M⋅⎜- 5⋅F ⋅M⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅cos ⎜t⋅w - ──────⎟ - F
# ⎢  ⎝               ⎝         ⎝        F   ⎠          ⎠      ⎝        F   ⎠
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                                            2
# 2  4  2 ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛         2⎛      log(r)⎞   ⎛
#  ⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜- F⋅M⋅cos ⎜t⋅w - ──────⎟ + ⎜2⋅F⋅
#         ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝          ⎝        F   ⎠   ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ⎛      log(r)⎞          ⎞    ⎛      log(r)⎞⎞       ⎛     ⎛      log(r)⎞
# M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟⋅sin⎜t⋅w - ──────⎟⎟ + 2⋅F⋅⎜F⋅sin⎜t⋅w - ──────⎟ +
#      ⎝        F   ⎠          ⎠    ⎝        F   ⎠⎠       ⎝     ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     4
#                                4 ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞
#                             F⋅r ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟
#                                  ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠
#
#
#                                                ⎛      log(r)⎞
#                                    -2⋅F⋅M⋅w⋅cos⎜t⋅w - ──────⎟
#                                                ⎝        F   ⎠
#                               ─────────────────────────────────────
#                                 ⎛         ⎛      log(r)⎞          ⎞
#                               r⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#                                 ⎝         ⎝        F   ⎠          ⎠
#
#
#
#
#
#                                                 0
#
#
#
#
#
#                                                 0
#
#
#                                                            5
#     ⎛      log(r)⎞    ⎞ ⎛         ⎛      log(r)⎞          ⎞    ⎛         ⎛
#  cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟  - ⎜2⋅F⋅M⋅sin⎜t⋅w
#     ⎝        F   ⎠    ⎠ ⎝         ⎝        F   ⎠          ⎠    ⎝         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                     5
#   log(r)⎞          ⎞  ⎛   2    ⎛      log(r)⎞          ⎛      log(r)⎞
# - ──────⎟ - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ──────⎟ + 3⋅F⋅cos⎜t⋅w - ──────⎟ - 2⋅F -
#     F   ⎠          ⎠  ⎝        ⎝        F   ⎠          ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   ⎞
#    ⎛      log(r)⎞⎞⎟
# sin⎜t⋅w - ──────⎟⎟⎟
#    ⎝        F   ⎠⎠⎠
# ───────────────────
#
#
#
#
#
#                        ⎛                                                2
#                        ⎜   3    4  2 ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞     2
#                      M⋅⎜- F ⋅M⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅cos
#                        ⎝             ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠
#                      ─────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                  2
# ⎛      log(r)⎞      3    4  2 ⎛         ⎛      log(r)⎞          ⎞     2⎛
# ⎜t⋅w - ──────⎟ - 3⋅F ⋅M⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅cos ⎜t⋅w -
# ⎝        F   ⎠                ⎝         ⎝        F   ⎠          ⎠      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       3
# log(r)⎞    2  4  2 ⎛         ⎛      log(r)⎞          ⎞     ⎛      log(r)⎞
# ──────⎟ - F ⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅sin⎜t⋅w - ──────⎟ - F⋅
#   F   ⎠            ⎝         ⎝        F   ⎠          ⎠     ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                2
#   ⎛     ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞  ⎛         ⎛      log(r)⎞
# M⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅
#   ⎝     ⎝        F   ⎠      ⎝        F   ⎠    ⎠  ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                          2 ⎛
#                                                                       F⋅r ⋅⎜2⋅
#                                                                            ⎝
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                              ⎛      log(r)⎞
#                  -2⋅F⋅M⋅w⋅cos⎜t⋅w - ──────⎟
#                              ⎝        F   ⎠
#             ─────────────────────────────────────
#               ⎛         ⎛      log(r)⎞          ⎞
#             r⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#               ⎝         ⎝        F   ⎠          ⎠
#
#
#       4                                        4
#      ⎞      ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛     ⎛      log(r)⎞      ⎛
# M + r⎟  - F⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅
#      ⎠      ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝     ⎝        F   ⎠      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                 4                                    2
#   ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛         ⎛      log(r)⎞          ⎞
# M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#   ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝         ⎝        F   ⎠          ⎠
#
#
#
#
#                               0
#
#
#
#
#
#                               0
#
#
#
#
#
#
#
#
#
#
#
#
#
#     log(r)⎞    ⎞ ⎛       ⎛      log(r)⎞        ⎛      log(r)⎞        ⎞       ⎛
# w - ──────⎟ - 1⎟⋅⎜F⋅M⋅sin⎜t⋅w - ──────⎟ - M⋅cos⎜t⋅w - ──────⎟ - M + r⎟ + 3⋅F⋅⎜
#       F   ⎠    ⎠ ⎝       ⎝        F   ⎠        ⎝        F   ⎠        ⎠       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞ ⎛         ⎛      log(r)⎞
# F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M +
#      ⎝        F   ⎠      ⎝        F   ⎠    ⎠ ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   5                                      5
#  ⎞    ⎛         ⎛      log(r)⎞          ⎞  ⎛   2    ⎛      log(r)⎞          ⎛
# r⎟  - ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ──────⎟ + 3⋅F⋅cos⎜t
#  ⎠    ⎝         ⎝        F   ⎠          ⎠  ⎝        ⎝        F   ⎠          ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                     0
#
#
#
#
#
#                                        ⎞
#      log(r)⎞            ⎛      log(r)⎞⎞⎟
# ⋅w - ──────⎟ - 2⋅F - sin⎜t⋅w - ──────⎟⎟⎟
#        F   ⎠            ⎝        F   ⎠⎠⎠
# ────────────────────────────────────────            0
#
#
#
#
#
#                                                  ⎛      log(r)⎞
#                                           2⋅M⋅cos⎜t⋅w - ──────⎟
#                                                  ⎝        F   ⎠
#                                           ─────────────────────
#                                                     r
#
#                                                                         2
#                                                                  2⋅M⋅sin (θ)⋅c
#
#                                                     0            ─────────────
#
#
#                 ⎤
#                 ⎥
#                 ⎥
#                 ⎥
#  0              ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#  0              ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#                 ⎥
#  0              ⎥
#                 ⎥
#                 ⎥
#   ⎛      log(r)⎞⎥
# os⎜t⋅w - ──────⎟⎥
#   ⎝        F   ⎠⎥
# ────────────────⎥
#  r              ⎦

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = einst.tensor_lambdify()
print(args) # these are the argument values 

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5
t = 1


#Make x values - which we will sub in for r 
x = np.arange(3.0, 20.0, 0.004)

# Call the functions
# note: what scale to use on these ? when is it appropriate to divide by r**2, etc? 
tt = func(t,x,theta, phi, F, M, w)[0][0]

tr = func(t,x,theta, phi, F, M, w)[0][1]/(x*x)

rr = func(t,x,theta, phi, F, M, w)[1][1]/(x*x)**2

hh = func(t,x,theta, phi, F, M, w)[2][2]/(x*x)**2

pp = func(t,x,theta, phi, F, M, w)[3][3]/(x*x*sin(theta)*sin(theta))**2


fig=plt.figure(figsize=(10, 5))
ax=fig.add_axes([0,2,1.0,1.0])

ax.plot(x,hh, "lightgrey",label="θθ", linewidth=6.0)
ax.plot(x,pp, "black",label="φφ", linewidth=0.5)

#ax.plot(x,tt, "-b", label="tt")
ax.plot(x,rr, "-g", label="rr")
ax.plot(x,tr, "-r", label="tr")

ax.legend(loc="upper right")
ax.set_title("Einstein Tensor, G")
# Out:
# (t, r, theta, phi, F, M, w)
# Text(0.5, 1.0, 'Einstein Tensor, G')

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#    ⎛                                            4
#    ⎜ 2  4  2 ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞  ⎛         2⎛      log(r)⎞
# -M⋅⎜F ⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅⎜2⋅F⋅M⋅sin ⎜t⋅w - ──────⎟ +
#    ⎝         ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠  ⎝          ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#          2⎛      log(r)⎞          ⎛      log(r)⎞        ⎛      log(r)⎞⎞
# 4⋅F⋅M⋅cos ⎜t⋅w - ──────⎟ - 2⋅M⋅sin⎜t⋅w - ──────⎟ + r⋅sin⎜t⋅w - ──────⎟⎟ - 3⋅F⋅
#           ⎝        F   ⎠          ⎝        F   ⎠        ⎝        F   ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                    7
# ⎛         ⎛      log(r)⎞          ⎞     ⎛      log(r)⎞   ⎛         ⎛      log(
# ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅cos⎜t⋅w - ──────⎟ - ⎜2⋅F⋅M⋅sin⎜t⋅w - ────
# ⎝         ⎝        F   ⎠          ⎠     ⎝        F   ⎠   ⎝         ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#               7                                                        2 ⎛
# r)⎞          ⎞     ⎛      log(r)⎞   ⎛         ⎛      log(r)⎞          ⎞  ⎜ 3
# ──⎟ - 2⋅M + r⎟ ⋅sin⎜t⋅w - ──────⎟ + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅⎜F ⋅M
#   ⎠          ⎠     ⎝        F   ⎠   ⎝         ⎝        F   ⎠          ⎠  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                           2
#   4  2 ⎛    ⎛     ⎛      log(r)⎞    ⎞    ⎞     2⎛      log(r)⎞      3    4  2
# ⋅r ⋅w ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ - 1⎟ + r⎟ ⋅cos ⎜t⋅w - ──────⎟ + 3⋅F ⋅M⋅r ⋅w ⋅
#        ⎝    ⎝     ⎝        F   ⎠    ⎠    ⎠      ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                    2
# ⎛         ⎛      log(r)⎞          ⎞     2⎛      log(r)⎞    2  4  2 ⎛         ⎛
# ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅cos ⎜t⋅w - ──────⎟ + F ⋅r ⋅w ⋅⎜2⋅F⋅M⋅sin⎜
# ⎝         ⎝        F   ⎠          ⎠      ⎝        F   ⎠            ⎝         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                 3 ⎛    ⎛     ⎛      log(r)⎞
#                                              F⋅r ⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ -
#                                                   ⎝    ⎝     ⎝        F   ⎠
#
#                         3
#       log(r)⎞          ⎞     ⎛      log(r)⎞       ⎛     ⎛      log(r)⎞      ⎛
# t⋅w - ──────⎟ - 2⋅M + r⎟ ⋅sin⎜t⋅w - ──────⎟ + F⋅M⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t
#         F   ⎠          ⎠     ⎝        F   ⎠       ⎝     ⎝        F   ⎠      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#        4                                    3
#  ⎞    ⎞  ⎛         ⎛      log(r)⎞          ⎞
# 1⎟ + r⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#  ⎠    ⎠  ⎝         ⎝        F   ⎠          ⎠
#
#                  2                                    4
#      log(r)⎞    ⎞  ⎛         ⎛      log(r)⎞          ⎞      ⎛    ⎛     ⎛
# ⋅w - ──────⎟ - 1⎟ ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟  + F⋅⎜2⋅M⋅⎜F⋅sin⎜t⋅w -
#        F   ⎠    ⎠  ⎝         ⎝        F   ⎠          ⎠      ⎝    ⎝     ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                  4
# log(r)⎞    ⎞    ⎞  ⎛     ⎛      log(r)⎞      ⎛      log(r)⎞    ⎞ ⎛       ⎛
# ──────⎟ - 1⎟ + r⎟ ⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w - ──────⎟ - 1⎟⋅⎜F⋅M⋅sin⎜t⋅w
#   F   ⎠    ⎠    ⎠  ⎝     ⎝        F   ⎠      ⎝        F   ⎠    ⎠ ⎝       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#   log(r)⎞        ⎛      log(r)⎞        ⎞       ⎛     ⎛      log(r)⎞      ⎛
# - ──────⎟ - M⋅cos⎜t⋅w - ──────⎟ - M + r⎟ - 3⋅F⋅⎜F⋅sin⎜t⋅w - ──────⎟ + cos⎜t⋅w
#     F   ⎠        ⎝        F   ⎠        ⎠       ⎝     ⎝        F   ⎠      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                   5
#   log(r)⎞    ⎞ ⎛         ⎛      log(r)⎞          ⎞    ⎛         ⎛      log(r)⎞
# - ──────⎟ - 1⎟⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟  + ⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟
#     F   ⎠    ⎠ ⎝         ⎝        F   ⎠          ⎠    ⎝         ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#            5
#           ⎞  ⎛   2    ⎛      log(r)⎞          ⎛      log(r)⎞            ⎛
#  - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ──────⎟ + 3⋅F⋅cos⎜t⋅w - ──────⎟ - 2⋅F - sin⎜t⋅w -
#           ⎠  ⎝        ⎝        F   ⎠          ⎝        F   ⎠            ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#          ⎞⎞
#  log(r)⎞⎞⎟⎟
#  ──────⎟⎟⎟⎟
#    F   ⎠⎠⎠⎠
# ────────────

# %%
#plot the Ricci scalar

args, funcR = R.tensor_lambdify()
print(args) # these are the argument values 

t = 5

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5

#Make x values - which we will sub in for r 
x = np.arange(10.0, 100.0, 0.04)

# Call the functions
ricci = funcR(t,x,theta, phi, F, M, w)

fig=plt.figure(figsize=(8, 4))
ax=fig.add_axes([0,2,1.0,1.0])
ax.set_title("Ricci scalar")
ax.legend(loc="lower right")
ax.plot(x,ricci, label="Ricci scalar")
# Out:
# No handles with labels found to put in legend.
# (t, r, theta, phi, F, M, w)

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢        ⎡
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢  ⎛      5  3    4⎛      log(r)⎞       4  3    3⎛      log(r)⎞    ⎛
# ⎢        ⎢M⋅⎜- 48⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 40⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t
# ⎢        ⎢  ⎝               ⎝        F   ⎠                ⎝        F   ⎠    ⎝
# ⎢        ⎢────────────────────────────────────────────────────────────────────
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎣
# ⎢
# ⎢
# ⎢        ⎡
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢  ⎛    5  3    4⎛      log(r)⎞       4  3    3⎛      log(r)⎞    ⎛
# ⎢        ⎢M⋅⎜48⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 40⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w
# ⎢        ⎢  ⎝             ⎝        F   ⎠                ⎝        F   ⎠    ⎝
# ⎢        ⎢────────────────────────────────────────────────────────────────────
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎢
# ⎢        ⎣
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢  ⎛    5  3    4⎛      log(r)⎞       4  3    3⎛      log(r)⎞    ⎛      log(r
# ⎢⎢M⋅⎜48⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 40⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ─────
# ⎢⎢  ⎝             ⎝        F   ⎠                ⎝        F   ⎠    ⎝        F
# ⎢⎢────────────────────────────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎣
# ⎣
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      log(r)⎞        4  3    3⎛      log(r)⎞       4  2      3⎛      log(r)⎞
# ⋅w - ──────⎟ + 192⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 72⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ +
#        F   ⎠                 ⎝        F   ⎠                  ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    log(r)⎞        4  3    3⎛      log(r)⎞       4  2      3⎛      log(r)⎞
#  - ──────⎟ - 192⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 72⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 8⋅
#      F   ⎠                 ⎝        F   ⎠                  ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# )⎞        4  3    3⎛      log(r)⎞       4  2      3⎛      log(r)⎞      3  3
# ─⎟ - 192⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 72⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 8⋅F ⋅M ⋅si
#  ⎠                 ⎝        F   ⎠                  ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    3  3    4⎛      log(r)⎞        3  3    2⎛      log(r)⎞    ⎛      log(r)⎞
# 8⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 120⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ -
#             ⎝        F   ⎠                 ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  3  3    4⎛      log(r)⎞        3  3    2⎛      log(r)⎞    ⎛      log(r)⎞
# F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 120⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ + 28
#           ⎝        F   ⎠                 ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  4⎛      log(r)⎞        3  3    2⎛      log(r)⎞    ⎛      log(r)⎞        3  3
# n ⎜t⋅w - ──────⎟ - 120⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ + 288⋅F ⋅M ⋅
#   ⎝        F   ⎠                 ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      3  3    2⎛      log(r)⎞       3  2      2⎛      log(r)⎞    ⎛      log(r)⎞
# 288⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 60⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟
#               ⎝        F   ⎠                  ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    3  3    2⎛      log(r)⎞       3  2      2⎛      log(r)⎞    ⎛      log(r)⎞
# 8⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ -
#             ⎝        F   ⎠                  ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    2⎛      log(r)⎞       3  2      2⎛      log(r)⎞    ⎛      log(r)⎞        3
# sin ⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ - 216⋅F ⋅
#     ⎝        F   ⎠                  ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         3  2      2⎛      log(r)⎞      3    4  2    2⎛      log(r)⎞      3
#  + 216⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 2⋅F ⋅M⋅r ⋅w ⋅sin ⎜t⋅w - ──────⎟ - 4⋅F ⋅M⋅r
#                    ⎝        F   ⎠                    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       3  2      2⎛      log(r)⎞      3    4  2    2⎛      log(r)⎞      3    4
#  216⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ + 2⋅F ⋅M⋅r ⋅w ⋅sin ⎜t⋅w - ──────⎟ + 4⋅F ⋅M⋅r ⋅
#                  ⎝        F   ⎠                    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2      2⎛      log(r)⎞      3    4  2    2⎛      log(r)⎞      3    4  2    2⎛
# M ⋅r⋅sin ⎜t⋅w - ──────⎟ + 2⋅F ⋅M⋅r ⋅w ⋅sin ⎜t⋅w - ──────⎟ + 4⋅F ⋅M⋅r ⋅w ⋅cos ⎜
#          ⎝        F   ⎠                    ⎝        F   ⎠                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4  2    2⎛      log(r)⎞       3    2    2⎛      log(r)⎞       2  3    3⎛
#  ⋅w ⋅cos ⎜t⋅w - ──────⎟ - 36⋅F ⋅M⋅r ⋅sin ⎜t⋅w - ──────⎟ - 24⋅F ⋅M ⋅sin ⎜t⋅w -
#          ⎝        F   ⎠                  ⎝        F   ⎠                ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2    2⎛      log(r)⎞       3    2    2⎛      log(r)⎞       2  3    3⎛      lo
# w ⋅cos ⎜t⋅w - ──────⎟ + 36⋅F ⋅M⋅r ⋅sin ⎜t⋅w - ──────⎟ + 24⋅F ⋅M ⋅sin ⎜t⋅w - ──
#        ⎝        F   ⎠                  ⎝        F   ⎠                ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#       log(r)⎞       3    2    2⎛      log(r)⎞       2  3    3⎛      log(r)⎞
# t⋅w - ──────⎟ + 36⋅F ⋅M⋅r ⋅sin ⎜t⋅w - ──────⎟ + 24⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ -
#         F   ⎠                  ⎝        F   ⎠                ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# log(r)⎞        2  3    ⎛      log(r)⎞       2  3    ⎛        2⋅log(r)⎞       2
# ──────⎟ + 192⋅F ⋅M ⋅sin⎜t⋅w - ──────⎟ - 60⋅F ⋅M ⋅sin⎜2⋅t⋅w - ────────⎟ + 12⋅F
#   F   ⎠                ⎝        F   ⎠               ⎝           F    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# g(r)⎞        2  3    ⎛      log(r)⎞       2  3    ⎛        2⋅log(r)⎞       2
# ────⎟ - 192⋅F ⋅M ⋅sin⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅sin⎜2⋅t⋅w - ────────⎟ - 12⋅F ⋅M
# F   ⎠                ⎝        F   ⎠               ⎝           F    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 5
# g(r)⎞          ⎞  ⎛   2    ⎛      log(r)⎞          ⎛      log(r)⎞            ⎛
# ────⎟ - 2⋅M + r⎟ ⋅⎜2⋅F ⋅sin⎜t⋅w - ──────⎟ + 3⋅F⋅cos⎜t⋅w - ──────⎟ - 2⋅F - sin⎜
# F   ⎠          ⎠  ⎝        ⎝        F   ⎠          ⎝        F   ⎠            ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      3      3    ⎛      log(r)⎞       2      ⎛      log(r)⎞        2    ⎛
# 6⋅F⋅r  + 8⋅M ⋅sin⎜t⋅w - ──────⎟ - 12⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ + 6⋅M⋅r ⋅sin⎜t⋅w -
#                  ⎝        F   ⎠              ⎝        F   ⎠             ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      3      3    ⎛      log(r)⎞       2      ⎛      log(r)⎞        2    ⎛
# 6⋅F⋅r  + 8⋅M ⋅sin⎜t⋅w - ──────⎟ - 12⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ + 6⋅M⋅r ⋅sin⎜t⋅w -
#                  ⎝        F   ⎠              ⎝        F   ⎠             ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         ⎤
#                         ⎥
#                         ⎥
#                         ⎥
#               ⎞⎞        ⎥
#       log(r)⎞⎞⎟⎟    2   ⎥
# t⋅w - ──────⎟⎟⎟⎟⋅sin (θ)⎥
#         F   ⎠⎠⎠⎠        ⎥
# ────────────────────────⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎥
#                         ⎦
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  log(r)⎞    3    ⎛      log(r)⎞⎞    2   ⎤⎤
#  ──────⎟ - r ⋅sin⎜t⋅w - ──────⎟⎟⋅sin (θ)⎥⎥
#    F   ⎠         ⎝        F   ⎠⎠        ⎥⎥
# ────────────────────────────────────────⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎦⎥
#                                          ⎥
#                                         ⎤⎥
#                                         ⎥⎥
#  log(r)⎞    3    ⎛      log(r)⎞⎞    2   ⎥⎥
#  ──────⎟ - r ⋅sin⎜t⋅w - ──────⎟⎟⋅sin (θ)⎥⎥
#    F   ⎠         ⎝        F   ⎠⎠        ⎥⎥
# ────────────────────────────────────────⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎥⎥
#                                         ⎦⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎥
#                                          ⎦

# %%
weyl[0,1,0,1]
# Out:
#   ⎛      5  3    4⎛      log(r)⎞       4  3    3⎛      log(r)⎞    ⎛      log(r
# M⋅⎜- 48⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 40⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ─────
#   ⎝               ⎝        F   ⎠                ⎝        F   ⎠    ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# )⎞        4  3    3⎛      log(r)⎞       4  2      3⎛      log(r)⎞      3  3
# ─⎟ + 192⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 72⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ + 8⋅F ⋅M ⋅si
#  ⎠                 ⎝        F   ⎠                  ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  4⎛      log(r)⎞        3  3    2⎛      log(r)⎞    ⎛      log(r)⎞        3  3
# n ⎜t⋅w - ──────⎟ + 120⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ - 288⋅F ⋅M ⋅
#   ⎝        F   ⎠                 ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2⎛      log(r)⎞       3  2      2⎛      log(r)⎞    ⎛      log(r)⎞        3
# sin ⎜t⋅w - ──────⎟ - 60⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ + 216⋅F ⋅
#     ⎝        F   ⎠                  ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2      2⎛      log(r)⎞      3    4  2    2⎛      log(r)⎞      3    4  2    2⎛
# M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 2⋅F ⋅M⋅r ⋅w ⋅sin ⎜t⋅w - ──────⎟ - 4⋅F ⋅M⋅r ⋅w ⋅cos ⎜
#          ⎝        F   ⎠                    ⎝        F   ⎠                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       log(r)⎞       3    2    2⎛      log(r)⎞       2  3    3⎛      log(r)⎞
# t⋅w - ──────⎟ - 36⋅F ⋅M⋅r ⋅sin ⎜t⋅w - ──────⎟ - 24⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ +
#         F   ⎠                  ⎝        F   ⎠                ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#      2  3    ⎛      log(r)⎞       2  3    ⎛        2⋅log(r)⎞       2  2      3
# 192⋅F ⋅M ⋅sin⎜t⋅w - ──────⎟ - 60⋅F ⋅M ⋅sin⎜2⋅t⋅w - ────────⎟ + 12⋅F ⋅M ⋅r⋅sin
#              ⎝        F   ⎠               ⎝           F    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛      log(r)⎞        2  2      ⎛      log(r)⎞       2  2      ⎛        2⋅log(
# ⎜t⋅w - ──────⎟ - 216⋅F ⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅r⋅sin⎜2⋅t⋅w - ──────
# ⎝        F   ⎠                  ⎝        F   ⎠                 ⎝           F
# ──────────────────────────────────────────────────────────────────────────────
#                                           3
#      3 ⎛         ⎛      log(r)⎞          ⎞
# 3⋅F⋅r ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#        ⎝         ⎝        F   ⎠          ⎠
#
# r)⎞      2    4  2    ⎛      log(r)⎞       2    2    ⎛      log(r)⎞       2
# ──⎟ + 2⋅F ⋅M⋅r ⋅w ⋅sin⎜t⋅w - ──────⎟ + 72⋅F ⋅M⋅r ⋅sin⎜t⋅w - ──────⎟ - 15⋅F ⋅M⋅
#   ⎠                   ⎝        F   ⎠                 ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2    ⎛        2⋅log(r)⎞    2  5  2    ⎛      log(r)⎞      2  3    ⎛      log(
# r ⋅sin⎜2⋅t⋅w - ────────⎟ - F ⋅r ⋅w ⋅sin⎜t⋅w - ──────⎟ - 6⋅F ⋅r ⋅sin⎜t⋅w - ────
#       ⎝           F    ⎠               ⎝        F   ⎠              ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# r)⎞         3    2⎛      log(r)⎞         3    ⎛      log(r)⎞         3
# ──⎟ + 24⋅F⋅M ⋅sin ⎜t⋅w - ──────⎟ + 40⋅F⋅M ⋅cos⎜t⋅w - ──────⎟ - 48⋅F⋅M  - 24⋅F⋅
#   ⎠               ⎝        F   ⎠              ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2      2⎛      log(r)⎞         2      ⎛      log(r)⎞         2            2
# M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 60⋅F⋅M ⋅r⋅cos⎜t⋅w - ──────⎟ + 72⋅F⋅M ⋅r + 6⋅F⋅M⋅r ⋅s
#          ⎝        F   ⎠                ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   2⎛      log(r)⎞           2    ⎛      log(r)⎞           2        3    ⎛
# in ⎜t⋅w - ──────⎟ + 30⋅F⋅M⋅r ⋅cos⎜t⋅w - ──────⎟ - 36⋅F⋅M⋅r  - 5⋅F⋅r ⋅cos⎜t⋅w -
#    ⎝        F   ⎠                ⎝        F   ⎠                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  log(r)⎞        3      3    ⎛      log(r)⎞       2      ⎛      log(r)⎞
#  ──────⎟ + 6⋅F⋅r  - 8⋅M ⋅sin⎜t⋅w - ──────⎟ + 12⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ - 6⋅M⋅r
#    F   ⎠                    ⎝        F   ⎠              ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2    ⎛      log(r)⎞    3    ⎛      log(r)⎞⎞
#  ⋅sin⎜t⋅w - ──────⎟ + r ⋅sin⎜t⋅w - ──────⎟⎟
#      ⎝        F   ⎠         ⎝        F   ⎠⎠
# ───────────────────────────────────────────

# %%
weyl[0,2,0,2]
# Out:
#   ⎛    5  3    4⎛      log(r)⎞       4  3    3⎛      log(r)⎞    ⎛      log(r)⎞
# M⋅⎜48⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 40⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟
#   ⎝             ⎝        F   ⎠                ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#         4  3    3⎛      log(r)⎞       4  2      3⎛      log(r)⎞      3  3    4
#  - 192⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ + 72⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟ - 8⋅F ⋅M ⋅sin
#                  ⎝        F   ⎠                  ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎛      log(r)⎞        3  3    2⎛      log(r)⎞    ⎛      log(r)⎞        3  3
# ⎜t⋅w - ──────⎟ - 120⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ + 288⋅F ⋅M ⋅si
# ⎝        F   ⎠                 ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#  2⎛      log(r)⎞       3  2      2⎛      log(r)⎞    ⎛      log(r)⎞        3  2
# n ⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅r⋅sin ⎜t⋅w - ──────⎟⋅cos⎜t⋅w - ──────⎟ - 216⋅F ⋅M
#   ⎝        F   ⎠                  ⎝        F   ⎠    ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       2⎛      log(r)⎞      3    4  2    2⎛      log(r)⎞      3    4  2    2⎛
# ⋅r⋅sin ⎜t⋅w - ──────⎟ + 2⋅F ⋅M⋅r ⋅w ⋅sin ⎜t⋅w - ──────⎟ + 4⋅F ⋅M⋅r ⋅w ⋅cos ⎜t⋅
#        ⎝        F   ⎠                    ⎝        F   ⎠                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#     log(r)⎞       3    2    2⎛      log(r)⎞       2  3    3⎛      log(r)⎞
# w - ──────⎟ + 36⋅F ⋅M⋅r ⋅sin ⎜t⋅w - ──────⎟ + 24⋅F ⋅M ⋅sin ⎜t⋅w - ──────⎟ - 19
#       F   ⎠                  ⎝        F   ⎠                ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    2  3    ⎛      log(r)⎞       2  3    ⎛        2⋅log(r)⎞       2  2      3⎛
# 2⋅F ⋅M ⋅sin⎜t⋅w - ──────⎟ + 60⋅F ⋅M ⋅sin⎜2⋅t⋅w - ────────⎟ - 12⋅F ⋅M ⋅r⋅sin ⎜t
#            ⎝        F   ⎠               ⎝           F    ⎠                  ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                              6
#
#
#      log(r)⎞        2  2      ⎛      log(r)⎞       2  2      ⎛        2⋅log(r)
# ⋅w - ──────⎟ + 216⋅F ⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ - 60⋅F ⋅M ⋅r⋅sin⎜2⋅t⋅w - ────────
#        F   ⎠                  ⎝        F   ⎠                 ⎝           F
# ──────────────────────────────────────────────────────────────────────────────
#                                          2
#     2 ⎛         ⎛      log(r)⎞          ⎞
# ⋅F⋅r ⋅⎜2⋅F⋅M⋅sin⎜t⋅w - ──────⎟ - 2⋅M + r⎟
#       ⎝         ⎝        F   ⎠          ⎠
#
# ⎞      2    4  2    ⎛      log(r)⎞       2    2    ⎛      log(r)⎞       2    2
# ⎟ - 2⋅F ⋅M⋅r ⋅w ⋅sin⎜t⋅w - ──────⎟ - 72⋅F ⋅M⋅r ⋅sin⎜t⋅w - ──────⎟ + 15⋅F ⋅M⋅r
# ⎠                   ⎝        F   ⎠                 ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#     ⎛        2⋅log(r)⎞    2  5  2    ⎛      log(r)⎞      2  3    ⎛      log(r)
# ⋅sin⎜2⋅t⋅w - ────────⎟ + F ⋅r ⋅w ⋅sin⎜t⋅w - ──────⎟ + 6⋅F ⋅r ⋅sin⎜t⋅w - ──────
#     ⎝           F    ⎠               ⎝        F   ⎠              ⎝        F
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞         3    2⎛      log(r)⎞         3    ⎛      log(r)⎞         3         2
# ⎟ - 24⋅F⋅M ⋅sin ⎜t⋅w - ──────⎟ - 40⋅F⋅M ⋅cos⎜t⋅w - ──────⎟ + 48⋅F⋅M  + 24⋅F⋅M
# ⎠               ⎝        F   ⎠              ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#       2⎛      log(r)⎞         2      ⎛      log(r)⎞         2            2
# ⋅r⋅sin ⎜t⋅w - ──────⎟ + 60⋅F⋅M ⋅r⋅cos⎜t⋅w - ──────⎟ - 72⋅F⋅M ⋅r - 6⋅F⋅M⋅r ⋅sin
#        ⎝        F   ⎠                ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2⎛      log(r)⎞           2    ⎛      log(r)⎞           2        3    ⎛      l
#  ⎜t⋅w - ──────⎟ - 30⋅F⋅M⋅r ⋅cos⎜t⋅w - ──────⎟ + 36⋅F⋅M⋅r  + 5⋅F⋅r ⋅cos⎜t⋅w - ─
#  ⎝        F   ⎠                ⎝        F   ⎠                         ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# og(r)⎞        3      3    ⎛      log(r)⎞       2      ⎛      log(r)⎞        2
# ─────⎟ - 6⋅F⋅r  + 8⋅M ⋅sin⎜t⋅w - ──────⎟ - 12⋅M ⋅r⋅sin⎜t⋅w - ──────⎟ + 6⋅M⋅r ⋅
#  F   ⎠                    ⎝        F   ⎠              ⎝        F   ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#    ⎛      log(r)⎞    3    ⎛      log(r)⎞⎞
# sin⎜t⋅w - ──────⎟ - r ⋅sin⎜t⋅w - ──────⎟⎟
#    ⎝        F   ⎠         ⎝        F   ⎠⎠
# ─────────────────────────────────────────

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

t = 1

theta = 1
phi = 1
F = 0.1
M = 1
w = 10



#Make x values - which we will sub in for r 
x = np.arange(4, 20.0, 0.04)

# Call the functions
y = func(t,x,theta, phi, F, M, w)[0][1][0][1]/x
z = -func(t,x,theta, phi, F, M, w)[0][2][0][2]/(x*x) # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("Weyl tensor")
# Out:
# (t, r, theta, phi, F, M, w)
# Text(0.5, 1.0, 'Weyl tensor')
