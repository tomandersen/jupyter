# %% [markdown]
# # Longitudinal Wave Metric Search - R Squared velocity with Kinetic energy
# ## Waves grown in length with the square of R
# # waves run a constant speed, with gamma of 2, wavelength grows with R, so frequency is a function of R
# Frequency is now a function of R

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
import einsteinpy

from sympy import symbols, sin, cos, sinh, ln
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()
print(einsteinpy.__version__)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 0.4.0

# %% [markdown]
# ### We in this instance allow super luminal longitudinal waves
# (maybe Lorentz transform only works on transverse wave generated matter?) - anyway ignore the KE of the wave. Not likely a good guess but here it is.
#
# #### Make time tick regular, waves get longer as they go to bigger r, these are waves of gravitational field energy (the energy in the grav potential field), they need to get longer to support the fact that we need to hold a fraction F of the mean mass M in the wave.

# %%
syms = sympy.symbols("t r theta phi")
G, M, F, a, w = sympy.symbols("G M F a w")
#a = M*(1 - F*sin(w*(syms[0] - 1/(w*F)*ln(syms[1])))) + M*(1 - F*sin(w*(syms[0] + 1/(w*F)*ln(syms[1]))))
# use trig identities, standing waves result from in plus out
Y = 10.0 # Y is a whacky factor - will Y != 1 make the stress energy tensor blow up?

w = 0.1/(syms[1]*syms[1])

# Logarithimic 
a = M*(1 - F*2*sin(w*syms[0])*cos(syms[1]/(Y*F)))



mT = sympy.diff(a, syms[0])
print(mT)
mR = sympy.diff(a, syms[1])
print(mR)


# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]

#take your pick
#list2d[0][0] = -mT*mT/(mR*mR)/(1 - 2*a/syms[1])
#list2d[0][0] = mT/mR/(1 - 2*a/syms[1])
list2d[0][0] = -1/(1 - 2*a/syms[1])

list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - 2*a/syms[1]) 
list2d[2][2] = (syms[1])**2
list2d[3][3] = (syms[1])**2*(sympy.sin(syms[2]) ** 2)
sch = MetricTensor(list2d, syms)
sch.tensor()
# Out:
# -0.2*F*M*cos(0.1*r/F)*cos(0.1*t/r**2)/r**2
# M*(0.4*F*t*cos(0.1*r/F)*cos(0.1*t/r**2)/r**3 + 0.2*sin(0.1*r/F)*sin(0.1*t/r**2))
# ⎡                    -1                                                                                  ⎤
# ⎢───────────────────────────────────────────                       0                       0       0     ⎥
# ⎢      ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞    ⎞                                                                 ⎥
# ⎢  2⋅M⋅⎜- 2⋅F⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1⎟                                                                 ⎥
# ⎢      ⎜         ⎜   2 ⎟    ⎝  F  ⎠    ⎟                                                                 ⎥
# ⎢      ⎝         ⎝  r  ⎠               ⎠                                                                 ⎥
# ⎢- ───────────────────────────────────── + 1                                                             ⎥
# ⎢                    r                                                                                   ⎥
# ⎢                                                                                                        ⎥
# ⎢                                                                  1                                     ⎥
# ⎢                     0                       ───────────────────────────────────────────  0       0     ⎥
# ⎢                                                   ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞    ⎞                    ⎥
# ⎢                                               2⋅M⋅⎜- 2⋅F⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1⎟                    ⎥
# ⎢                                                   ⎜         ⎜   2 ⎟    ⎝  F  ⎠    ⎟                    ⎥
# ⎢                                                   ⎝         ⎝  r  ⎠               ⎠                    ⎥
# ⎢                                             - ───────────────────────────────────── + 1                ⎥
# ⎢                                                                 r                                      ⎥
# ⎢                                                                                                        ⎥
# ⎢                                                                                           2            ⎥
# ⎢                     0                                            0                       r       0     ⎥
# ⎢                                                                                                        ⎥
# ⎢                                                                                               2    2   ⎥
# ⎣                     0                                            0                       0   r ⋅sin (θ)⎦

# %% [markdown]
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡                                                                                                                   3
# ⎢  ⎛            ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞⎞ ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                 ⎞                                                                                ⎛
# ⎢M⋅⎜51.2⋅F⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 25.6⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟⎟⋅⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0.25⋅r⎟                                                                    -0.4⋅F⋅M⋅cos⎜
# ⎢  ⎜            ⎝  F  ⎠    ⎜   2 ⎟              ⎝  F  ⎠    ⎜   2 ⎟⎟ ⎜           ⎜   2 ⎟    ⎝  F  ⎠                 ⎟                                                                                ⎝
# ⎢  ⎝                       ⎝  r  ⎠                         ⎝  r  ⎠⎠ ⎝           ⎝  r  ⎠                            ⎠
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────                                                          ──────────────────────
# ⎢                                                                              4                                                                                                3 ⎛           ⎛0.1⋅t⎞
# ⎢                                     4 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞                                                                                                r ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟
# ⎢                                    r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟                                                                                                   ⎜           ⎜   2 ⎟
# ⎢                                       ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟                                                                                                   ⎝           ⎝  r  ⎠
# ⎢                                       ⎝         ⎝  r  ⎠                     ⎠
# ⎢
# ⎢                                                                                                                                                                        3
# ⎢                                                       ⎛0.1⋅r⎞    ⎛0.1⋅t⎞                                               ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                 ⎞  ⎛         2    ⎛0.1⋅t⎞
# ⎢                                         -0.025⋅F⋅M⋅cos⎜─────⎟⋅cos⎜─────⎟                                             M⋅⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0.25⋅r⎟ ⋅⎜512.0⋅F⋅r ⋅sin⎜─────⎟⋅cos
# ⎢                                                       ⎝  F  ⎠    ⎜   2 ⎟                                               ⎜           ⎜   2 ⎟    ⎝  F  ⎠                 ⎟  ⎜              ⎜   2 ⎟
# ⎢                                                                  ⎝  r  ⎠                                               ⎝           ⎝  r  ⎠                            ⎠  ⎝              ⎝  r  ⎠
# ⎢                              ────────────────────────────────────────────────────────                                ──────────────────────────────────────────────────────────────────────────────
# ⎢                               3 ⎛            ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                     ⎞
# ⎢                              r ⋅⎜0.25⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.125⋅M + 0.0625⋅r⎟                                                                                            4 ⎛         ⎛0.1⋅t
# ⎢                                 ⎜            ⎜   2 ⎟    ⎝  F  ⎠                     ⎟                                                                                           r ⋅⎜4⋅F⋅M⋅sin⎜─────
# ⎢                                 ⎝            ⎝  r  ⎠                                ⎠                                                                                              ⎜         ⎜   2
# ⎢                                                                                                                                                                                    ⎝         ⎝  r
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                         0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                         0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
# 0.1⋅r⎞    ⎛0.1⋅t⎞
# ─────⎟⋅cos⎜─────⎟
#   F  ⎠    ⎜   2 ⎟
#           ⎝  r  ⎠
# ────────────────────────────
#     ⎛0.1⋅r⎞                ⎞
# ⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#     ⎝  F  ⎠                ⎟
#                            ⎠
#
#
#
# ⎛0.1⋅r⎞               ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞          2⎞
# ⎜─────⎟ + 51.2⋅F⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 25.6⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ - 256.0⋅r ⎟
# ⎝  F  ⎠               ⎝  F  ⎠    ⎜   2 ⎟              ⎝  F  ⎠    ⎜   2 ⎟           ⎟
#                                  ⎝  r  ⎠                         ⎝  r  ⎠           ⎠
# ────────────────────────────────────────────────────────────────────────────────────
#                        4
# ⎞    ⎛0.1⋅r⎞          ⎞
# ⎟⋅cos⎜─────⎟ - 2⋅M + r⎟
# ⎟    ⎝  F  ⎠          ⎟
# ⎠                     ⎠
#
#                                                                                                                                             2
#                                                                                             ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                 ⎞  ⎛       3    4    2⎛0.1⋅r⎞    2⎛0.1⋅t⎞          3    4
#                                                                                       0.5⋅M⋅⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0.25⋅r⎟ ⋅⎜256.0⋅F ⋅M⋅r ⋅cos ⎜─────⎟⋅cos ⎜─────⎟ - 256.0⋅F ⋅M⋅r ⋅
#                                                                                             ⎜           ⎜   2 ⎟    ⎝  F  ⎠                 ⎟  ⎜                  ⎝  F  ⎠     ⎜   2 ⎟
#                                                                                             ⎝           ⎝  r  ⎠                            ⎠  ⎝                              ⎝  r  ⎠
#   0                                                                                   ───────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#   0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    2⎛0.1⋅r⎞          3    2      ⎛0.1⋅t⎞    2⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    2    2⎛0.1⋅r⎞          3    2    2⎛0.1⋅r⎞          2    4    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞
# cos ⎜─────⎟ - 153.6⋅F ⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos ⎜─────⎟⋅cos⎜─────⎟ - 2.56⋅F ⋅M⋅r ⋅cos ⎜─────⎟ + 10.24⋅F ⋅M⋅t ⋅cos ⎜─────⎟ + 256.0⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 76.8⋅F ⋅M⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ +
#     ⎝  F  ⎠                      ⎜   2 ⎟     ⎝  F  ⎠    ⎜   2 ⎟                    ⎝  F  ⎠                     ⎝  F  ⎠                    ⎜   2 ⎟    ⎝  F  ⎠                     ⎝  F  ⎠    ⎜   2 ⎟
#                                  ⎝  r  ⎠                ⎝  r  ⎠                                                                           ⎝  r  ⎠                                           ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                           0
#
#
#
#
#
#
#
#
#
#
#
#                                                                           0
#
#
#
#
#
#
#
#        2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          2  5    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2  3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         2  3    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2
#  1.28⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 5.12⋅F ⋅M⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 128.0⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 64.0⋅F ⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ - 0.64⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 2.56⋅F ⋅r⋅t ⋅s
#                  ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                  ⎜   2 ⎟    ⎝  F  ⎠                   ⎝  F  ⎠    ⎜   2 ⎟                 ⎜   2 ⎟    ⎝  F  ⎠
#                  ⎝  r  ⎠                              ⎝  r  ⎠                             ⎝  r  ⎠                                         ⎝  r  ⎠                 ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                         2
#                                5 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                ⎞
#                             F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#                                  ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜           ⎜   2 ⎟    ⎝  F  ⎠                ⎟
#                                  ⎝         ⎝  r  ⎠                     ⎠  ⎝           ⎝  r  ⎠                           ⎠
#
#
#
#
#
#
#                                                                           0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ⎛0.1⋅t⎞    ⎛0.1⋅r⎞             6    2⎛0.1⋅t⎞             6             4             3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           5           4      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞
# in⎜─────⎟⋅cos⎜─────⎟ - 2.56⋅F⋅M⋅r ⋅cos ⎜─────⎟ + 2.56⋅F⋅M⋅r  - 64.0⋅F⋅M⋅r  + 5.12⋅F⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ - 12.8⋅F⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ + 64.0⋅F⋅r  - 2.56⋅F⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ -
#   ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟                                                ⎝  F  ⎠    ⎜   2 ⎟                ⎝  F  ⎠    ⎜   2 ⎟                              ⎝  F  ⎠    ⎜   2 ⎟
#   ⎝  r  ⎠                              ⎝  r  ⎠                                                           ⎝  r  ⎠                           ⎝  r  ⎠                                         ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#                                                           0
#
#
#
#
#
#
#
# 1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          2  5    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2  3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         2  3    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞
# ───⎟⋅cos⎜─────⎟ - 5.12⋅F ⋅M⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 128.0⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 64.0⋅F ⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ - 0.64⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 2.56⋅F ⋅r⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟
#  2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                  ⎜   2 ⎟    ⎝  F  ⎠                   ⎝  F  ⎠    ⎜   2 ⎟                 ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠
# r  ⎠                              ⎝  r  ⎠                             ⎝  r  ⎠                                         ⎝  r  ⎠                 ⎝  r  ⎠                              ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                         2
#                5 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                ⎞
#             F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#                  ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜           ⎜   2 ⎟    ⎝  F  ⎠                ⎟
#                  ⎝         ⎝  r  ⎠                     ⎠  ⎝           ⎝  r  ⎠                           ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              6    2⎛0.1⋅t⎞             6             4             3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           5           4      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅t⎞
#  - 2.56⋅F⋅M⋅r ⋅cos ⎜─────⎟ + 2.56⋅F⋅M⋅r  - 64.0⋅F⋅M⋅r  + 5.12⋅F⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ - 12.8⋅F⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ + 64.0⋅F⋅r  - 2.56⋅F⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ - 1.28⋅M⋅r ⋅sin⎜─────⎟
#                    ⎜   2 ⎟                                                ⎝  F  ⎠    ⎜   2 ⎟                ⎝  F  ⎠    ⎜   2 ⎟                              ⎝  F  ⎠    ⎜   2 ⎟                ⎜   2 ⎟
#                    ⎝  r  ⎠                                                           ⎝  r  ⎠                           ⎝  r  ⎠                                         ⎝  r  ⎠                ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                     ⎤
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#     ⎛0.1⋅r⎞         7    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞⎞    2   ⎥
# ⋅cos⎜─────⎟ + 0.64⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟⎟⋅sin (θ)⎥
#     ⎝  F  ⎠              ⎜   2 ⎟    ⎝  F  ⎠⎟        ⎥
#                          ⎝  r  ⎠           ⎠        ⎥
# ────────────────────────────────────────────────────⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎥
#                                                     ⎦

# %%
ri = RicciTensor.from_metric(sch)
ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡  ⎛                                              3
# ⎢  ⎜     2 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛       2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞              ⎛0.1⋅r⎞    ⎛0.1⋅t⎞        3    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞    2⎞   ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞
# ⎢M⋅⎜2⋅F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜2.0⋅F⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 0.4⋅F⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 0.2⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ - r ⎟ + ⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0
# ⎢  ⎜       ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜            ⎜   2 ⎟    ⎝  F  ⎠              ⎝  F  ⎠    ⎜   2 ⎟             ⎝  F  ⎠    ⎜   2 ⎟     ⎟   ⎜           ⎜   2 ⎟    ⎝  F  ⎠
# ⎢  ⎝       ⎝         ⎝  r  ⎠                     ⎠  ⎝            ⎝  r  ⎠                                    ⎝  r  ⎠                        ⎝  r  ⎠     ⎠   ⎝           ⎝  r  ⎠
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#       2
#      ⎞  ⎛       3    4    2⎛0.1⋅r⎞    2⎛0.1⋅t⎞          3    4    2⎛0.1⋅r⎞         3    2      ⎛0.1⋅t⎞    2⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    2    2⎛0.1⋅r⎞         3    2    2⎛0.1⋅r⎞          2    4
# .25⋅r⎟ ⋅⎜128.0⋅F ⋅M⋅r ⋅cos ⎜─────⎟⋅cos ⎜─────⎟ - 128.0⋅F ⋅M⋅r ⋅cos ⎜─────⎟ - 76.8⋅F ⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos ⎜─────⎟⋅cos⎜─────⎟ - 1.28⋅F ⋅M⋅r ⋅cos ⎜─────⎟ + 5.12⋅F ⋅M⋅t ⋅cos ⎜─────⎟ + 128.0⋅F ⋅M⋅r ⋅s
#      ⎟  ⎜                  ⎝  F  ⎠     ⎜   2 ⎟                     ⎝  F  ⎠                     ⎜   2 ⎟     ⎝  F  ⎠    ⎜   2 ⎟                    ⎝  F  ⎠                    ⎝  F  ⎠
#      ⎠  ⎝                              ⎝  r  ⎠                                                 ⎝  r  ⎠                ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2  5    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2  3      ⎛0.1⋅r⎞
# in⎜─────⎟⋅cos⎜─────⎟ + 38.4⋅F ⋅M⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 0.64⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.56⋅F ⋅M⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 64.0⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 32.0⋅F ⋅r ⋅t⋅cos⎜─────⎟⋅co
#   ⎜   2 ⎟    ⎝  F  ⎠                     ⎝  F  ⎠    ⎜   2 ⎟                   ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                 ⎜   2 ⎟    ⎝  F  ⎠                   ⎝  F  ⎠
#   ⎝  r  ⎠                                           ⎝  r  ⎠                   ⎝  r  ⎠                              ⎝  r  ⎠                            ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                             3
#                    6 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                ⎞
#                 F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#                      ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜           ⎜   2 ⎟    ⎝  F  ⎠                ⎟
#                      ⎝         ⎝  r  ⎠                     ⎠  ⎝           ⎝  r  ⎠                           ⎠
#
#
#                                                            ⎛0.1⋅r⎞    ⎛0.1⋅t⎞
#                                              -0.025⋅F⋅M⋅cos⎜─────⎟⋅cos⎜─────⎟
#                                                            ⎝  F  ⎠    ⎜   2 ⎟
#                                                                       ⎝  r  ⎠
#                                   ────────────────────────────────────────────────────────
#                                    3 ⎛            ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                     ⎞
#                                   r ⋅⎜0.25⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.125⋅M + 0.0625⋅r⎟
#                                      ⎜            ⎜   2 ⎟    ⎝  F  ⎠                     ⎟
#                                      ⎝            ⎝  r  ⎠                                ⎠
#
#
#
#
#
#
#                                                               0
#
#
#
#
#
#
#                                                               0
#
#
#
#  ⎛0.1⋅t⎞         2  3    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞             6    2⎛0.1⋅t⎞             6             4             3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞          6    ⎛0.1⋅r⎞
# s⎜─────⎟ - 0.32⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1.28⋅F ⋅r⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 1.28⋅F⋅M⋅r ⋅cos ⎜─────⎟ + 1.28⋅F⋅M⋅r  - 32.0⋅F⋅M⋅r  + 2.56⋅F⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ - 6.4⋅F⋅r ⋅sin⎜─────⎟⋅si
#  ⎜   2 ⎟                 ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟                                                ⎝  F  ⎠    ⎜   2 ⎟               ⎝  F  ⎠
#  ⎝  r  ⎠                 ⎝  r  ⎠                              ⎝  r  ⎠                              ⎝  r  ⎠                                                           ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                            ⎞
#  ⎛0.1⋅t⎞           5           4      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         7    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞⎞⎟
# n⎜─────⎟ + 32.0⋅F⋅r  - 1.28⋅F⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.64⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 0.32⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟⎟⎟
#  ⎜   2 ⎟                              ⎝  F  ⎠    ⎜   2 ⎟                ⎜   2 ⎟    ⎝  F  ⎠              ⎜   2 ⎟    ⎝  F  ⎠⎟⎟
#  ⎝  r  ⎠                                         ⎝  r  ⎠                ⎝  r  ⎠                         ⎝  r  ⎠           ⎠⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                                                 ⎛                                              3
#                                                                                                                                 ⎜     2 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛       2    ⎛0.1⋅t⎞
#                                                                                                                               M⋅⎜2⋅F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜2.0⋅F⋅r ⋅sin⎜─────⎟
#                                                                                                                                 ⎜       ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜            ⎜   2 ⎟
#                                                                                                                                 ⎝       ⎝         ⎝  r  ⎠                     ⎠  ⎝            ⎝  r  ⎠
#                                                                                                                               ───────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                    2
#     ⎛0.1⋅r⎞              ⎛0.1⋅r⎞    ⎛0.1⋅t⎞        3    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞    2⎞   ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                 ⎞  ⎛         3    4    2⎛0.1⋅r⎞    2⎛0.1⋅t⎞          3    4    2⎛0.
# ⋅cos⎜─────⎟ + 0.4⋅F⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 0.2⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ - r ⎟ + ⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0.25⋅r⎟ ⋅⎜- 128.0⋅F ⋅M⋅r ⋅cos ⎜─────⎟⋅cos ⎜─────⎟ + 128.0⋅F ⋅M⋅r ⋅cos ⎜──
#     ⎝  F  ⎠              ⎝  F  ⎠    ⎜   2 ⎟             ⎝  F  ⎠    ⎜   2 ⎟     ⎟   ⎜           ⎜   2 ⎟    ⎝  F  ⎠                 ⎟  ⎜                    ⎝  F  ⎠     ⎜   2 ⎟                     ⎝
#                                     ⎝  r  ⎠                        ⎝  r  ⎠     ⎠   ⎝           ⎝  r  ⎠                            ⎠  ⎝                                ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                                                         ⎛0.1⋅r⎞    ⎛0
#                                                                                                                                                                             -0.4⋅F⋅M⋅cos⎜─────⎟⋅cos⎜─
#                                                                                                                                                                                         ⎝  F  ⎠    ⎜
#                                                                                                                                                                                                    ⎝
#                                                                                                                                                                    ──────────────────────────────────
#                                                                                                                                                                     3 ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞
#                                                                                                                                                                    r ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟
#                                                                                                                                                                       ⎜           ⎜   2 ⎟    ⎝  F  ⎠
#                                                                                                                                                                       ⎝           ⎝  r  ⎠
#
#
#
# 1⋅r⎞         3    2      ⎛0.1⋅t⎞    2⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    2    2⎛0.1⋅r⎞         3    2    2⎛0.1⋅r⎞          2    4    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         2
# ───⎟ + 76.8⋅F ⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos ⎜─────⎟⋅cos⎜─────⎟ + 1.28⋅F ⋅M⋅r ⋅cos ⎜─────⎟ - 5.12⋅F ⋅M⋅t ⋅cos ⎜─────⎟ - 128.0⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 38.4⋅F ⋅M⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ - 0.64⋅F ⋅
# F  ⎠                     ⎜   2 ⎟     ⎝  F  ⎠    ⎜   2 ⎟                    ⎝  F  ⎠                    ⎝  F  ⎠                    ⎜   2 ⎟    ⎝  F  ⎠                     ⎝  F  ⎠    ⎜   2 ⎟
#                          ⎝  r  ⎠                ⎝  r  ⎠                                                                          ⎝  r  ⎠                                           ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                                                           3
#                                                                                                                                                  6 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛
# ...
# sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#    ⎜   2 ⎟    ⎝  F  ⎠                ⎟
#    ⎝  r  ⎠                           ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    ⎛0.1⋅r⎞             6    2⎛0.1⋅t⎞             6             4             3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞          6    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           5           4      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6
# cos⎜─────⎟ + 1.28⋅F⋅M⋅r ⋅cos ⎜─────⎟ - 1.28⋅F⋅M⋅r  + 32.0⋅F⋅M⋅r  - 2.56⋅F⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ + 6.4⋅F⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ - 32.0⋅F⋅r  + 1.28⋅F⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ + 0.64⋅M⋅r ⋅s
#    ⎝  F  ⎠                   ⎜   2 ⎟                                                ⎝  F  ⎠    ⎜   2 ⎟               ⎝  F  ⎠    ⎜   2 ⎟                              ⎝  F  ⎠    ⎜   2 ⎟
#                              ⎝  r  ⎠                                                           ⎝  r  ⎠                          ⎝  r  ⎠                                         ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                             ⎤
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                           0                                          0                      ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                      ⎞                                                                                      ⎥
#   ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         7    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞⎞⎟                                                                                      ⎥
# in⎜─────⎟⋅cos⎜─────⎟ - 0.32⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟⎟⎟                                                                                      ⎥
#   ⎜   2 ⎟    ⎝  F  ⎠              ⎜   2 ⎟    ⎝  F  ⎠⎟⎟                                                                                      ⎥
#   ⎝  r  ⎠                         ⎝  r  ⎠           ⎠⎠                                                                                      ⎥
# ──────────────────────────────────────────────────────                    0                                          0                      ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                                                                                                             ⎥
#                                                             ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞    ⎞                                               ⎥
#                                                         2⋅M⋅⎜- 2⋅F⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1⎟                                               ⎥
#                                                             ⎜         ⎜   2 ⎟    ⎝  F  ⎠    ⎟                                               ⎥
#                                                             ⎝         ⎝  r  ⎠               ⎠                                               ⎥
#                                                         ─────────────────────────────────────                        0                      ⎥
#                                                                           r                                                                 ⎥
#                                                                                                                                             ⎥
#                                                                                                    ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞    ⎞    2   ⎥
#                                                                                                2⋅M⋅⎜- 2⋅F⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1⎟⋅sin (θ)⎥
#                                                                                                    ⎜         ⎜   2 ⎟    ⎝  F  ⎠    ⎟        ⎥
#                                                                                                    ⎝         ⎝  r  ⎠               ⎠        ⎥
#                                                                           0                    ─────────────────────────────────────────────⎥
#                                                                                                                      r                      ⎦

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = einst.tensor_lambdify()
print(args) # these are the argument values 

theta = 1
phi = 1
F = 0.01
M = 1
t = 1


#Make x values - which we will sub in for r 
x = np.arange(3.0, 20.0, 0.004)

# Call the functions
# note: what scale to use on these ? when is it appropriate to divide by r**2, etc? 
tt = func(t,x,theta, phi, F, M)[0][0]

tr = func(t,x,theta, phi, F, M)[0][1]/(x*x)

rr = func(t,x,theta, phi, F, M)[1][1]/(x*x)**2

hh = func(t,x,theta, phi, F, M)[2][2]/(x*x)**2

pp = func(t,x,theta, phi, F, M)[3][3]/(x*x*sin(theta)*sin(theta))**2


fig=plt.figure(figsize=(10, 5))
ax=fig.add_axes([0,2,1.0,1.0])

ax.plot(x,hh, "lightgrey",label="θθ", linewidth=6.0)
ax.plot(x,pp, "black",label="φφ", linewidth=0.5)

ax.plot(x,tt, "-b", label="tt")
ax.plot(x,rr, "-g", label="rr")
ax.plot(x,tr, "-r", label="tr")

ax.legend(loc="upper right")
ax.set_title("Einstein Tensor, G")
# Out:
# (t, r, theta, phi, F, M)
# Text(0.5, 1.0, 'Einstein Tensor, G')

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#    ⎛                                                                                                                              2                                                   2
#    ⎜     4 ⎛       ⎛0.1⋅t⎞    ⎛0.1⋅r⎞    ⎞ ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                ⎞ ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞    ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                 ⎞  ⎛         3
# -M⋅⎜4⋅F⋅r ⋅⎜2⋅F⋅sin⎜─────⎟⋅cos⎜─────⎟ - 1⎟⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟  - ⎜1.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.5⋅M + 0.25⋅r⎟ ⋅⎜- 256.0⋅F ⋅M
#    ⎜       ⎜       ⎜   2 ⎟    ⎝  F  ⎠    ⎟ ⎜           ⎜   2 ⎟    ⎝  F  ⎠                ⎟ ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟    ⎜           ⎜   2 ⎟    ⎝  F  ⎠                 ⎟  ⎜
#    ⎝       ⎝       ⎝  r  ⎠               ⎠ ⎝           ⎝  r  ⎠                           ⎠ ⎝         ⎝  r  ⎠                     ⎠    ⎝           ⎝  r  ⎠                            ⎠  ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#   4    2⎛0.1⋅r⎞    2⎛0.1⋅t⎞          3    4    2⎛0.1⋅r⎞          3    2      ⎛0.1⋅t⎞    2⎛0.1⋅r⎞    ⎛0.1⋅t⎞         3    2    2⎛0.1⋅r⎞          3    2    2⎛0.1⋅r⎞          2    4    ⎛0.1⋅t⎞    ⎛0.1
# ⋅r ⋅cos ⎜─────⎟⋅cos ⎜─────⎟ + 256.0⋅F ⋅M⋅r ⋅cos ⎜─────⎟ + 153.6⋅F ⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos ⎜─────⎟⋅cos⎜─────⎟ + 2.56⋅F ⋅M⋅r ⋅cos ⎜─────⎟ - 10.24⋅F ⋅M⋅t ⋅cos ⎜─────⎟ - 256.0⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜───
#         ⎝  F  ⎠     ⎜   2 ⎟                     ⎝  F  ⎠                      ⎜   2 ⎟     ⎝  F  ⎠    ⎜   2 ⎟                    ⎝  F  ⎠                     ⎝  F  ⎠                    ⎜   2 ⎟    ⎝  F
#                     ⎝  r  ⎠                                                  ⎝  r  ⎠                ⎝  r  ⎠                                                                           ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
# ⋅r⎞         2    2      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          2  5    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2  3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞
# ──⎟ - 76.8⋅F ⋅M⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ - 1.28⋅F ⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 5.12⋅F ⋅M⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 128.0⋅F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 64.0⋅F ⋅r ⋅t⋅cos⎜─────⎟⋅cos⎜─────⎟ + 0.64⋅
#   ⎠                     ⎝  F  ⎠    ⎜   2 ⎟                   ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                  ⎜   2 ⎟    ⎝  F  ⎠                   ⎝  F  ⎠    ⎜   2 ⎟
#                                    ⎝  r  ⎠                   ⎝  r  ⎠                              ⎝  r  ⎠                             ⎝  r  ⎠                                         ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                     2
#            7 ⎛         ⎛0.1⋅t⎞    ⎛0.1⋅r⎞          ⎞  ⎛           ⎛0.1⋅t⎞    ⎛0.1⋅r⎞                ⎞
#         F⋅r ⋅⎜4⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2⋅M + r⎟ ⋅⎜4.0⋅F⋅M⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.0⋅M + 1.0⋅r⎟
#              ⎜         ⎜   2 ⎟    ⎝  F  ⎠          ⎟  ⎜           ⎜   2 ⎟    ⎝  F  ⎠                ⎟
#              ⎝         ⎝  r  ⎠                     ⎠  ⎝           ⎝  r  ⎠                           ⎠
#
#
#  2  3    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         2    2    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞             6    2⎛0.1⋅t⎞             6             4             3      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅r⎞    ⎛0.1⋅t⎞
# F ⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 2.56⋅F ⋅r⋅t ⋅sin⎜─────⎟⋅cos⎜─────⎟ + 2.56⋅F⋅M⋅r ⋅cos ⎜─────⎟ - 2.56⋅F⋅M⋅r  + 64.0⋅F⋅M⋅r  - 5.12⋅F⋅M⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ + 12.8⋅F⋅r ⋅sin⎜─────⎟⋅sin⎜─────⎟ - 64.0
#          ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟    ⎝  F  ⎠                   ⎜   2 ⎟                                                ⎝  F  ⎠    ⎜   2 ⎟                ⎝  F  ⎠    ⎜   2 ⎟
#          ⎝  r  ⎠                              ⎝  r  ⎠                              ⎝  r  ⎠                                                           ⎝  r  ⎠                           ⎝  r  ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                             ⎞
#     5           4      ⎛0.1⋅r⎞    ⎛0.1⋅t⎞           6    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞         7    ⎛0.1⋅t⎞    ⎛0.1⋅r⎞⎞⎟
# ⋅F⋅r  + 2.56⋅F⋅r ⋅t⋅sin⎜─────⎟⋅cos⎜─────⎟ + 1.28⋅M⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟ - 0.64⋅r ⋅sin⎜─────⎟⋅cos⎜─────⎟⎟⎟
#                        ⎝  F  ⎠    ⎜   2 ⎟                ⎜   2 ⎟    ⎝  F  ⎠              ⎜   2 ⎟    ⎝  F  ⎠⎟⎟
#                                   ⎝  r  ⎠                ⎝  r  ⎠                         ⎝  r  ⎠           ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
#plot the Ricci scalar

args, funcR = R.tensor_lambdify()
print(args) # these are the argument values 

t = 5

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5

#Make x values - which we will sub in for r 
x = np.arange(10.0, 100.0, 0.04)

# Call the functions
ricci = funcR(t,x,theta, phi, F, M, w)

fig=plt.figure(figsize=(8, 4))
ax=fig.add_axes([0,2,1.0,1.0])
ax.set_title("Ricci scalar")
ax.legend(loc="lower right")
ax.plot(x,ricci, label="Ricci scalar")
# Out:
# (t, r, theta, phi, F, M)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dc/zdmw2pxd67q028v5bf412_pc0000gn/T/ipykernel_42575/2790900691.py in <module>
#      16
#      17 # Call the functions
# ---> 18 ricci = funcR(t,x,theta, phi, F, M, w)
#      19
#      20 fig=plt.figure(figsize=(8, 4))
#
# TypeError: _lambdifygenerated() takes 6 positional arguments but 7 were given

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!

# %%
weyl[0,1,0,1]

# %%
weyl[0,2,0,2]

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

t = 1

theta = 1
phi = 1
F = 0.1
M = 1
w = 10



#Make x values - which we will sub in for r 
x = np.arange(4, 20.0, 0.04)

# Call the functions
y = func(t,x,theta, phi, F, M, w)[0][1][0][1]/x
z = -func(t,x,theta, phi, F, M, w)[0][2][0][2]/(x*x) # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("Weyl tensor")
