# %% [markdown]
# # Longitudinal Wave Metric Search - Birkoff
# ## Metric is always Schwarschild - with varying mass at different radius
# So the mass inside R is what matters.
#
# Constant frequency, wavelength goes as R, so wave is superluminal, but not instant. Wave speed cancels out of equation

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
import einsteinpy

from sympy import symbols, sin, cos, sinh, ln, lambdify
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()
print(einsteinpy.__version__)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 0.4.0

# %% [markdown]
# # sin wave outgoing

# %%
t, r, theta, phi = sympy.symbols("t r theta phi")
G, M, F, a, w, v = sympy.symbols("G M F a w, v")

# standing wave solutions are the easiest (for me) to imagine and model mathematically
# a_out is outgoing energy, so for a given time the mass will look bigger the farther out you are, as mass leaving has not yet passed you by

# dPhi/dR where phi is the phase will get us w/v, so if v goes as r (linear speed), we must use a phase as below with ln() 

# a_in = M + M*F*(t - r/v) + M*F/w*sin(w*(t - r/v))
# a_out = M - M*F*(t - r/v) + M*F/w*sin(w*(t + r/v))
a_in = M + M*F*(t - ln(r)/v) + M*F/w*sin(w*(t - ln(r)/v))
a_out = M - M*F*(t - ln(r)/v) + M*F/w*sin(w*(t + ln(r)/v))
#a = M*(1 - F*2*sin(w*t))

a = 1/2*(a_in + a_out)

#slope of mass loss for a_out is never lower than 0, which is what we need.
mT = sympy.diff(a_out, t)
print(mT)
mR = sympy.diff(a, r)
print(mR)

print(sympy.diff(ln(r/5), r))


# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]

#take your pick
#list2d[0][0] = -mT*mT/(mR*mR)/(1 - 2*a/r)
#list2d[0][0] = mT/mR/(1 - 2*a/r)


list2d[0][0] = (1 - 2*a/r)

list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - 2*a/r) 
list2d[2][2] = (r)**2
list2d[3][3] = (r)**2*(sympy.sin(theta) ** 2)

list2d[0][0] = list2d[0][0].simplify()
list2d[1][1] = list2d[1][1].simplify()


sch = MetricTensor(list2d, [t, r, theta, phi])
sch.tensor()
# Out:
# F*M*cos(w*(t + log(r)/v)) - F*M
# -0.5*F*M*cos(w*(t - log(r)/v))/(r*v) + 0.5*F*M*cos(w*(t + log(r)/v))/(r*v)
# 1/r
# ⎡                      ⎛w⋅log(r)⎞                                                                                    ⎤
# ⎢  2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟                                                                                    ⎥
# ⎢                      ⎝   v    ⎠   2.0⋅M                                                                            ⎥
# ⎢- ────────────────────────────── - ───── + 1.0                           0                            0       0     ⎥
# ⎢               r⋅w                   r                                                                              ⎥
# ⎢                                                                                                                    ⎥
# ⎢                                                                        r⋅w                                         ⎥
# ⎢                      0                         ────────────────────────────────────────────────────  0       0     ⎥
# ⎢                                                                      ⎛w⋅log(r)⎞                                    ⎥
# ⎢                                                - 2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ - 2.0⋅M⋅w + 1.0⋅r⋅w                ⎥
# ⎢                                                                      ⎝   v    ⎠                                    ⎥
# ⎢                                                                                                                    ⎥
# ⎢                                                                                                       2            ⎥
# ⎢                      0                                                  0                            r       0     ⎥
# ⎢                                                                                                                    ⎥
# ⎢                                                                                                           2    2   ⎥
# ⎣                      0                                                  0                            0   r ⋅sin (θ)⎦

# %%
###Plot mass function
# first make the tensor into a function, printing 

mass_l = lambdify([t, r, M, F, w, v], a_out)

r_vals = np.arange(3.0, 80.0, 0.01)

m_vals = mass_l(1, r_vals, 1, 0.001, 6, 0.2)

plt.plot(r_vals, m_vals)
plt.ylabel("Mass")
plt.show()

# %% [markdown]
# #### Figure - mass as a function of R for a fixed time. Total mass as seen
#
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
#einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡          ⎛                  ⎛w⋅log(r)⎞          ⎞
# ⎢          ⎜  F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟          ⎟
# ⎢          ⎜                  ⎝   v    ⎠   M      ⎟ ⎛      3  3      4         ⎛w⋅log(r)⎞    3⎛w⋅log(r)⎞         3  3      4         4⎛w⋅log(r)⎞         2  3        3         ⎛w⋅log(r)⎞    2⎛w⋅log(
# ⎢  8.0⋅F⋅M⋅⎜- ────────────────────────── - ─ + 0.5⎟⋅⎜0.25⋅F ⋅M ⋅v⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜────────⎟ + 0.25⋅F ⋅M ⋅w⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.75⋅F ⋅M ⋅v⋅w⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜──────
# ⎢          ⎝             r⋅w               r      ⎠ ⎝                          ⎝   v    ⎠     ⎝   v    ⎠                              ⎝   v    ⎠                               ⎝   v    ⎠     ⎝   v
# ⎢- ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
# r)⎞         2  3  2    3         3⎛w⋅log(r)⎞          2  2          3         ⎛w⋅log(r)⎞    2⎛w⋅log(r)⎞          2  2    2    3         3⎛w⋅log(r)⎞           3    2    2         ⎛w⋅log(r)⎞    ⎛w⋅lo
# ──⎟ + 0.75⋅F ⋅M ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.375⋅F ⋅M ⋅r⋅v⋅w⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜────────⎟ - 0.375⋅F ⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.75⋅F⋅M ⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────
#   ⎠                               ⎝   v    ⎠                                  ⎝   v    ⎠     ⎝   v    ⎠                                  ⎝   v    ⎠                               ⎝   v    ⎠    ⎝   v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# g(r)⎞           3  3    2         2⎛w⋅log(r)⎞           2      2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞           2    3    2         2⎛w⋅log(r)⎞               4  2  3    2         2⎛w⋅log(r)⎞
# ────⎟ + 0.75⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.75⋅F⋅M ⋅r⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ - 0.75⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.0625⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.1
#     ⎠                              ⎝   v    ⎠                                 ⎝   v    ⎠    ⎝   v    ⎠                                ⎝   v    ⎠                                     ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#                                                                                                                                                       3  2 ⎛                  ⎛w⋅log(r)⎞
#                                                                                                                                                      r ⋅v ⋅⎜- F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ - M⋅w + 0.5⋅
#                                                                                                                                                            ⎝                  ⎝   v    ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         4  2  3    2         2⎛w⋅log(r)⎞               2    2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞               2  3    2         2⎛w⋅log(r)⎞         3    3             ⎛w⋅log(r)⎞         3  4
# 25⋅F⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos ⎜────────⎟ + 0.1875⋅F⋅M⋅r ⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ + 0.1875⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.25⋅M ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.25⋅M ⋅w ⋅si
#                               ⎝   v    ⎠                                   ⎝   v    ⎠    ⎝   v    ⎠                                  ⎝   v    ⎠                            ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     3
#    ⎞
# r⋅w⎟
#    ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           ⎛w⋅log(r)⎞          2      3             ⎛w⋅log(r)⎞          2    4             ⎛w⋅log(r)⎞             4  2  4             ⎛w⋅log(r)⎞             2    3             ⎛w⋅log(r)⎞
# n(t⋅w)⋅cos⎜────────⎟ - 0.375⋅M ⋅r⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.375⋅M ⋅r⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.0625⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.1875⋅M⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.1875⋅M⋅
#           ⎝   v    ⎠                               ⎝   v    ⎠                             ⎝   v    ⎠                                 ⎝   v    ⎠                                ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                                                                                ⎛w⋅log(r)⎞
#                                                                                                                                          0.5⋅F⋅M⋅w⋅cos(t⋅w)⋅cos⎜────────⎟
#                                                                                                                                                                ⎝   v    ⎠
#                                                                                                                             ─────────────────────────────────────────────────────────
#                                                                                                                               ⎛                      ⎛w⋅log(r)⎞                     ⎞
#                                                                                                                             r⋅⎜- 0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#                                                                                                                               ⎝                      ⎝   v    ⎠                     ⎠
#
#
#
#
#
#                                                                                                                                                         0
#
#
#
#
#
#
#
#
#                                                                                                                                                         0
#
#
#
#
#
#
#                                                                                                                                                             ⎛
#  2  4             ⎛w⋅log(r)⎞            5  2  4             ⎛w⋅log(r)⎞            3    3             ⎛w⋅log(r)⎞            3  4             ⎛w⋅log(r)⎞⎞     ⎜       2    4  2  4    2         2⎛w⋅log
# r ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.03125⋅r ⋅v ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.03125⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.03125⋅r ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟⎟   M⋅⎜- 2.0⋅F ⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos ⎜─────
#                   ⎝   v    ⎠                                ⎝   v    ⎠                               ⎝   v    ⎠                             ⎝   v    ⎠⎠     ⎝                                  ⎝   v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ───────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                   2
# (r)⎞      4  2  4 ⎛                ⎛w⋅log(r)⎞                ⎞             ⎛w⋅log(r)⎞         ⎛                    ⎛w⋅log(r)⎞                    ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅
# ───⎟ - F⋅r ⋅v ⋅w ⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟⋅sin(t⋅w)⋅cos⎜────────⎟ + 4.0⋅M⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜──
#    ⎠              ⎝                ⎝   v    ⎠                ⎠             ⎝   v    ⎠         ⎝                    ⎝   v    ⎠                    ⎠  ⎝                ⎝   v    ⎠                   ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#   3    2         2⎛w⋅log(r)⎞               2    2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞               2  3    2         2⎛w⋅log(r)⎞         3    3             ⎛w⋅log(r)⎞         3  4             ⎛w
# ⋅w ⋅cos (t⋅w)⋅cos ⎜────────⎟ + 0.1875⋅F⋅M⋅r ⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ + 0.1875⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.25⋅M ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.25⋅M ⋅w ⋅sin(t⋅w)⋅cos⎜─
#                   ⎝   v    ⎠                                   ⎝   v    ⎠    ⎝   v    ⎠                                  ⎝   v    ⎠                            ⎝   v    ⎠                          ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                 3
#                ⎞
# - M⋅w + 0.5⋅r⋅w⎟
#                ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ⋅log(r)⎞          2      3             ⎛w⋅log(r)⎞          2    4             ⎛w⋅log(r)⎞             4  2  4             ⎛w⋅log(r)⎞             2    3             ⎛w⋅log(r)⎞             2  4
# ───────⎟ - 0.375⋅M ⋅r⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.375⋅M ⋅r⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.0625⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.1875⋅M⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.1875⋅M⋅r ⋅w ⋅sin(t⋅
#   v    ⎠                               ⎝   v    ⎠                             ⎝   v    ⎠                                 ⎝   v    ⎠                                ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                                                                                                    ⎤
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#       ⎛w⋅log(r)⎞            5  2  4             ⎛w⋅log(r)⎞            3    3             ⎛w⋅log(r)⎞            3  4             ⎛w⋅log(r)⎞⎞    2   ⎥
# w)⋅cos⎜────────⎟ + 0.03125⋅r ⋅v ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.03125⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.03125⋅r ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟⎟⋅sin (θ)⎥
#       ⎝   v    ⎠                                ⎝   v    ⎠                               ⎝   v    ⎠                             ⎝   v    ⎠⎠        ⎥
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎥
#                                                                                                                                                    ⎦

# %%
ri = RicciTensor.from_metric(sch)
#ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡  ⎛                                                                                                                                                                                          2
# ⎢  ⎜       2    4  2  4    2         2⎛w⋅log(r)⎞      4  2  4 ⎛                ⎛w⋅log(r)⎞                ⎞             ⎛w⋅log(r)⎞         ⎛                    ⎛w⋅log(r)⎞                    ⎞  ⎛
# ⎢M⋅⎜- 2.0⋅F ⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos ⎜────────⎟ - F⋅r ⋅v ⋅w ⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟⋅sin(t⋅w)⋅cos⎜────────⎟ + 4.0⋅M⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅
# ⎢  ⎝                                  ⎝   v    ⎠              ⎝                ⎝   v    ⎠                ⎠             ⎝   v    ⎠         ⎝                    ⎝   v    ⎠                    ⎠  ⎝
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                                                           2                                                     3
#             ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞          ⎛                ⎛w⋅log(r)⎞                ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞     ⎛
# sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟  + 4.0⋅v⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟ - w⋅⎜2.0⋅F⋅M⋅sin(t⋅
#             ⎝   v    ⎠                   ⎝   v    ⎠      ⎠          ⎝                ⎝   v    ⎠                ⎠  ⎝                ⎝   v    ⎠                   ⎝   v    ⎠      ⎠     ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                              4  2  2 ⎛                ⎛w⋅log(r)⎞                ⎞ ⎛
#                                                                                                                             r ⋅v ⋅w ⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅c
#                                                                                                                                      ⎝                ⎝   v    ⎠                ⎠ ⎝
#
#
#                                                                                                                                                                                      ⎛w⋅log(r)⎞
#                                                                                                                                                                0.5⋅F⋅M⋅w⋅cos(t⋅w)⋅cos⎜────────⎟
#                                                                                                                                                                                      ⎝   v    ⎠
#                                                                                                                                                   ───────────────────────────────────────────────────
#                                                                                                                                                     ⎛                      ⎛w⋅log(r)⎞
#                                                                                                                                                   r⋅⎜- 0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.5⋅M⋅w + 0.2
#                                                                                                                                                     ⎝                      ⎝   v    ⎠
#
#
#
#
#
#                                                                                                                                                                               0
#
#
#
#
#
#                                                                                                                                                                               0
#
#
#
#       ⎛w⋅log(r)⎞          ⎞ ⎛                ⎛w⋅log(r)⎞                ⎞ ⎛                    ⎛w⋅log(r)⎞                ⎞ ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞   ⎛
# w)⋅sin⎜────────⎟ + 1.0⋅r⋅v⎟⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 2.0⋅M⋅w - r⋅w⎟⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟ - ⎜F⋅M⋅sin(
#       ⎝   v    ⎠          ⎠ ⎝                ⎝   v    ⎠                ⎠ ⎝                    ⎝   v    ⎠                ⎠ ⎝                ⎝   v    ⎠                   ⎝   v    ⎠      ⎠   ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   ⎛w⋅log(r)⎞                ⎞
# os⎜────────⎟ + 2.0⋅M⋅w - r⋅w⎟
#   ⎝   v    ⎠                ⎠
#
#
#
#
#
# ──────
#      ⎞
# 5⋅r⋅w⎟
#      ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                    3                                                                                                                   ⎞
#         ⎛w⋅log(r)⎞                ⎞  ⎛       2             ⎛w⋅log(r)⎞                          ⎛w⋅log(r)⎞          2             ⎛w⋅log(r)⎞        2  ⎞⎟
# t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜8.0⋅F⋅v ⋅sin(t⋅w)⋅cos⎜────────⎟ + 12.0⋅F⋅v⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ - 4.0⋅F⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 8.0⋅v ⋅w⎟⎟
#         ⎝   v    ⎠                ⎠  ⎝                     ⎝   v    ⎠                          ⎝   v    ⎠                        ⎝   v    ⎠           ⎠⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                                                                             ⎛
#                                                                                                                                                             ⎜      ⎛                ⎛w⋅log(r)⎞
#                                                                                                                                                           M⋅⎜0.5⋅v⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w
#                                                                                                                                                             ⎝      ⎝                ⎝   v    ⎠
#                                                                                                                                                           ───────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           4                                                                                                                         ⎛
#          ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞   ⎛                    ⎛w⋅log(r)⎞                     ⎞ ⎜      2    4  2  4    2         2⎛w⋅log(r)⎞            4  2  4 ⎛
# - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟ - ⎜0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.5⋅M⋅w - 0.25⋅r⋅w⎟⋅⎜0.25⋅F ⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos ⎜────────⎟ + 0.125⋅F⋅r ⋅v ⋅w ⋅⎜
#          ⎠  ⎝                ⎝   v    ⎠                   ⎝   v    ⎠      ⎠   ⎝                    ⎝   v    ⎠                     ⎠ ⎝                                 ⎝   v    ⎠                    ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                         2                                                                2
#                 ⎛w⋅log(r)⎞                ⎞             ⎛w⋅log(r)⎞          ⎛                ⎛w⋅log(r)⎞                ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞           ⎛
# F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.25⋅M⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟  + 0.25⋅M⋅⎜
#                 ⎝   v    ⎠                ⎠             ⎝   v    ⎠          ⎝                ⎝   v    ⎠                ⎠  ⎝                ⎝   v    ⎠                   ⎝   v    ⎠      ⎠           ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                     ⎛w⋅log(r)⎞
#                                               0.5⋅F⋅M⋅w⋅cos(t⋅w)⋅cos⎜────────⎟
#                                                                     ⎝   v    ⎠
#                                  ─────────────────────────────────────────────────────────
#                                    ⎛                      ⎛w⋅log(r)⎞                     ⎞
#                                  r⋅⎜- 0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#                                    ⎝                      ⎝   v    ⎠                     ⎠
#
#                                                    2                                                                2                                                     3
#                     ⎛w⋅log(r)⎞                    ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞      ⎞          ⎛                ⎛w⋅log(r)⎞                ⎞  ⎛                ⎛w⋅log(r
# 1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟  - 0.5⋅v⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜───────
#                     ⎝   v    ⎠                    ⎠  ⎝                ⎝   v    ⎠                   ⎝   v    ⎠      ⎠          ⎝                ⎝   v    ⎠                ⎠  ⎝                ⎝   v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                  4
#           2  2 ⎛                    ⎛w⋅log(r)⎞                     ⎞ ⎛                ⎛w⋅log(r)⎞                ⎞
#          r ⋅v ⋅⎜0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.5⋅M⋅w - 0.25⋅r⋅w⎟⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟
#                ⎝                    ⎝   v    ⎠                     ⎠ ⎝                ⎝   v    ⎠                ⎠
#
#
#
#
#                                                              0
#
#
#
#
#
#                                                              0
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                        2
# )⎞                   ⎛w⋅log(r)⎞      ⎞          ⎛                    ⎛w⋅log(r)⎞          ⎞ ⎛                ⎛w⋅log(r)⎞                ⎞  ⎛                ⎛w⋅log(r)⎞                   ⎛w⋅log(r)⎞
# ─⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v⋅w⎟ - 0.25⋅w⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅sin⎜────────⎟ + 1.0⋅r⋅v⎟⋅⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜F⋅v⋅sin(t⋅w)⋅cos⎜────────⎟ + F⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ + v
#  ⎠                   ⎝   v    ⎠      ⎠          ⎝                    ⎝   v    ⎠          ⎠ ⎝                ⎝   v    ⎠                ⎠  ⎝                ⎝   v    ⎠                   ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                                                         0
#
#
#
#
#                                                   3                                                                                                                  ⎞⎞
#   ⎞   ⎛                ⎛w⋅log(r)⎞                ⎞  ⎛       2             ⎛w⋅log(r)⎞                         ⎛w⋅log(r)⎞          2             ⎛w⋅log(r)⎞        2  ⎞⎟⎟
# ⋅w⎟ + ⎜F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜1.0⋅F⋅v ⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.5⋅F⋅v⋅w⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.5⋅F⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.0⋅v ⋅w⎟⎟⎟
#   ⎠   ⎝                ⎝   v    ⎠                ⎠  ⎝                     ⎝   v    ⎠                         ⎝   v    ⎠                        ⎝   v    ⎠           ⎠⎠⎠
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────                 0
#
#
#
#
#
#                                                                                                                                                                                               ⎛w⋅log(
#                                                                                                                                                                          -2.0⋅F⋅M⋅sin(t⋅w)⋅sin⎜──────
#                                                                                                                                                                                               ⎝   v
#                                                                                                                                                                          ────────────────────────────
#                                                                                                                                                                                        r⋅v
#
#
#
#
#                                                                                                                                                                                         0
#
#
#                                               ⎤
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                          0                    ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                          0                    ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
#                                               ⎥
# r)⎞                                           ⎥
# ──⎟                                           ⎥
#   ⎠                                           ⎥
# ────                     0                    ⎥
#                                               ⎥
#                                               ⎥
#                   2                ⎛w⋅log(r)⎞ ⎥
#       -2.0⋅F⋅M⋅sin (θ)⋅sin(t⋅w)⋅sin⎜────────⎟ ⎥
#                                    ⎝   v    ⎠ ⎥
#       ────────────────────────────────────────⎥
#                         r⋅v                   ⎦

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = einst.tensor_lambdify()
print(args) # these are the argument values 

theta = 1
phi = 1
F = 0.01
M = 1
w = 5
t = 1.31312
v = 0.2


#Make x values - which we will sub in for r 
x = np.arange(7.0, 20.0, 0.01)

# Call the functions
# note: what scale to use on these ? when is it appropriate to divide by r**2, etc? 
tt = func(t,x,theta, phi, F, M, w, v)[0][0]

tr = func(t,x,theta, phi, F, M, w, v)[0][1]/(x*x)

rr = func(t,x,theta, phi, F, M, w, v)[1][1]/(x*x)**2

hh = func(t,x,theta, phi, F, M, w, v)[2][2]/(x*x)**2

pp = func(t,x,theta, phi, F, M, w, v)[3][3]/(x*x*sin(theta)*sin(theta))**2


fig=plt.figure(figsize=(10, 5))
ax=fig.add_axes([0,2,1.0,1.0])

ax.plot(x,hh, "lightgrey",label="θθ", linewidth=6.0)
ax.plot(x,pp, "black",label="φφ", linewidth=0.5)

ax.plot(x,tt, "-b", label="tt")
ax.plot(x,rr, "-g", label="rr")
ax.plot(x,tr, "-r", label="tr")

ax.legend(loc="upper right")
ax.set_title("Einstein Tensor, G")
# Out:
# (t, r, theta, phi, F, M, v, w)
# Text(0.5, 1.0, 'Einstein Tensor, G')

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#          ⎛      3  3      4         ⎛w⋅log(r)⎞    3⎛w⋅log(r)⎞         3  3      4         4⎛w⋅log(r)⎞         2  3        3         ⎛w⋅log(r)⎞    2⎛w⋅log(r)⎞         2  3  2    3         3⎛w⋅log(r)
# -8.0⋅F⋅M⋅⎜0.25⋅F ⋅M ⋅v⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜────────⎟ + 0.25⋅F ⋅M ⋅w⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.75⋅F ⋅M ⋅v⋅w⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜────────⎟ + 0.75⋅F ⋅M ⋅w ⋅sin (t⋅w)⋅cos ⎜────────
#          ⎝                          ⎝   v    ⎠     ⎝   v    ⎠                              ⎝   v    ⎠                               ⎝   v    ⎠     ⎝   v    ⎠                               ⎝   v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ⎞          2  2          3         ⎛w⋅log(r)⎞    2⎛w⋅log(r)⎞          2  2    2    3         3⎛w⋅log(r)⎞           3    2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞           3  3    2         2⎛w⋅log(r
# ⎟ - 0.375⋅F ⋅M ⋅r⋅v⋅w⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos ⎜────────⎟ - 0.375⋅F ⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.75⋅F⋅M ⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ + 0.75⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos ⎜───────
# ⎠                                  ⎝   v    ⎠     ⎝   v    ⎠                                  ⎝   v    ⎠                               ⎝   v    ⎠    ⎝   v    ⎠                              ⎝   v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# )⎞           2      2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞           2    3    2         2⎛w⋅log(r)⎞               4  2  3    2         2⎛w⋅log(r)⎞              4  2  3    2         2⎛w⋅log(r)⎞
# ─⎟ - 0.75⋅F⋅M ⋅r⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ - 0.75⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.0625⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ - 0.125⋅F⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos ⎜────────⎟ +
#  ⎠                                 ⎝   v    ⎠    ⎝   v    ⎠                                ⎝   v    ⎠                                     ⎝   v    ⎠                                    ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                                                      3
#                                                                                                                             3  2 ⎛                    ⎛w⋅log(r)⎞                    ⎞
#                                                                                                                            r ⋅v ⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜────────⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟
#                                                                                                                                  ⎝                    ⎝   v    ⎠                    ⎠
#
#             2    2    2         ⎛w⋅log(r)⎞    ⎛w⋅log(r)⎞               2  3    2         2⎛w⋅log(r)⎞         3    3             ⎛w⋅log(r)⎞         3  4             ⎛w⋅log(r)⎞          2      3
# 0.1875⋅F⋅M⋅r ⋅v⋅w ⋅sin (t⋅w)⋅sin⎜────────⎟⋅cos⎜────────⎟ + 0.1875⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos ⎜────────⎟ + 0.25⋅M ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.25⋅M ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.375⋅M ⋅r⋅v⋅w ⋅sin(
#                                 ⎝   v    ⎠    ⎝   v    ⎠                                  ⎝   v    ⎠                            ⎝   v    ⎠                          ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#         ⎛w⋅log(r)⎞          2    4             ⎛w⋅log(r)⎞             4  2  4             ⎛w⋅log(r)⎞             2    3             ⎛w⋅log(r)⎞             2  4             ⎛w⋅log(r)⎞            5
# t⋅w)⋅sin⎜────────⎟ - 0.375⋅M ⋅r⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.0625⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.1875⋅M⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ + 0.1875⋅M⋅r ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ + 0.03125⋅r ⋅v
#         ⎝   v    ⎠                             ⎝   v    ⎠                                 ⎝   v    ⎠                                ⎝   v    ⎠                              ⎝   v    ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# 2  4             ⎛w⋅log(r)⎞            3    3             ⎛w⋅log(r)⎞            3  4             ⎛w⋅log(r)⎞⎞
#  ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟ - 0.03125⋅r ⋅v⋅w ⋅sin(t⋅w)⋅sin⎜────────⎟ - 0.03125⋅r ⋅w ⋅sin(t⋅w)⋅cos⎜────────⎟⎟
#                  ⎝   v    ⎠                               ⎝   v    ⎠                             ⎝   v    ⎠⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
#plot the Ricci scalar

args, funcR = R.tensor_lambdify()
print(args) # these are the argument values 

t = 5

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5

#Make x values - which we will sub in for r 
x = np.arange(10.0, 100.0, 0.04)

# Call the functions
ricci = funcR(t,x,theta, phi, F, M, w)

fig=plt.figure(figsize=(8, 4))
ax=fig.add_axes([0,2,1.0,1.0])
ax.set_title("Ricci scalar")
ax.legend(loc="lower right")
ax.plot(x,ricci, label="Ricci scalar")
# Out:
# (t, r, theta, phi, F, M, v, w)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dc/zdmw2pxd67q028v5bf412_pc0000gn/T/ipykernel_87680/2790900691.py in <module>
#      16
#      17 # Call the functions
# ---> 18 ricci = funcR(t,x,theta, phi, F, M, w)
#      19
#      20 fig=plt.figure(figsize=(8, 4))
#
# TypeError: _lambdifygenerated() missing 1 required positional argument: 'w'

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!

# %%
weyl[0,1,0,1]

# %%
weyl[0,2,0,2]

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

t = 1

theta = 1
phi = 1
F = 0.1
M = 1
w = 10



#Make x values - which we will sub in for r 
x = np.arange(4, 20.0, 0.04)

# Call the functions
y = func(t,x,theta, phi, F, M, w)[0][1][0][1]/x
z = -func(t,x,theta, phi, F, M, w)[0][2][0][2]/(x*x) # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("Weyl tensor")
