# %% [markdown]
# # Longitudinal Wave Metric Search - Birkoff
# ## Metric is always Schwarschild - with varying mass at different radius
# So the mass inside R is what matters.
#
# Frequency drops with radius, constant velocity v, taken as perhaps .

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
import einsteinpy

from sympy import symbols, sin, cos, sinh, ln, lambdify
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()
print(einsteinpy.__version__)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 0.4.0

# %% [markdown]
# # sin wave outgoing

# %%
t, r, theta, phi = sympy.symbols("t r theta phi")
G, M, F, a, w, v = sympy.symbols("G M F a w, v")

# standing wave solutions are the easiest (for me) to imagine and model mathematically
# a_out is outgoing energy, so for a given time the mass will look bigger the farther out you are, as mass leaving has not yet passed you by



a_in = M + M*F*(t - r/v) + M*F/w*sin(w*(t/r**2 - r/(v*r**2)))
a_out = M - M*F*(t - r/v) + M*F/w*sin(w*(t/r**2 + r/(v*r**2)))
#a = M*(1 - F*2*sin(w*t))

a = 1/2*(a_in + a_out)

#slope of mass loss for a_out is never lower than 0, which is what we need.
mT = sympy.diff(a_out, t)
print(mT)
mR = sympy.diff(a, r)
print(mR)


# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]

#take your pick
#list2d[0][0] = -mT*mT/(mR*mR)/(1 - 2*a/r)
#list2d[0][0] = mT/mR/(1 - 2*a/r)


list2d[0][0] = (1 - 2*a/r)

list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - 2*a/r) 
list2d[2][2] = (r)**2
list2d[3][3] = (r)**2*(sympy.sin(theta) ** 2)

list2d[0][0] = list2d[0][0].simplify()
list2d[1][1] = list2d[1][1].simplify()


sch = MetricTensor(list2d, [t, r, theta, phi])
sch.tensor()
# Out:
# -F*M + F*M*cos(w*(1/(r*v) + t/r**2))/r**2
# 0.5*F*M*(-1/(r**2*v) - 2*t/r**3)*cos(w*(1/(r*v) + t/r**2)) + 0.5*F*M*(1/(r**2*v) - 2*t/r**3)*cos(w*(-1/(r*v) + t/r**2))
# ⎡             ⎛t⋅w⎞    ⎛ w ⎞                                                                               ⎤
# ⎢  2.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟                                                                               ⎥
# ⎢             ⎜  2⎟    ⎝r⋅v⎠                                                                               ⎥
# ⎢             ⎝ r ⎠            2.0⋅M                                                                       ⎥
# ⎢- ───────────────────────── - ───── + 1.0                         0                         0       0     ⎥
# ⎢             r⋅w                r                                                                         ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                 r⋅w                                      ⎥
# ⎢                    0                      ───────────────────────────────────────────────  0       0     ⎥
# ⎢                                                        ⎛t⋅w⎞    ⎛ w ⎞                                    ⎥
# ⎢                                           - 2.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ - 2.0⋅M⋅w + 1.0⋅r⋅w                ⎥
# ⎢                                                        ⎜  2⎟    ⎝r⋅v⎠                                    ⎥
# ⎢                                                        ⎝ r ⎠                                             ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                                             2            ⎥
# ⎢                    0                                             0                         r       0     ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                                                 2    2   ⎥
# ⎣                    0                                             0                         0   r ⋅sin (θ)⎦

# %%
###Plot mass function
# first make the tensor into a function, printing 

mass_l = lambdify([t, r, M, F, w, v], a)

r_vals = np.arange(4.0, 80.0, 0.01)

m_vals = mass_l(1, r_vals, 1, 0.001, 100, 1)

plt.plot(r_vals, m_vals)
plt.ylabel("Mass")
plt.show()

# %% [markdown]
# #### Figure - mass as a function of R for a fixed time. Total mass as seen
#
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
#einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡          ⎛         ⎛t⋅w⎞    ⎛ w ⎞          ⎞
# ⎢          ⎜  F⋅M⋅sin⎜───⎟⋅cos⎜───⎟          ⎟ ⎛
# ⎢          ⎜         ⎜  2⎟    ⎝r⋅v⎠          ⎟ ⎜
# ⎢          ⎜         ⎝ r ⎠            M      ⎟ ⎜       3  3  2    2    3⎛t⋅w⎞    ⎛t⋅w⎞    4⎛ w ⎞         3  3  2      4⎛t⋅w⎞    4⎛ w ⎞        3  3            3⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    3⎛ w ⎞
# ⎢  8.0⋅F⋅M⋅⎜- ───────────────────── - ─ + 0.5⎟⋅⎜- 0.5⋅F ⋅M ⋅r ⋅t⋅v ⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.25⋅F ⋅M ⋅r ⋅w⋅sin ⎜───⎟⋅cos ⎜───⎟ + 1.0⋅F ⋅M ⋅r⋅t⋅v⋅w⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 1.
# ⎢          ⎝           r⋅w            r      ⎠ ⎜                        ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                         ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠
# ⎢                                              ⎝                        ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠                                   ⎝ r ⎠             ⎝ r ⎠
# ⎢- ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
#
#    3  3  2  2      4⎛t⋅w⎞    4⎛ w ⎞        2  3  2    2      2⎛t⋅w⎞    ⎛t⋅w⎞    3⎛ w ⎞         2  3  2  2    3⎛t⋅w⎞    3⎛ w ⎞        2  3        2    2⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    2⎛ w ⎞        2  3
# 0⋅F ⋅M ⋅t ⋅v ⋅w⋅sin ⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F ⋅M ⋅r ⋅t⋅v ⋅w⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F ⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 3.0⋅F ⋅M ⋅r⋅t⋅v⋅w ⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 3.0⋅F ⋅M ⋅
#                     ⎜  2⎟     ⎝r⋅v⎠                           ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                        ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠
#                     ⎝ r ⎠                                     ⎝ r ⎠    ⎝ r ⎠                                  ⎝ r ⎠                                    ⎝ r ⎠             ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2  2  2    3⎛t⋅w⎞    3⎛ w ⎞         2  2  3    2      2⎛t⋅w⎞    ⎛t⋅w⎞    3⎛ w ⎞          2  2  3  2    3⎛t⋅w⎞    3⎛ w ⎞        2  2  2      2    2⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    2⎛ w ⎞        2  2    2
# t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F ⋅M ⋅r ⋅t⋅v ⋅w⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 0.375⋅F ⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F ⋅M ⋅r ⋅t⋅v⋅w ⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F ⋅M ⋅r⋅t
#              ⎜  2⎟     ⎝r⋅v⎠                            ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                         ⎜  2⎟     ⎝r⋅v⎠                           ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠
#              ⎝ r ⎠                                      ⎝ r ⎠    ⎝ r ⎠                                   ⎝ r ⎠                                     ⎝ r ⎠             ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                          ⎛   ⎛    ⎛1   t⎞⎞      ⎛    ⎛1   t⎞⎞⎞
#                                                                                                                                          ⎜   ⎜2⋅w⋅⎜─ - ─⎟⎟      ⎜2⋅w⋅⎜─ + ─⎟⎟⎟
#   2  2    3⎛t⋅w⎞    3⎛ w ⎞          3  2    2  2    ⎛t⋅w⎞    ⎛t⋅w⎞    2⎛ w ⎞           3  2  3    2⎛t⋅w⎞    2⎛ w ⎞            3        3 ⎜   ⎜    ⎝v   r⎠⎟      ⎜    ⎝v   r⎠⎟⎟          3  2  2  3
# ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F⋅M ⋅r ⋅t⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 0.375⋅F⋅M ⋅r⋅t⋅v⋅w ⋅⎜cos⎜───────────⎟ - cos⎜───────────⎟⎟ + 3.0⋅F⋅M ⋅t ⋅v ⋅w ⋅si
#            ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                       ⎝   ⎝     r     ⎠      ⎝     r     ⎠⎠
#            ⎝ r ⎠                                    ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                  ⎛   ⎛    ⎛1   t⎞⎞      ⎛    ⎛1   t⎞⎞⎞
#                                                                                                                                  ⎜   ⎜2⋅w⋅⎜─ - ─⎟⎟      ⎜2⋅w⋅⎜─ + ─⎟⎟⎟
#  2⎛t⋅w⎞    2⎛ w ⎞          2  3    2  2    ⎛t⋅w⎞    ⎛t⋅w⎞    2⎛ w ⎞           2  3  3    2⎛t⋅w⎞    2⎛ w ⎞            2  2      3 ⎜   ⎜    ⎝v   r⎠⎟      ⎜    ⎝v   r⎠⎟⎟          2    2  2  3    2⎛t⋅w
# n ⎜───⎟⋅cos ⎜───⎟ + 1.5⋅F⋅M ⋅r ⋅t⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 0.75⋅F⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 0.375⋅F⋅M ⋅r ⋅t⋅v⋅w ⋅⎜cos⎜───────────⎟ - cos⎜───────────⎟⎟ - 3.0⋅F⋅M ⋅r⋅t ⋅v ⋅w ⋅sin ⎜───
#   ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                        ⎝   ⎝     r     ⎠      ⎝     r     ⎠⎠                           ⎜  2
#   ⎝ r ⎠                                    ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠                                                                                                  ⎝ r
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#                                                                                                                                                                 7  2 ⎛         ⎛t⋅w⎞    ⎛ w ⎞
#                                                                                                                                                                r ⋅v ⋅⎜- F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ - M⋅w +
#                                                                                                                                                                      ⎜         ⎜  2⎟    ⎝r⋅v⎠
#                                                                                                                                                                      ⎝         ⎝ r ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  2  3    ⎛t⋅w⎞    ⎛ w ⎞             4  2  4    ⎛t⋅w⎞    ⎛ w ⎞             4  4    ⎛t⋅w⎞    ⎛ w ⎞           3      4    ⎛ w ⎞    ⎛t⋅w⎞           2  2  2  4    ⎛t⋅w⎞    ⎛ w ⎞           5    2  3    ⎛
# v ⋅w ⋅cos⎜───⎟⋅cos⎜───⎟ - 0.0625⋅M⋅r ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.1875⋅M⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.75⋅M⋅r ⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.75⋅M⋅r ⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.0625⋅r ⋅t⋅v ⋅w ⋅cos⎜
#          ⎜  2⎟    ⎝r⋅v⎠                        ⎜  2⎟    ⎝r⋅v⎠                     ⎜  2⎟    ⎝r⋅v⎠                       ⎝r⋅v⎠    ⎜  2⎟                         ⎜  2⎟    ⎝r⋅v⎠                        ⎜
#          ⎝ r ⎠                                 ⎝ r ⎠                              ⎝ r ⎠                                         ⎝ r ⎠                         ⎝ r ⎠                                 ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                                                                                        ⎤
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                               ⎞        ⎥
#                                                                                                                                                               ⎟        ⎥
# t⋅w⎞    ⎛ w ⎞            5  2  4    ⎛t⋅w⎞    ⎛ w ⎞            5  4    ⎛t⋅w⎞    ⎛ w ⎞          4      4    ⎛ w ⎞    ⎛t⋅w⎞          3  2  2  4    ⎛t⋅w⎞    ⎛ w ⎞⎟    2   ⎥
# ───⎟⋅cos⎜───⎟ + 0.03125⋅r ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.03125⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.125⋅r ⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.125⋅r ⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟⎟⋅sin (θ)⎥
#   2⎟    ⎝r⋅v⎠                       ⎜  2⎟    ⎝r⋅v⎠                    ⎜  2⎟    ⎝r⋅v⎠                      ⎝r⋅v⎠    ⎜  2⎟                        ⎜  2⎟    ⎝r⋅v⎠⎟        ⎥
#  r ⎠                                ⎝ r ⎠                             ⎝ r ⎠                                        ⎝ r ⎠                        ⎝ r ⎠         ⎠        ⎥
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎥
#                                                                                                                                                                        ⎦

# %%
ri = RicciTensor.from_metric(sch)
#ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡  ⎛                                                                                                                                                                       2
# ⎢  ⎜       2    4  2  4    2⎛t⋅w⎞    2⎛ w ⎞      4  2  4 ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞    ⎛t⋅w⎞    ⎛ w ⎞          ⎛           ⎛t⋅w⎞    ⎛ w ⎞                    ⎞  ⎛       2      ⎛t⋅w⎞
# ⎢M⋅⎜- 2.0⋅F ⋅M⋅r ⋅v ⋅w ⋅cos ⎜───⎟⋅cos ⎜───⎟ - F⋅r ⋅v ⋅w ⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟⋅sin⎜───⎟⋅cos⎜───⎟ + 16.0⋅M⋅⎜1.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜0.5⋅F⋅r ⋅v⋅sin⎜───⎟⋅cos
# ⎢  ⎜                        ⎜  2⎟     ⎝r⋅v⎠              ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟    ⎜  2⎟    ⎝r⋅v⎠          ⎜           ⎜  2⎟    ⎝r⋅v⎠                    ⎟  ⎜              ⎜  2⎟
# ⎢  ⎝                        ⎝ r ⎠                        ⎝       ⎝ r ⎠                         ⎠    ⎝ r ⎠                   ⎝           ⎝ r ⎠                             ⎠  ⎝              ⎝ r ⎠
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                                                                                  2                                                   3
# ⎛ w ⎞                ⎛t⋅w⎞    ⎛ w ⎞                  ⎛t⋅w⎞    ⎛ w ⎞        2    ⎞         2   ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞  ⎛       2      ⎛t⋅w⎞    ⎛ w ⎞                ⎛t⋅w⎞    ⎛ w ⎞
# ⎜───⎟ - 0.5⋅F⋅r⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 1.0⋅F⋅t⋅v⋅w⋅cos⎜───⎟⋅cos⎜───⎟ + 0.5⋅r ⋅v⋅w⎟  + 4.0⋅r ⋅v⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜2.0⋅F⋅r ⋅v⋅sin⎜───⎟⋅cos⎜───⎟ - 2.0⋅F⋅r⋅w⋅sin⎜───⎟⋅sin⎜───⎟ +
# ⎝r⋅v⎠                ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠             ⎟             ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟  ⎜              ⎜  2⎟    ⎝r⋅v⎠                ⎜  2⎟    ⎝r⋅v⎠
#                      ⎝ r ⎠                           ⎝ r ⎠                      ⎠             ⎝       ⎝ r ⎠                         ⎠  ⎝              ⎝ r ⎠                         ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                           3
#                ⎛t⋅w⎞    ⎛ w ⎞        2    ⎞    2   ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞  ⎛       2      ⎛t⋅w⎞    ⎛ w ⎞                ⎛t⋅w⎞    ⎛ w ⎞                  ⎛t⋅w⎞    ⎛ w ⎞        2    ⎞
# 4.0⋅F⋅t⋅v⋅w⋅cos⎜───⎟⋅cos⎜───⎟ + 2.0⋅r ⋅v⋅w⎟ - r ⋅v⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜4.0⋅F⋅r ⋅v⋅sin⎜───⎟⋅cos⎜───⎟ - 4.0⋅F⋅r⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 8.0⋅F⋅t⋅v⋅w⋅cos⎜───⎟⋅cos⎜───⎟ + 4.0⋅r ⋅v⋅w⎟
#                ⎜  2⎟    ⎝r⋅v⎠             ⎟        ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟  ⎜              ⎜  2⎟    ⎝r⋅v⎠                ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠             ⎟
#                ⎝ r ⎠                      ⎠        ⎝       ⎝ r ⎠                         ⎠  ⎝              ⎝ r ⎠                         ⎝ r ⎠                           ⎝ r ⎠                      ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                               8  2  2 ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞ ⎛           ⎛t⋅w⎞    ⎛
#                                                                                                                              r ⋅v ⋅w ⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟⋅⎜2.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜─
#                                                                                                                                       ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟ ⎜           ⎜  2⎟    ⎝r
#                                                                                                                                       ⎝       ⎝ r ⎠                         ⎠ ⎝           ⎝ r ⎠
#
#
#                                                                                                                                                                           ⎛t⋅w⎞    ⎛ w ⎞
#                                                                                                                                                              0.5⋅F⋅M⋅w⋅cos⎜───⎟⋅cos⎜───⎟
#                                                                                                                                                                           ⎜  2⎟    ⎝r⋅v⎠
#                                                                                                                                                                           ⎝ r ⎠
#                                                                                                                                                 ─────────────────────────────────────────────────────
#                                                                                                                                                  3 ⎛             ⎛t⋅w⎞    ⎛ w ⎞                     ⎞
#                                                                                                                                                 r ⋅⎜- 0.5⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#                                                                                                                                                    ⎜             ⎜  2⎟    ⎝r⋅v⎠                     ⎟
#                                                                                                                                                    ⎝             ⎝ r ⎠                              ⎠
#
#
#
#
#
#
#                                                                                                                                                                           0
#
#
#
#
#
#
#
#                                                                                                                                                                           0
#
#
#
#
#          ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞ ⎛           ⎛t⋅w⎞    ⎛ w ⎞                ⎞ ⎛               ⎛t⋅w⎞    ⎛ w ⎞                  ⎛t⋅w⎞    ⎛ w ⎞        3  ⎞ ⎛       2      ⎛t⋅w⎞    ⎛ w ⎞
#  - 0.5⋅w⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟⋅⎜2.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + 2.0⋅M⋅w - r⋅w⎟⋅⎜- 2.0⋅F⋅M⋅r⋅sin⎜───⎟⋅sin⎜───⎟ + 4.0⋅F⋅M⋅t⋅v⋅cos⎜───⎟⋅cos⎜───⎟ + 1.0⋅r ⋅v⎟⋅⎜2.0⋅F⋅r ⋅v⋅sin⎜───⎟⋅cos⎜───⎟
#          ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟ ⎜           ⎜  2⎟    ⎝r⋅v⎠                ⎟ ⎜               ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠           ⎟ ⎜              ⎜  2⎟    ⎝r⋅v⎠
#          ⎝       ⎝ r ⎠                         ⎠ ⎝           ⎝ r ⎠                         ⎠ ⎝               ⎝ r ⎠                           ⎝ r ⎠                    ⎠ ⎝              ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# w ⎞                ⎞
# ──⎟ + 2.0⋅M⋅w - r⋅w⎟
# ⋅v⎠                ⎟
#                    ⎠
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                       3
#                 ⎛t⋅w⎞    ⎛ w ⎞                  ⎛t⋅w⎞    ⎛ w ⎞        2    ⎞   ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞  ⎛       4  2    ⎛t⋅w⎞    ⎛ w ⎞           3        ⎛t⋅w⎞    ⎛ w ⎞           2
#  - 2.0⋅F⋅r⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 4.0⋅F⋅t⋅v⋅w⋅cos⎜───⎟⋅cos⎜───⎟ + 2.0⋅r ⋅v⋅w⎟ - ⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜8.0⋅F⋅r ⋅v ⋅sin⎜───⎟⋅cos⎜───⎟ - 16.0⋅F⋅r ⋅v⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 40.0⋅F⋅r ⋅
#                 ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠             ⎟   ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟  ⎜               ⎜  2⎟    ⎝r⋅v⎠                    ⎜  2⎟    ⎝r⋅v⎠
#                 ⎝ r ⎠                           ⎝ r ⎠                      ⎠   ⎝       ⎝ r ⎠                         ⎠  ⎝               ⎝ r ⎠                             ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                ⎞
#    2      ⎛t⋅w⎞    ⎛ w ⎞          2  2    ⎛t⋅w⎞    ⎛ w ⎞                 2    ⎛ w ⎞    ⎛t⋅w⎞           2  2  2    ⎛t⋅w⎞    ⎛ w ⎞        4  2  ⎞⎟
# t⋅v ⋅w⋅cos⎜───⎟⋅cos⎜───⎟ - 4.0⋅F⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 16.0⋅F⋅r⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 16.0⋅F⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 8.0⋅r ⋅v ⋅w⎟⎟
#           ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠                      ⎝r⋅v⎠    ⎜  2⎟                      ⎜  2⎟    ⎝r⋅v⎠              ⎟⎟
#           ⎝ r ⎠                           ⎝ r ⎠                                        ⎝ r ⎠                      ⎝ r ⎠                       ⎠⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                                                                                                     ⎛                                              4
#                                                                                                                                                     ⎜   2   ⎛       ⎛t⋅w⎞    ⎛ w ⎞                ⎞
#                                                                                                                                                   M⋅⎜2⋅r ⋅v⋅⎜F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅
#                                                                                                                                                     ⎜       ⎜       ⎜  2⎟    ⎝r⋅v⎠                ⎟
#                                                                                                                                                     ⎝       ⎝       ⎝ r ⎠                         ⎠
#                                                                                                                                                   ───────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                                 ⎛
# ⎛        2      ⎛t⋅w⎞    ⎛ w ⎞                 ⎛t⋅w⎞    ⎛ w ⎞                  ⎛t⋅w⎞    ⎛ w ⎞         2    ⎞   ⎛           ⎛t⋅w⎞    ⎛ w ⎞                     ⎞ ⎜      2    4  2  4    2⎛t⋅w⎞    2⎛ w
# ⎜0.25⋅F⋅r ⋅v⋅sin⎜───⎟⋅cos⎜───⎟ - 0.25⋅F⋅r⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 0.5⋅F⋅t⋅v⋅w⋅cos⎜───⎟⋅cos⎜───⎟ + 0.25⋅r ⋅v⋅w⎟ - ⎜0.5⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + 0.5⋅M⋅w - 0.25⋅r⋅w⎟⋅⎜0.25⋅F ⋅M⋅r ⋅v ⋅w ⋅cos ⎜───⎟⋅cos ⎜──
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                    3
#     ⎛t⋅w⎞    ⎛ w ⎞                ⎞  ⎛       4  2    ⎛t⋅w⎞    ⎛ w ⎞          3        ⎛t⋅w⎞    ⎛ w ⎞          2    2      ⎛t⋅w⎞    ⎛ w ⎞          2  2    ⎛t⋅w⎞    ⎛ w ⎞                2    ⎛ w ⎞
# ⋅sin⎜───⎟⋅cos⎜───⎟ + M⋅w - 0.5⋅r⋅w⎟ ⋅⎜1.0⋅F⋅r ⋅v ⋅sin⎜───⎟⋅cos⎜───⎟ - 2.0⋅F⋅r ⋅v⋅w⋅sin⎜───⎟⋅sin⎜───⎟ + 5.0⋅F⋅r ⋅t⋅v ⋅w⋅cos⎜───⎟⋅cos⎜───⎟ - 0.5⋅F⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 2.0⋅F⋅r⋅t⋅v⋅w ⋅sin⎜───⎟⋅co
#     ⎜  2⎟    ⎝r⋅v⎠                ⎟  ⎜               ⎜  2⎟    ⎝r⋅v⎠                   ⎜  2⎟    ⎝r⋅v⎠                      ⎜  2⎟    ⎝r⋅v⎠                  ⎜  2⎟    ⎝r⋅v⎠                     ⎝r⋅v⎠
#     ⎝ r ⎠                         ⎠  ⎝               ⎝ r ⎠                            ⎝ r ⎠                               ⎝ r ⎠                           ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                                                                             ⎤
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                         0                                                                0                                  ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                         ⎞⎞                                                                                                                                  ⎥
#  ⎛t⋅w⎞          2  2  2    ⎛t⋅w⎞    ⎛ w ⎞        4  2  ⎞⎟⎟                                                                                                                                  ⎥
# s⎜───⎟ - 2.0⋅F⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 1.0⋅r ⋅v ⋅w⎟⎟⎟                                                                                                                                  ⎥
#  ⎜  2⎟                     ⎜  2⎟    ⎝r⋅v⎠              ⎟⎟⎟                                                                                                                                  ⎥
#  ⎝ r ⎠                     ⎝ r ⎠                       ⎠⎠⎠                                                                                                                                  ⎥
# ──────────────────────────────────────────────────────────                              0                                                                0                                  ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                                                                             ⎥
#                                                                 ⎛         ⎛t⋅w⎞    ⎛ w ⎞              ⎛t⋅w⎞    ⎛ w ⎞⎞                                                                       ⎥
#                                                             F⋅M⋅⎜2.0⋅r⋅sin⎜───⎟⋅sin⎜───⎟ - 4.0⋅t⋅v⋅cos⎜───⎟⋅cos⎜───⎟⎟                                                                       ⎥
#                                                                 ⎜         ⎜  2⎟    ⎝r⋅v⎠              ⎜  2⎟    ⎝r⋅v⎠⎟                                                                       ⎥
#                                                                 ⎝         ⎝ r ⎠                       ⎝ r ⎠         ⎠                                                                       ⎥
#                                                             ─────────────────────────────────────────────────────────                                    0                                  ⎥
#                                                                                         3                                                                                                   ⎥
#                                                                                        r ⋅v                                                                                                 ⎥
#                                                                                                                                                                                             ⎥
#                                                                                                                                ⎛         ⎛t⋅w⎞    ⎛ w ⎞              ⎛t⋅w⎞    ⎛ w ⎞⎞    2   ⎥
#                                                                                                                        1.0⋅F⋅M⋅⎜2.0⋅r⋅sin⎜───⎟⋅sin⎜───⎟ - 4.0⋅t⋅v⋅cos⎜───⎟⋅cos⎜───⎟⎟⋅sin (θ)⎥
#                                                                                                                                ⎜         ⎜  2⎟    ⎝r⋅v⎠              ⎜  2⎟    ⎝r⋅v⎠⎟        ⎥
#                                                                                                                                ⎝         ⎝ r ⎠                       ⎝ r ⎠         ⎠        ⎥
#                                                                                         0                              ─────────────────────────────────────────────────────────────────────⎥
#                                                                                                                                                          3                                  ⎥
#                                                                                                                                                         r ⋅v                                ⎦

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = einst.tensor_lambdify()
print(args) # these are the argument values 

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5
t = 1.31312
v = 1


#Make x values - which we will sub in for r 
x = np.arange(3.0, 20.0, 0.01)

# Call the functions
# note: what scale to use on these ? when is it appropriate to divide by r**2, etc? 
tt = func(t,x,theta, phi, F, M, w, v)[0][0]

tr = func(t,x,theta, phi, F, M, w, v)[0][1]/(x*x)

rr = func(t,x,theta, phi, F, M, w, v)[1][1]/(x*x)**2

hh = func(t,x,theta, phi, F, M, w, v)[2][2]/(x*x)**2

pp = func(t,x,theta, phi, F, M, w, v)[3][3]/(x*x*sin(theta)*sin(theta))**2


fig=plt.figure(figsize=(10, 5))
ax=fig.add_axes([0,2,1.0,1.0])

ax.plot(x,hh, "lightgrey",label="θθ", linewidth=6.0)
ax.plot(x,pp, "black",label="φφ", linewidth=0.5)

ax.plot(x,tt, "-b", label="tt")
ax.plot(x,rr, "-g", label="rr")
ax.plot(x,tr, "-r", label="tr")

ax.legend(loc="upper right")
ax.set_title("Einstein Tensor, G")
# Out:
# (t, r, theta, phi, F, M, v, w)
# Text(0.5, 1.0, 'Einstein Tensor, G')

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#          ⎛
#          ⎜
#          ⎜       3  3  2    2    3⎛t⋅w⎞    ⎛t⋅w⎞    4⎛ w ⎞         3  3  2      4⎛t⋅w⎞    4⎛ w ⎞        3  3            3⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    3⎛ w ⎞        3  3  2  2      4⎛t⋅w⎞    4⎛ w ⎞
# -8.0⋅F⋅M⋅⎜- 0.5⋅F ⋅M ⋅r ⋅t⋅v ⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.25⋅F ⋅M ⋅r ⋅w⋅sin ⎜───⎟⋅cos ⎜───⎟ + 1.0⋅F ⋅M ⋅r⋅t⋅v⋅w⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 1.0⋅F ⋅M ⋅t ⋅v ⋅w⋅sin ⎜───⎟⋅cos ⎜───⎟ -
#          ⎜                        ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                         ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠                         ⎜  2⎟     ⎝r⋅v⎠
#          ⎝                        ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠                                   ⎝ r ⎠             ⎝ r ⎠                                   ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#      2  3  2    2      2⎛t⋅w⎞    ⎛t⋅w⎞    3⎛ w ⎞         2  3  2  2    3⎛t⋅w⎞    3⎛ w ⎞        2  3        2    2⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    2⎛ w ⎞        2  3  2  2  2    3⎛t⋅w⎞    3⎛ w ⎞         2
# 1.5⋅F ⋅M ⋅r ⋅t⋅v ⋅w⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F ⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 3.0⋅F ⋅M ⋅r⋅t⋅v⋅w ⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 3.0⋅F ⋅M ⋅t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F
#                         ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                        ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟     ⎝r⋅v⎠
#                         ⎝ r ⎠    ⎝ r ⎠                                  ⎝ r ⎠                                    ⎝ r ⎠             ⎝ r ⎠                                    ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#   2  3    2      2⎛t⋅w⎞    ⎛t⋅w⎞    3⎛ w ⎞          2  2  3  2    3⎛t⋅w⎞    3⎛ w ⎞        2  2  2      2    2⎛t⋅w⎞    ⎛ w ⎞    ⎛t⋅w⎞    2⎛ w ⎞        2  2    2  2  2    3⎛t⋅w⎞    3⎛ w ⎞          3
# ⋅M ⋅r ⋅t⋅v ⋅w⋅sin ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 0.375⋅F ⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F ⋅M ⋅r ⋅t⋅v⋅w ⋅sin ⎜───⎟⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F ⋅M ⋅r⋅t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 1.5⋅F⋅M ⋅
#                   ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                         ⎜  2⎟     ⎝r⋅v⎠                           ⎜  2⎟    ⎝r⋅v⎠    ⎜  2⎟     ⎝r⋅v⎠                            ⎜  2⎟     ⎝r⋅v⎠
#                   ⎝ r ⎠    ⎝ r ⎠                                   ⎝ r ⎠                                     ⎝ r ⎠             ⎝ r ⎠                                      ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                    ⎛   ⎛    ⎛1   t⎞⎞      ⎛    ⎛1   t⎞⎞⎞
#                                                                                                    ⎜   ⎜2⋅w⋅⎜─ - ─⎟⎟      ⎜2⋅w⋅⎜─ + ─⎟⎟⎟
#  2    2  2    ⎛t⋅w⎞    ⎛t⋅w⎞    2⎛ w ⎞           3  2  3    2⎛t⋅w⎞    2⎛ w ⎞            3        3 ⎜   ⎜    ⎝v   r⎠⎟      ⎜    ⎝v   r⎠⎟⎟          3  2  2  3    2⎛t⋅w⎞    2⎛ w ⎞          2  3    2
# r ⋅t⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ + 0.75⋅F⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 0.375⋅F⋅M ⋅r⋅t⋅v⋅w ⋅⎜cos⎜───────────⎟ - cos⎜───────────⎟⎟ + 3.0⋅F⋅M ⋅t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 1.5⋅F⋅M ⋅r ⋅t⋅v ⋅w
#               ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                       ⎝   ⎝     r     ⎠      ⎝     r     ⎠⎠                         ⎜  2⎟     ⎝r⋅v⎠
#               ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠                                                                                               ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                            ⎛   ⎛    ⎛1   t⎞⎞      ⎛    ⎛1   t⎞⎞⎞
#                                                                                            ⎜   ⎜2⋅w⋅⎜─ - ─⎟⎟      ⎜2⋅w⋅⎜─ + ─⎟⎟⎟
# 2    ⎛t⋅w⎞    ⎛t⋅w⎞    2⎛ w ⎞           2  3  3    2⎛t⋅w⎞    2⎛ w ⎞            2  2      3 ⎜   ⎜    ⎝v   r⎠⎟      ⎜    ⎝v   r⎠⎟⎟          2    2  2  3    2⎛t⋅w⎞    2⎛ w ⎞              4    2  2
#  ⋅sin⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 0.75⋅F⋅M ⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 0.375⋅F⋅M ⋅r ⋅t⋅v⋅w ⋅⎜cos⎜───────────⎟ - cos⎜───────────⎟⎟ - 3.0⋅F⋅M ⋅r⋅t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 0.375⋅F⋅M⋅r ⋅t⋅v ⋅w ⋅sin
#      ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                       ⎜  2⎟     ⎝r⋅v⎠                        ⎝   ⎝     r     ⎠      ⎝     r     ⎠⎠                           ⎜  2⎟     ⎝r⋅v⎠
#      ⎝ r ⎠    ⎝ r ⎠                                 ⎝ r ⎠                                                                                                  ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                                                              3
#                                                                                                                                          7  2 ⎛           ⎛t⋅w⎞    ⎛ w ⎞                    ⎞
#                                                                                                                                         r ⋅v ⋅⎜1.0⋅F⋅M⋅sin⎜───⎟⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟
#                                                                                                                                               ⎜           ⎜  2⎟    ⎝r⋅v⎠                    ⎟
#                                                                                                                                               ⎝           ⎝ r ⎠                             ⎠
#
#                                                                                                                                                                            ⎛   ⎛    ⎛1   t⎞⎞      ⎛
#                                                                                                                                                                            ⎜   ⎜2⋅w⋅⎜─ - ─⎟⎟      ⎜2⋅
# ⎛t⋅w⎞    ⎛t⋅w⎞    2⎛ w ⎞               4  2  3    2⎛t⋅w⎞    2⎛ w ⎞              4  2  3    2⎛t⋅w⎞    2⎛ w ⎞               4  3    2⎛t⋅w⎞    2⎛ w ⎞                3      3 ⎜   ⎜    ⎝v   r⎠⎟      ⎜
# ⎜───⎟⋅cos⎜───⎟⋅cos ⎜───⎟ - 0.0625⋅F⋅M⋅r ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 0.125⋅F⋅M⋅r ⋅v ⋅w ⋅cos ⎜───⎟⋅cos ⎜───⎟ + 0.1875⋅F⋅M⋅r ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ + 0.09375⋅F⋅M⋅r ⋅t⋅v⋅w ⋅⎜cos⎜───────────⎟ - cos⎜──
# ⎜  2⎟    ⎜  2⎟     ⎝r⋅v⎠                           ⎜  2⎟     ⎝r⋅v⎠                          ⎜  2⎟     ⎝r⋅v⎠                        ⎜  2⎟     ⎝r⋅v⎠                         ⎝   ⎝     r     ⎠      ⎝
# ⎝ r ⎠    ⎝ r ⎠                                     ⎝ r ⎠                                    ⎝ r ⎠                                  ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#   ⎛1   t⎞⎞⎞
# w⋅⎜─ + ─⎟⎟⎟
#   ⎝v   r⎠⎟⎟             2  2  2  3    2⎛t⋅w⎞    2⎛ w ⎞        3  2    2  3    ⎛t⋅w⎞    ⎛ w ⎞         3  2  4    ⎛t⋅w⎞    ⎛ w ⎞        3        4    ⎛ w ⎞    ⎛t⋅w⎞        3  2  2  4    ⎛t⋅w⎞    ⎛ w
# ─────────⎟⎟ + 0.75⋅F⋅M⋅r ⋅t ⋅v ⋅w ⋅sin ⎜───⎟⋅cos ⎜───⎟ - 0.5⋅M ⋅r ⋅t⋅v ⋅w ⋅cos⎜───⎟⋅cos⎜───⎟ + 0.25⋅M ⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 1.0⋅M ⋅r⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 1.0⋅M ⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───
#    r     ⎠⎠                            ⎜  2⎟     ⎝r⋅v⎠                        ⎜  2⎟    ⎝r⋅v⎠                    ⎜  2⎟    ⎝r⋅v⎠                      ⎝r⋅v⎠    ⎜  2⎟                      ⎜  2⎟    ⎝r⋅v
#                                        ⎝ r ⎠                                  ⎝ r ⎠                             ⎝ r ⎠                                        ⎝ r ⎠                      ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ⎞         2  3    2  3    ⎛t⋅w⎞    ⎛ w ⎞          2  3  4    ⎛t⋅w⎞    ⎛ w ⎞        2  2      4    ⎛ w ⎞    ⎛t⋅w⎞        2    2  2  4    ⎛t⋅w⎞    ⎛ w ⎞            4    2  3    ⎛t⋅w⎞    ⎛ w ⎞
# ⎟ + 0.75⋅M ⋅r ⋅t⋅v ⋅w ⋅cos⎜───⎟⋅cos⎜───⎟ - 0.375⋅M ⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 1.5⋅M ⋅r ⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 1.5⋅M ⋅r⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.375⋅M⋅r ⋅t⋅v ⋅w ⋅cos⎜───⎟⋅cos⎜───⎟ - 0.062
# ⎠                         ⎜  2⎟    ⎝r⋅v⎠                     ⎜  2⎟    ⎝r⋅v⎠                       ⎝r⋅v⎠    ⎜  2⎟                        ⎜  2⎟    ⎝r⋅v⎠                         ⎜  2⎟    ⎝r⋅v⎠
#                           ⎝ r ⎠                              ⎝ r ⎠                                         ⎝ r ⎠                        ⎝ r ⎠                                  ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#      4  2  4    ⎛t⋅w⎞    ⎛ w ⎞             4  4    ⎛t⋅w⎞    ⎛ w ⎞           3      4    ⎛ w ⎞    ⎛t⋅w⎞           2  2  2  4    ⎛t⋅w⎞    ⎛ w ⎞           5    2  3    ⎛t⋅w⎞    ⎛ w ⎞            5  2
# 5⋅M⋅r ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.1875⋅M⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.75⋅M⋅r ⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.75⋅M⋅r ⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ + 0.0625⋅r ⋅t⋅v ⋅w ⋅cos⎜───⎟⋅cos⎜───⎟ + 0.03125⋅r ⋅v ⋅w
#                 ⎜  2⎟    ⎝r⋅v⎠                     ⎜  2⎟    ⎝r⋅v⎠                       ⎝r⋅v⎠    ⎜  2⎟                         ⎜  2⎟    ⎝r⋅v⎠                        ⎜  2⎟    ⎝r⋅v⎠
#                 ⎝ r ⎠                              ⎝ r ⎠                                         ⎝ r ⎠                         ⎝ r ⎠                                 ⎝ r ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                                                                                                                                ⎞
#                                                                                                                                ⎟
# 4    ⎛t⋅w⎞    ⎛ w ⎞            5  4    ⎛t⋅w⎞    ⎛ w ⎞          4      4    ⎛ w ⎞    ⎛t⋅w⎞          3  2  2  4    ⎛t⋅w⎞    ⎛ w ⎞⎟
#  ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.03125⋅r ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.125⋅r ⋅t⋅v⋅w ⋅sin⎜───⎟⋅cos⎜───⎟ - 0.125⋅r ⋅t ⋅v ⋅w ⋅sin⎜───⎟⋅cos⎜───⎟⎟
#      ⎜  2⎟    ⎝r⋅v⎠                    ⎜  2⎟    ⎝r⋅v⎠                      ⎝r⋅v⎠    ⎜  2⎟                        ⎜  2⎟    ⎝r⋅v⎠⎟
#      ⎝ r ⎠                             ⎝ r ⎠                                        ⎝ r ⎠                        ⎝ r ⎠         ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
#plot the Ricci scalar

args, funcR = R.tensor_lambdify()
print(args) # these are the argument values 

t = 5

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5

#Make x values - which we will sub in for r 
x = np.arange(10.0, 100.0, 0.04)

# Call the functions
ricci = funcR(t,x,theta, phi, F, M, w)

fig=plt.figure(figsize=(8, 4))
ax=fig.add_axes([0,2,1.0,1.0])
ax.set_title("Ricci scalar")
ax.legend(loc="lower right")
ax.plot(x,ricci, label="Ricci scalar")
# Out:
# (t, r, theta, phi, F, M, v, w)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dc/zdmw2pxd67q028v5bf412_pc0000gn/T/ipykernel_89343/2790900691.py in <module>
#      16
#      17 # Call the functions
# ---> 18 ricci = funcR(t,x,theta, phi, F, M, w)
#      19
#      20 fig=plt.figure(figsize=(8, 4))
#
# TypeError: _lambdifygenerated() missing 1 required positional argument: 'w'

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!

# %%
weyl[0,1,0,1]

# %%
weyl[0,2,0,2]

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

t = 1

theta = 1
phi = 1
F = 0.1
M = 1
w = 10



#Make x values - which we will sub in for r 
x = np.arange(4, 20.0, 0.04)

# Call the functions
y = func(t,x,theta, phi, F, M, w)[0][1][0][1]/x
z = -func(t,x,theta, phi, F, M, w)[0][2][0][2]/(x*x) # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("Weyl tensor")
