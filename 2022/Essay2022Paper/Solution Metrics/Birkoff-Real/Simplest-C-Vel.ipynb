# %% [markdown]
# # Longitudinal Wave Metric Search - Birkoff
# ## Metric is always Schwarschild - with varying mass at different radius
# So the mass inside R is what matters.
#
# Constant frequency, constant velocity v, taken as 1 ( c==1 as well).

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np
import einsteinpy

from sympy import symbols, sin, cos, sinh, ln, lambdify
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()
print(einsteinpy.__version__)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
# 0.4.0

# %% [markdown]
# # sin wave outgoing

# %%
t, r, theta, phi = sympy.symbols("t r theta phi")
G, M, F, a, w, v = sympy.symbols("G M F a w, v")

# standing wave solutions are the easiest (for me) to imagine and model mathematically
# a_out is outgoing energy, so for a given time the mass will look bigger the farther out you are, as mass leaving has not yet passed you by



a_in = M + M*F*(t - r/v) + M*F/w*sin(w*(t - r/v))
a_out = M - M*F*(t - r/v) + M*F/w*sin(w*(t + r/v))
#a = M*(1 - F*2*sin(w*t))

a = 1/2*(a_in + a_out)

#slope of mass loss for a_out is never lower than 0, which is what we need.
mT = sympy.diff(a_out, t)
print(mT)
mR = sympy.diff(a, r)
print(mR)


# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]

#take your pick
#list2d[0][0] = -mT*mT/(mR*mR)/(1 - 2*a/r)
#list2d[0][0] = mT/mR/(1 - 2*a/r)


list2d[0][0] = (1 - 2*a/r)

list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - 2*a/r) 
list2d[2][2] = (r)**2
list2d[3][3] = (r)**2*(sympy.sin(theta) ** 2)

list2d[0][0] = list2d[0][0].simplify()
list2d[1][1] = list2d[1][1].simplify()


sch = MetricTensor(list2d, [t, r, theta, phi])
sch.tensor()
# Out:
# F*M*cos(w*(r/v + t)) - F*M
# -0.5*F*M*cos(w*(-r/v + t))/v + 0.5*F*M*cos(w*(r/v + t))/v
# ⎡                      ⎛r⋅w⎞                                                                               ⎤
# ⎢  2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟                                                                               ⎥
# ⎢                      ⎝ v ⎠   2.0⋅M                                                                       ⎥
# ⎢- ───────────────────────── - ───── + 1.0                         0                         0       0     ⎥
# ⎢             r⋅w                r                                                                         ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                 r⋅w                                      ⎥
# ⎢                    0                      ───────────────────────────────────────────────  0       0     ⎥
# ⎢                                                                 ⎛r⋅w⎞                                    ⎥
# ⎢                                           - 2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ - 2.0⋅M⋅w + 1.0⋅r⋅w                ⎥
# ⎢                                                                 ⎝ v ⎠                                    ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                                             2            ⎥
# ⎢                    0                                             0                         r       0     ⎥
# ⎢                                                                                                          ⎥
# ⎢                                                                                                 2    2   ⎥
# ⎣                    0                                             0                         0   r ⋅sin (θ)⎦

# %%
###Plot mass function
# first make the tensor into a function, printing 

mass_l = lambdify([t, r, M, F, w, v], a)

r_vals = np.arange(3.0, 80.0, 0.01)

m_vals = mass_l(1, r_vals, 1, 0.001, 2, 1)

plt.plot(r_vals, m_vals)
plt.ylabel("Mass")
plt.show()

# %% [markdown]
# #### Figure - mass as a function of R for a fixed time. Total mass as seen
#
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
#einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡
# ⎢    ⎛
# ⎢    ⎜        ⎛                    ⎛r⋅w⎞                    ⎞ ⎛     3  3    4         3⎛r⋅w⎞         2  3      3         2⎛r⋅w⎞        2  2        3         2⎛r⋅w⎞           3  2    2         ⎛r⋅w⎞
# ⎢F⋅M⋅⎜0.5⋅r⋅w⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟⋅⎜4.0⋅F ⋅M ⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F ⋅M ⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ - 6.0⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟
# ⎢    ⎝        ⎝                    ⎝ v ⎠                    ⎠ ⎝                        ⎝ v ⎠                              ⎝ v ⎠                               ⎝ v ⎠                             ⎝ v ⎠
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#
#            2    2    2         ⎛r⋅w⎞        2  2  2    2         ⎛r⋅w⎞            2  2  2    2         ⎛r⋅w⎞            2  2    2         ⎛r⋅w⎞        3  3                 2    3               2  2
#  - 12.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 2.0⋅F⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos⎜───⎟ + 3.0⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 4.0⋅M ⋅w ⋅sin(t⋅w) - 6.0⋅M ⋅r⋅w ⋅sin(t⋅w) - M⋅r ⋅v
#                                ⎝ v ⎠                             ⎝ v ⎠                                 ⎝ v ⎠                              ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   3                   2  3                 3  2  3                 3  3         ⎞    ⎛r⋅w⎞       ⎛                    ⎛r⋅w⎞                ⎞ ⎛   3  3    4         2⎛r⋅w⎞    ⎛r⋅w⎞        3  3    4
# ⋅w ⋅sin(t⋅w) + 3.0⋅M⋅r ⋅w ⋅sin(t⋅w) + 0.5⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.5⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟ + r⋅w⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 2.0⋅M⋅w - r⋅w⎟⋅⎜- F ⋅M ⋅sin (t⋅w)⋅sin ⎜───⎟⋅cos⎜───⎟ + 1.0⋅F ⋅M ⋅sin (t
#                                                                                 ⎠    ⎝ v ⎠       ⎝                    ⎝ v ⎠                ⎠ ⎝                      ⎝ v ⎠    ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                                                                3
#                                                                                                                                            2  2 ⎛                    ⎛r⋅w⎞                    ⎞  ⎛
#                                                                                                                                           r ⋅v ⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜2.0
#                                                                                                                                                 ⎝                    ⎝ v ⎠                    ⎠  ⎝
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        ⎛r⋅w⎞        2  3      3         2⎛r⋅w⎞        2  3      3             2  2        3         2⎛r⋅w⎞        2  2        3               3  2    2         ⎛r⋅w⎞          2    2    2         ⎛r
# ⋅w)⋅cos⎜───⎟ - 3.0⋅F ⋅M ⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ + 3.0⋅F ⋅M ⋅w⋅sin (t⋅w) + 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ - 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w) + 3.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 3.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜─
#        ⎝ v ⎠                             ⎝ v ⎠                                                       ⎝ v ⎠                                                      ⎝ v ⎠                              ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#                  ⎛r⋅w⎞                ⎞
# ⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 2.0⋅M⋅w - r⋅w⎟
#                  ⎝ v ⎠                ⎠
#
#
#
#                                                                                                                                                                                                 0.5⋅F
#
#                                                                                                                                                                                     ─────────────────
#                                                                                                                                                                                       ⎛
#                                                                                                                                                                                     r⋅⎜- 0.5⋅F⋅M⋅sin(
#                                                                                                                                                                                       ⎝
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ⋅w⎞             2  2  2    2         ⎛r⋅w⎞            2  2  2    ⎛r⋅w⎞             2  2    2         ⎛r⋅w⎞        3  3                 2    3                    2  2  3                    2  3
# ──⎟ + 0.25⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 0.5⋅F⋅M⋅r ⋅v ⋅w ⋅cos⎜───⎟ + 0.75⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 1.0⋅M ⋅w ⋅sin(t⋅w) - 1.5⋅M ⋅r⋅w ⋅sin(t⋅w) - 0.25⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w) + 0.75⋅M⋅r ⋅w ⋅sin(
# v ⎠                                  ⎝ v ⎠                       ⎝ v ⎠                               ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#                  ⎛r⋅w⎞
# ⋅M⋅w⋅cos(t⋅w)⋅cos⎜───⎟
#                  ⎝ v ⎠
# ───────────────────────────────────
#         ⎛r⋅w⎞                     ⎞
# t⋅w)⋅cos⎜───⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#         ⎝ v ⎠                     ⎠
#
#
#
#
#
#
#         0
#
#
#
#
#
#
#
#
#
#         0
#
#
#
#
#
#                                                                                                                                             ⎛                  ⎛r⋅w⎞          ⎞
#                                                                                                                        4                  ⎞ ⎜  F⋅M⋅sin(t⋅w)⋅cos⎜───⎟          ⎟
#               3  2  3                   3  3         ⎞    ⎛r⋅w⎞         ⎛                    ⎛r⋅w⎞                    ⎞              ⎛r⋅w⎞⎟ ⎜                  ⎝ v ⎠   M      ⎟           ⎛     3  3
# t⋅w) + 0.125⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.125⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟ + 8.0⋅v⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅sin(t⋅w)⋅sin⎜───⎟⎟⋅⎜- ───────────────────── - ─ + 0.5⎟   0.5⋅F⋅M⋅⎜4.0⋅F ⋅M ⋅
#                                                      ⎠    ⎝ v ⎠         ⎝                    ⎝ v ⎠                    ⎠              ⎝ v ⎠⎠ ⎝           r⋅w            r      ⎠           ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── + ───────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           2  2        3         2⎛r⋅w⎞        2  2        3               3  2    2         ⎛r⋅w⎞          2    2    2         ⎛r⋅w⎞             2  2  2    2         ⎛r⋅w⎞            2  2  2    ⎛r⋅
# w) + 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ - 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w) + 3.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 3.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 0.25⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 0.5⋅F⋅M⋅r ⋅v ⋅w ⋅cos⎜──
#                                  ⎝ v ⎠                                                      ⎝ v ⎠                              ⎝ v ⎠                                  ⎝ v ⎠                       ⎝ v
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# w⎞             2  2    2         ⎛r⋅w⎞        3  3                 2    3                    2  2  3                    2  3                   3  2  3                   3  3         ⎞    ⎛r⋅w⎞
# ─⎟ + 0.75⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 1.0⋅M ⋅w ⋅sin(t⋅w) - 1.5⋅M ⋅r⋅w ⋅sin(t⋅w) - 0.25⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w) + 0.75⋅M⋅r ⋅w ⋅sin(t⋅w) + 0.125⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.125⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟ + 8.
#  ⎠                               ⎝ v ⎠                                                                                                                                                ⎠    ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                                ⎤
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                    4                  ⎞        ⎥
#     ⎛                    ⎛r⋅w⎞                    ⎞              ⎛r⋅w⎞⎟    2   ⎥
# 0⋅v⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅sin(t⋅w)⋅sin⎜───⎟⎟⋅sin (θ)⎥
#     ⎝                    ⎝ v ⎠                    ⎠              ⎝ v ⎠⎠        ⎥
# ───────────────────────────────────────────────────────────────────────────────⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎥
#                                                                                ⎦

# %%
ri = RicciTensor.from_metric(sch)
#ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡        ⎛     3  3    4         3⎛r⋅w⎞         2  3      3         2⎛r⋅w⎞        2  2        3         2⎛r⋅w⎞           3  2    2         ⎛r⋅w⎞           2    2    2         ⎛r⋅w⎞        2  2  2
# ⎢0.5⋅F⋅M⋅⎜4.0⋅F ⋅M ⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F ⋅M ⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ - 6.0⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 12.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - F⋅M⋅r ⋅v ⋅w ⋅s
# ⎢        ⎝                        ⎝ v ⎠                              ⎝ v ⎠                               ⎝ v ⎠                             ⎝ v ⎠                               ⎝ v ⎠
# ⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢                                                                                                                                                                                                2  2
# ⎢                                                                                                                                                                                               r ⋅v
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                                                                                                                                             ───────
# ⎢                                                                                                                                                                                               ⎛
# ⎢                                                                                                                                                                                             r⋅⎜- 0.
# ⎢                                                                                                                                                                                               ⎝
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#   2         ⎛r⋅w⎞            2  2  2    2         ⎛r⋅w⎞            2  2    2         ⎛r⋅w⎞        3  3                 2    3               2  2  3                   2  3                 3  2  3
# in (t⋅w)⋅cos⎜───⎟ - 2.0⋅F⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos⎜───⎟ + 3.0⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 4.0⋅M ⋅w ⋅sin(t⋅w) - 6.0⋅M ⋅r⋅w ⋅sin(t⋅w) - M⋅r ⋅v ⋅w ⋅sin(t⋅w) + 3.0⋅M⋅r ⋅w ⋅sin(t⋅w) + 0.5⋅r ⋅v ⋅w ⋅si
#             ⎝ v ⎠                                 ⎝ v ⎠                              ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                           2
#  ⎛                  ⎛r⋅w⎞                ⎞
# ⋅⎜- F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ - M⋅w + 0.5⋅r⋅w⎟
#  ⎝                  ⎝ v ⎠                ⎠
#
#                            ⎛r⋅w⎞
#      0.5⋅F⋅M⋅w⋅cos(t⋅w)⋅cos⎜───⎟
#                            ⎝ v ⎠
# ─────────────────────────────────────────────
#                   ⎛r⋅w⎞                     ⎞
# 5⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#                   ⎝ v ⎠                     ⎠
#
#
#
#
#
#                   0
#
#
#
#
#
#                   0
#
#
#               3  3         ⎞    ⎛r⋅w⎞
# n(t⋅w) - 0.5⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟
#                            ⎠    ⎝ v ⎠
# ─────────────────────────────────────
#
#
#
#
#
#                                             2 ⎛       3  3    4         2⎛r⋅w⎞    ⎛r⋅w⎞        3  3    4         ⎛r⋅w⎞        2  3      3         2⎛r⋅w⎞        2  3      3              2  2
#                                        F⋅M⋅w ⋅⎜- 0.5⋅F ⋅M ⋅sin (t⋅w)⋅sin ⎜───⎟⋅cos⎜───⎟ + 0.5⋅F ⋅M ⋅sin (t⋅w)⋅cos⎜───⎟ - 1.5⋅F ⋅M ⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ + 1.5⋅F ⋅M ⋅w⋅sin (t⋅w) + 0.75⋅F ⋅M ⋅r⋅w⋅sin
#                                               ⎝                          ⎝ v ⎠    ⎝ v ⎠                          ⎝ v ⎠                             ⎝ v ⎠
#                                        ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                      ⎛r⋅w⎞
#                                                                                                0.5⋅F⋅M⋅w⋅cos(t⋅w)⋅cos⎜───⎟
#                                                                                                                      ⎝ v ⎠
#                                                                                    ────────────────────────────────────────────────────
#                                                                                      ⎛                      ⎛r⋅w⎞                     ⎞
#                                                                                    r⋅⎜- 0.5⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ - 0.5⋅M⋅w + 0.25⋅r⋅w⎟
#                                                                                      ⎝                      ⎝ v ⎠                     ⎠
#
#
# 3         2⎛r⋅w⎞         2  2        3               3  2    2         ⎛r⋅w⎞          2    2    2         ⎛r⋅w⎞              2  2  2    2         ⎛r⋅w⎞             2  2  2    ⎛r⋅w⎞              2
#  (t⋅w)⋅sin ⎜───⎟ - 0.75⋅F ⋅M ⋅r⋅w⋅sin (t⋅w) + 1.5⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 1.5⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 0.125⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 0.25⋅F⋅M⋅r ⋅v ⋅w ⋅cos⎜───⎟ + 0.375⋅F⋅M⋅r ⋅w
#            ⎝ v ⎠                                                       ⎝ v ⎠                              ⎝ v ⎠                                   ⎝ v ⎠                        ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                   4
#                                                                                        2 ⎛                  ⎛r⋅w⎞                ⎞
#                                                                                       v ⋅⎜- F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ - M⋅w + 0.5⋅r⋅w⎟
#                                                                                          ⎝                  ⎝ v ⎠                ⎠
#
#
#
#
#                                                                                                             0
#
#
#
#
#
#                                                                                                             0
#
#
#
#
#
#                                                                                                                                                                                                   0
#
#
#
#
#
# 2    2         ⎛r⋅w⎞        3  3                  2    3                     2  2  3                     2  3                    3  2  3                    3  3         ⎞    ⎛r⋅w⎞
#  ⋅sin (t⋅w)⋅cos⎜───⎟ + 0.5⋅M ⋅w ⋅sin(t⋅w) - 0.75⋅M ⋅r⋅w ⋅sin(t⋅w) - 0.125⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w) + 0.375⋅M⋅r ⋅w ⋅sin(t⋅w) + 0.0625⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.0625⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟
#                ⎝ v ⎠                                                                                                                                                     ⎠    ⎝ v ⎠
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────               0
#
#
#
#
#
#
#                                                                                                                                                                                      -2.0⋅F⋅M⋅sin(t⋅w
#
#                                                                                                                                                                                      ────────────────
#                                                                                                                                                                                                   v
#
#
#
#
#                                                                                                                                                                                                   0
#
#
#                                                 ⎤
#                                                 ⎥
#                                                 ⎥
#                               0                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                               0                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#                                                 ⎥
#      ⎛r⋅w⎞                                      ⎥
# )⋅sin⎜───⎟                                      ⎥
#      ⎝ v ⎠                                      ⎥
# ───────────                   0                 ⎥
#                                                 ⎥
#                                                 ⎥
#                          2                ⎛r⋅w⎞ ⎥
#              -2.0⋅F⋅M⋅sin (θ)⋅sin(t⋅w)⋅sin⎜───⎟ ⎥
#                                           ⎝ v ⎠ ⎥
#              ───────────────────────────────────⎥
#                               v                 ⎦

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = einst.tensor_lambdify()
print(args) # these are the argument values 

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5
t = 1.31312
v = 1


#Make x values - which we will sub in for r 
x = np.arange(3.0, 20.0, 0.01)

# Call the functions
# note: what scale to use on these ? when is it appropriate to divide by r**2, etc? 
tt = func(t,x,theta, phi, F, M, w, v)[0][0]

tr = func(t,x,theta, phi, F, M, w, v)[0][1]/(x*x)

rr = func(t,x,theta, phi, F, M, w, v)[1][1]/(x*x)**2

hh = func(t,x,theta, phi, F, M, w, v)[2][2]/(x*x)**2

pp = func(t,x,theta, phi, F, M, w, v)[3][3]/(x*x*sin(theta)*sin(theta))**2


fig=plt.figure(figsize=(10, 5))
ax=fig.add_axes([0,2,1.0,1.0])

ax.plot(x,hh, "lightgrey",label="θθ", linewidth=6.0)
ax.plot(x,pp, "black",label="φφ", linewidth=0.5)

ax.plot(x,tt, "-b", label="tt")
ax.plot(x,rr, "-g", label="rr")
ax.plot(x,tr, "-r", label="tr")

ax.legend(loc="upper right")
ax.set_title("Einstein Tensor, G")
# Out:
# (t, r, theta, phi, F, M, v, w)
# Text(0.5, 1.0, 'Einstein Tensor, G')

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#      ⎛
#      ⎜        ⎛                    ⎛r⋅w⎞                    ⎞ ⎛     3  3    4         3⎛r⋅w⎞         2  3      3         2⎛r⋅w⎞        2  2        3         2⎛r⋅w⎞           3  2    2         ⎛r⋅w⎞
# -F⋅M⋅⎜0.5⋅r⋅w⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟⋅⎜4.0⋅F ⋅M ⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F ⋅M ⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ - 6.0⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅cos ⎜───⎟ + 12.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟
#      ⎝        ⎝                    ⎝ v ⎠                    ⎠ ⎝                        ⎝ v ⎠                              ⎝ v ⎠                               ⎝ v ⎠                             ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#            2    2    2         ⎛r⋅w⎞        2  2  2    2         ⎛r⋅w⎞            2  2  2    2         ⎛r⋅w⎞            2  2    2         ⎛r⋅w⎞        3  3                 2    3               2  2
#  - 12.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 2.0⋅F⋅M⋅r ⋅v ⋅w ⋅cos (t⋅w)⋅cos⎜───⎟ + 3.0⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 4.0⋅M ⋅w ⋅sin(t⋅w) - 6.0⋅M ⋅r⋅w ⋅sin(t⋅w) - M⋅r ⋅v
#                                ⎝ v ⎠                             ⎝ v ⎠                                 ⎝ v ⎠                              ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#   3                   2  3                 3  2  3                 3  3         ⎞    ⎛r⋅w⎞       ⎛                    ⎛r⋅w⎞                ⎞ ⎛   3  3    4         2⎛r⋅w⎞    ⎛r⋅w⎞        3  3    4
# ⋅w ⋅sin(t⋅w) + 3.0⋅M⋅r ⋅w ⋅sin(t⋅w) + 0.5⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.5⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟ + r⋅w⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 2.0⋅M⋅w - r⋅w⎟⋅⎜- F ⋅M ⋅sin (t⋅w)⋅sin ⎜───⎟⋅cos⎜───⎟ + 1.0⋅F ⋅M ⋅sin (t
#                                                                                 ⎠    ⎝ v ⎠       ⎝                    ⎝ v ⎠                ⎠ ⎝                      ⎝ v ⎠    ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                                              3
#                                                                                                                          2  2 ⎛                    ⎛r⋅w⎞                    ⎞  ⎛                    ⎛
#                                                                                                                         r ⋅v ⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅⎜2.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜
#                                                                                                                               ⎝                    ⎝ v ⎠                    ⎠  ⎝                    ⎝
#
#
#        ⎛r⋅w⎞        2  3      3         2⎛r⋅w⎞        2  3      3             2  2        3         2⎛r⋅w⎞        2  2        3               3  2    2         ⎛r⋅w⎞          2    2    2         ⎛r
# ⋅w)⋅cos⎜───⎟ - 3.0⋅F ⋅M ⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ + 3.0⋅F ⋅M ⋅w⋅sin (t⋅w) + 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w)⋅sin ⎜───⎟ - 1.5⋅F ⋅M ⋅r⋅w⋅sin (t⋅w) + 3.0⋅F⋅M ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 3.0⋅F⋅M ⋅r⋅w ⋅sin (t⋅w)⋅cos⎜─
#        ⎝ v ⎠                             ⎝ v ⎠                                                       ⎝ v ⎠                                                      ⎝ v ⎠                              ⎝
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
# r⋅w⎞                ⎞
# ───⎟ + 2.0⋅M⋅w - r⋅w⎟
#  v ⎠                ⎠
#
#
# ⋅w⎞             2  2  2    2         ⎛r⋅w⎞            2  2  2    ⎛r⋅w⎞             2  2    2         ⎛r⋅w⎞        3  3                 2    3                    2  2  3                    2  3
# ──⎟ + 0.25⋅F⋅M⋅r ⋅v ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ - 0.5⋅F⋅M⋅r ⋅v ⋅w ⋅cos⎜───⎟ + 0.75⋅F⋅M⋅r ⋅w ⋅sin (t⋅w)⋅cos⎜───⎟ + 1.0⋅M ⋅w ⋅sin(t⋅w) - 1.5⋅M ⋅r⋅w ⋅sin(t⋅w) - 0.25⋅M⋅r ⋅v ⋅w ⋅sin(t⋅w) + 0.75⋅M⋅r ⋅w ⋅sin(
# v ⎠                                  ⎝ v ⎠                       ⎝ v ⎠                               ⎝ v ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#                                                                                                                        4                  ⎞
#               3  2  3                   3  3         ⎞    ⎛r⋅w⎞         ⎛                    ⎛r⋅w⎞                    ⎞              ⎛r⋅w⎞⎟
# t⋅w) + 0.125⋅r ⋅v ⋅w ⋅sin(t⋅w) - 0.125⋅r ⋅w ⋅sin(t⋅w)⎟⋅cos⎜───⎟ + 8.0⋅v⋅⎜1.0⋅F⋅M⋅sin(t⋅w)⋅cos⎜───⎟ + 1.0⋅M⋅w - 0.5⋅r⋅w⎟ ⋅sin(t⋅w)⋅sin⎜───⎟⎟
#                                                      ⎠    ⎝ v ⎠         ⎝                    ⎝ v ⎠                    ⎠              ⎝ v ⎠⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
#plot the Ricci scalar

args, funcR = R.tensor_lambdify()
print(args) # these are the argument values 

t = 5

theta = 1
phi = 1
F = 0.01
M = 1
w = 0.5

#Make x values - which we will sub in for r 
x = np.arange(10.0, 100.0, 0.04)

# Call the functions
ricci = funcR(t,x,theta, phi, F, M, w)

fig=plt.figure(figsize=(8, 4))
ax=fig.add_axes([0,2,1.0,1.0])
ax.set_title("Ricci scalar")
ax.legend(loc="lower right")
ax.plot(x,ricci, label="Ricci scalar")
# Out:
# (t, r, theta, phi, F, M, v, w)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dc/zdmw2pxd67q028v5bf412_pc0000gn/T/ipykernel_85641/2790900691.py in <module>
#      16
#      17 # Call the functions
# ---> 18 ricci = funcR(t,x,theta, phi, F, M, w)
#      19
#      20 fig=plt.figure(figsize=(8, 4))
#
# TypeError: _lambdifygenerated() missing 1 required positional argument: 'w'

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!

# %%
weyl[0,1,0,1]

# %%
weyl[0,2,0,2]

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

t = 1

theta = 1
phi = 1
F = 0.1
M = 1
w = 10



#Make x values - which we will sub in for r 
x = np.arange(4, 20.0, 0.04)

# Call the functions
y = func(t,x,theta, phi, F, M, w)[0][1][0][1]/x
z = -func(t,x,theta, phi, F, M, w)[0][2][0][2]/(x*x) # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("Weyl tensor")
