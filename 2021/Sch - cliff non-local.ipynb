# %% [markdown]
# # Schwarshild coordinates Einstein Tensor calculations using Symbolic module

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np

from sympy import symbols, sin, cos, sinh
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()

# %% [markdown]
# ### Use plain coordinates.

# %% [markdown]
# ![alt-text](img/schwarschild.png "Schwarschild coords")

# %%
syms = sympy.symbols("t r theta phi")
G, M, c, a, w, k = sympy.symbols("G M c a w k")
# time vary the mass
a = 2*M*(sin(w*syms[0] - k*syms[1])**2)

#a = 2*M
# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]
list2d[0][0] = -(1 - a/syms[1])
list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - a/syms[1]) 
list2d[2][2] = (syms[1])**2
list2d[3][3] = (syms[1])**2*(sympy.sin(syms[2]) ** 2)
sch = MetricTensor(list2d, syms)
sch.tensor()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The MathtextBackendBitmap class was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# ⎡       2                                                          ⎤
# ⎢2⋅M⋅sin (k⋅r - t⋅w)                                               ⎥
# ⎢─────────────────── - 1              0              0       0     ⎥
# ⎢         r                                                        ⎥
# ⎢                                                                  ⎥
# ⎢                                     1                            ⎥
# ⎢           0             ─────────────────────────  0       0     ⎥
# ⎢                                  2                               ⎥
# ⎢                           2⋅M⋅sin (k⋅r - t⋅w)                    ⎥
# ⎢                         - ─────────────────── + 1                ⎥
# ⎢                                    r                             ⎥
# ⎢                                                                  ⎥
# ⎢                                                     2            ⎥
# ⎢           0                         0              r       0     ⎥
# ⎢                                                                  ⎥
# ⎢                                                         2    2   ⎥
# ⎣           0                         0              0   r ⋅sin (θ)⎦

# %% [markdown]
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡  ⎛                                ⎛                                 3                                                                                4
# ⎢  ⎜⎛         2                   ⎞ ⎜        ⎛       2               ⎞                                                        ⎛       2               ⎞
# ⎢M⋅⎝⎝1.0⋅M⋅sin (k⋅r - t⋅w) - 0.5⋅r⎠⋅⎝- 8⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) + 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅
# ⎢─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                                                                                   ⎛
#                                                                                   ⎜      4  2    2               2                 4  2 ⎛       2
# r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1) + 2⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝16⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 2⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) -
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                     3
#   ⎞                        ⎛       2               ⎞  ⎛   2  2                                                  2           ⎞
#  r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                      ⎞                                  ⎛
# 3                                                    ⎟                                  ⎜      4  2    2               2                  ⎛       2
#  ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M⋅sin (k⋅r - t⋅w)
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      2                                                                                                                                                2
#     ⎞                                         2    2                 4  2 ⎛       2               ⎞                          ⎛       2               ⎞
#  - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅M⋅k
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                       3
#                                                            4 ⎛       2               ⎞
#                                                         2⋅r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#
#
#                                                                           -2⋅M⋅w⋅sin(2⋅k⋅r - 2⋅t⋅w)
#                                                                        ────────────────────────────────
#                                                                        r⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#
#
#
#
#
#                                                                                       0
#
#
#
#
#
#
#
#                                                                                       0
#
#
#
#
#                                                                                                              3
#                                                                                     ⎛       2               ⎞  ⎛   2  2
# ⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                               ⎞⎞                              4
#            2           ⎞                                 3                                                    ⎟⎟     ⎛       2               ⎞
# ⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎠ + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                      ⎛
#                                                                             ⎛       2               ⎞                                ⎜       4  2    2
#  - t⋅w) - sin(k⋅r - t⋅w))⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝- 8⋅M⋅r ⋅w ⋅sin (k⋅r - t
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                     3
#        2               4  2 ⎛       2               ⎞                      ⎛       2               ⎞  ⎛ 2  2
# ⋅w)⋅cos (k⋅r - t⋅w) + r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + ⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) - k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + sin
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#              ⎞⎞
# 2           ⎞⎟⎟
#  (k⋅r - t⋅w)⎠⎠⎠
# ───────────────
#
#
#
#
#                    ⎛                                 3                                                                                  4
#                    ⎜        ⎛       2               ⎞                                                          ⎛       2               ⎞
#                  M⋅⎝4.0⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) + 1.0⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2
#                  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#                                                                 ⎞                                       ⎛
#            3                                                    ⎟                                       ⎜      4  2    2               2                  ⎛
# w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠ + 0.25⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                       3
#              ⎛       2               ⎞
#            r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                      2
#     2               ⎞                                         2    2                 4  2 ⎛       2               ⎞                          ⎛       2
# ⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         2                                                                                                                    3
#        ⎞                                                                                            ⎛       2               ⎞  ⎛   2  2
# ⋅w) - r⎠ ⋅(2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                                                         ⎤
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                               ⎞⎞        ⎥
#                            2           ⎞                                 3                                                    ⎟⎟    2   ⎥
# ⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎠⋅sin (θ)⎥
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎥
#                                                                                                                                         ⎦

# %%
ri = RicciTensor.from_metric(sch)
ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡    ⎛                                                                                                                            3
# ⎢    ⎜       4  2    2               2               4  2 ⎛       2               ⎞                      ⎛       2               ⎞  ⎛ 2  2
# ⎢2⋅M⋅⎜- 8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) + r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + ⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w)
# ⎢    ⎝
# ⎢─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢                                                                                                                                                            2
# ⎢                                                                                                                                 4 ⎛       2               ⎞
# ⎢                                                                                                                                r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠
# ⎢
# ⎢
# ⎢
# ⎢                                                                                                                                  -2⋅M⋅w⋅sin(2⋅k⋅r - 2⋅t⋅w)
# ⎢                                                                                                                               ──────────────────────────────
# ⎢                                                                                                                               r⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M +
# ⎢
# ⎢
# ⎢
# ⎢                                                                                                                                              0
# ⎢
# ⎢
# ⎣                                                                                                                                              0
#
#                                                                                                                                 ⎞
#                               2           ⎞                                 3 ⎛                          cos(2⋅k⋅r - 2⋅t⋅w)   1⎞⎟
# - k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅⎜-k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - ────────────────── + ─⎟⎟
#                                                                               ⎝                                  2            2⎠⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                                                      ⎛
#                                                                                                                                      ⎜  ⎛       2
#                                                                                                                                    M⋅⎝2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) -
# ──                                                                                                                                 ───────────────────────────
# r)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    4                                                                                      ⎛
#   ⎞                                                                                       ⎜      4  2    2               2                  ⎛       2
#  r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1) + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M⋅sin (k⋅r - t⋅
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                              -2⋅M⋅w⋅sin(2⋅k⋅r - 2⋅t⋅w)
#                                                                                                           ────────────────────────────────
#                                                                                                           r⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#
#
#        2                                                                                                                                                2
#       ⎞                                         2    2                 4  2 ⎛       2               ⎞                          ⎛       2               ⎞
# w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅M
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                           4
#                                                                                                2 ⎛       2               ⎞
#                                                                                             2⋅r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#                                                                                                                           0
#
#
#                                                                                                                           0
#
#
#
#
#
#
#
#
#
#
#                                                                                                                3
#                                                                                       ⎛       2               ⎞  ⎛   2  2
# ⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r -
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                                                                0
#
#
#
#
#                                                                                                                 ⎞⎞
#              2           ⎞                                 3                                                    ⎟⎟
#  2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎠
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────             0
#
#
#
#
#                                                                                                                     2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w)
#
#                                                                                                                                                        2
#                                                                                                                                0              4⋅M⋅k⋅sin (θ)⋅si
#
#                            ⎤
#                            ⎥
#                            ⎥
#                            ⎥
#      0                     ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#      0                     ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#                            ⎥
#      0                     ⎥
#                            ⎥
#                            ⎥
# n(k⋅r - t⋅w)⋅cos(k⋅r - t⋅w)⎦

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#   ⎛                               3                                                                                4
#   ⎜      ⎛       2               ⎞                                                        ⎛       2               ⎞
# M⋅⎝8⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                               ⎛
#                                               ⎜      4  2    2               2                 4  2 ⎛       2               ⎞                        ⎛       2
# ⋅t⋅w) - 1) - 2⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝16⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 2⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅⎝2⋅M⋅sin
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                 3
#                ⎞  ⎛   2  2                                                  2           ⎞                                 3
# (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                  ⎞                                  ⎛                                                                          2
#                  ⎟                                  ⎜      4  2    2               2                  ⎛       2               ⎞
# k⋅r - 2⋅t⋅w) - 1)⎠ - (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                      3
#           3 ⎛       2               ⎞
#        2⋅r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#                                                                                                                   2
#           2    2                 4  2 ⎛       2               ⎞                          ⎛       2               ⎞
# ⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                          3
#                                                 ⎛       2               ⎞  ⎛   2  2                                                  2           ⎞
# k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                           ⎞⎞
#                      3                                                    ⎟⎟
# k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎠
# ────────────────────────────────────────────────────────────────────────────

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢             ⎡
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢  ⎛                                 3                                                                                4
# ⎢             ⎢  ⎜        ⎛       2               ⎞                                                        ⎛       2               ⎞
# ⎢             ⎢M⋅⎜- 4⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w
# ⎢             ⎢  ⎝
# ⎢             ⎢───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎢
# ⎢             ⎣
# ⎢
# ⎢                                                         ⎡
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢  ⎛                               3
# ⎢                                                         ⎢  ⎜      ⎛       2               ⎞                                                        ⎛       2
# ⎢                                                         ⎢M⋅⎜8⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin
# ⎢                                                         ⎢  ⎝
# ⎢                                                         ⎢───────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎢
# ⎢                                                         ⎣
# ⎢
# ⎢⎡
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢  ⎛                               3                                                                                4
# ⎢⎢  ⎜      ⎛       2               ⎞                                                        ⎛       2               ⎞
# ⎢⎢M⋅⎜8⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r -
# ⎢⎢  ⎝
# ⎢⎢────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢⎢
# ⎢⎢
# ⎣⎣
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                ⎛
#                                                                ⎜       4  2    2               2               4  2 ⎛       2               ⎞
# ) + cos(2⋅k⋅r - 2⋅t⋅w) - 1) + 6⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎜- 8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) + r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅
#                                                                ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 4                                                                                   3
#                ⎞                                                           ⎛       2               ⎞                                    2
# (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1) - 12⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin (k⋅r - t⋅w) + 12⋅(M⋅c
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                            3                                                                                    ⎛
#                   ⎛       2               ⎞                                    2                                                ⎜       4  2    2
#  2⋅t⋅w) - 1) - 12⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin (k⋅r - t⋅w) - 12⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎜- 8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅c
#                                                                                                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                               3
#      ⎛       2               ⎞  ⎛ 2  2                                                  2           ⎞                                 3 ⎛
# w) + ⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) - k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅⎜-k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅
#                                                                                                                                         ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                            ⎛                                                                                                                          3
#                            ⎜     4  2    2               2               4  2 ⎛       2               ⎞                      ⎛       2               ⎞  ⎛ 2  2
# os(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎜8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) - ⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r
#                            ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                 ⎤
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                      ⎞⎞        ⎤⎥
#                 3                                                    ⎟⎟    2   ⎥⎥
#  2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎟⋅sin (θ)⎥⎥
#                                                                       ⎠        ⎥⎥
# ───────────────────────────────────────────────────────────────────────────────⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎥⎥
#                                                                                ⎦⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎥
#                                                                                 ⎦

# %%
weyl[0,1,0,1]
# Out:
#   ⎛                                 3                                                                                4
#   ⎜        ⎛       2               ⎞                                                        ⎛       2               ⎞
# M⋅⎜- 4⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r -
#   ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                 ⎛
#                                                 ⎜       4  2    2               2               4  2 ⎛       2               ⎞                      ⎛       2
#  2⋅t⋅w) - 1) + 6⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎜- 8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) + r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + ⎝2⋅M⋅sin (
#                                                 ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                3
#               ⎞  ⎛ 2  2                                                  2           ⎞                                 3 ⎛                          cos(2⋅k⋅r
# k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) - k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅⎜-k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - ──────────
#                                                                                                                          ⎝                                  2
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#              ⎞                                  ⎛                                                                          2
# - 2⋅t⋅w)   1⎞⎟                                  ⎜      4  2    2               2                  ⎛       2               ⎞
# ──────── + ─⎟⎟ - (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r -
#            2⎠⎠
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                               2
#       2    2                 4  2 ⎛       2               ⎞                          ⎛       2               ⎞
#  t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                  3
#                                                                                                                       3 ⎛       2               ⎞
#                                                                                                                    6⋅r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅
#
#                                                                      3
#                                             ⎛       2               ⎞  ⎛   2  2                                                  2           ⎞
# - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# r - 2⋅t⋅w) - M + r)
#
#                                                                       ⎞                                    ⎛
#                  3                                                    ⎟                                    ⎜      4  2    2               2                  ⎛
# - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠ + 2⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝56⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (k⋅r - t⋅w) - 6⋅M⋅⎝
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                         2
#        2               ⎞                                         2    2                 4  2 ⎛       2               ⎞                          ⎛       2
# 2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 7⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 3⋅r⋅⎝2⋅M⋅sin (k⋅r
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#            2                                                                                                                    3
#           ⎞                                                                                            ⎛       2               ⎞  ⎛   2  2
# - t⋅w) - r⎠ ⋅(2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 7⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w)
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                                                    ⎞⎞
#                               2           ⎞                                   3                                                    ⎟⎟
# + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + 2⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎟
#                                                                                                                                     ⎠
# ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
weyl[0,2,0,2]
# Out:
#   ⎛                               3                                                                                4
#   ⎜      ⎛       2               ⎞                                                        ⎛       2               ⎞
# M⋅⎜8⋅k⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin(2⋅k⋅r - 2⋅t⋅w) - 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2
#   ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                          3                                                                                    ⎛
#                 ⎛       2               ⎞                                    2                                                ⎜     4  2    2               2
# ⋅t⋅w) - 1) - 12⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅sin (k⋅r - t⋅w) + 12⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎜8⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos (
#                                                                                                                               ⎝
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                            3
#               4  2 ⎛       2               ⎞                      ⎛       2               ⎞  ⎛ 2  2                                                  2
# k⋅r - t⋅w) - r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) - ⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) - k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + sin (k⋅r - t
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                          ⎞                                    ⎛
#    ⎞                                 3 ⎛                          cos(2⋅k⋅r - 2⋅t⋅w)   1⎞⎟                                    ⎜      4  2    2               2
# ⋅w)⎠ - (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅⎜-k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - ────────────────── + ─⎟⎟ - 2⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝16⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w)⋅cos
#                                        ⎝                                  2            2⎠⎠
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                 3
#                  4  2 ⎛       2               ⎞                        ⎛       2               ⎞  ⎛   2  2                                                  2
# (k⋅r - t⋅w) - 2⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅t⋅w) + 2⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝- k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                              2
#                                                   2 ⎛       2               ⎞
#                                               12⋅r ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)
#
#                                                                                                  ⎞                                  ⎛
#           ⎞                                 3                                                    ⎟                                  ⎜      4  2    2
# k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠ - (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r)⋅⎝32⋅M⋅r ⋅w ⋅sin (k⋅r - t⋅w
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                  2
#      2                  ⎛       2               ⎞                                         2    2                 4  2 ⎛       2               ⎞
# )⋅cos (k⋅r - t⋅w) - 4⋅M⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w)) ⋅sin (k⋅r - t⋅w) - 4⋅r ⋅w ⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠⋅cos(2⋅k⋅r - 2⋅
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                     2                                                                                                                    3
#            ⎛       2               ⎞                                                                                            ⎛       2               ⎞  ⎛
# t⋅w) + 2⋅r⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅(2⋅M⋅k⋅sin(2⋅k⋅r - 2⋅t⋅w) - 1)⋅(2⋅k⋅r⋅cos(k⋅r - t⋅w) - sin(k⋅r - t⋅w))⋅sin(k⋅r - t⋅w) + 4⋅⎝2⋅M⋅sin (k⋅r - t⋅w) - r⎠ ⋅⎝-
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                                                                                                                           ⎞⎞
#  2  2                                                  2           ⎞                                 3                                                    ⎟⎟
# k ⋅r ⋅cos(2⋅k⋅r - 2⋅t⋅w) + k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) - sin (k⋅r - t⋅w)⎠ + (M⋅cos(2⋅k⋅r - 2⋅t⋅w) - M + r) ⋅(2⋅k⋅r⋅sin(2⋅k⋅r - 2⋅t⋅w) + cos(2⋅k⋅r - 2⋅t⋅w) - 1)⎠⎟
#                                                                                                                                                            ⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

#Make x values - which we will sub in for r 
x = np.arange(1.9, 20.0, 0.04)
func(0.5,x,0, 0, 1, 1, 1)[0][1][0][1]

# Call the functions
y = func(1.0,x,1, 1, 1, 1, 1)[0][1][0][1]
z = -func(1.0,x,1, 1, 1, 1, 1)[0][2][0][2] # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("T_01")
# Out:
# (t, r, theta, phi, M, k, w)
# Text(0.5, 1.0, 'T_01')
