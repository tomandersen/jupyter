# %% [markdown]
# # Einstein Tensor calculations using Symbolic module
# # EXAMPLE - don't modify too much. Not a meaningful metric to me, etc

# %%
import sympy
from sympy import symbols, sin, cos, sinh
from einsteinpy.symbolic import EinsteinTensor, MetricTensor

sympy.init_printing()

# %% [markdown]
# ### Defining the Anti-de Sitter spacetime Metric

# %%
syms = sympy.symbols("t chi theta phi")
t, ch, th, ph = syms
m = sympy.diag(-1, cos(t) ** 3, cos(t) ** 2 * sinh(ch) ** 2, cos(t) ** 2 * sinh(ch) ** 2 * sin(th) ** 2).tolist()
metric = MetricTensor(m, syms)

# %% [markdown]
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(metric)
einst.tensor()
# Out:
# ⎡                                               3
# ⎢                                          7⋅cos (t)   5⋅cos(t)    cos(t)           1
# ⎢                                          ───────── - ──────── - ──────── + 2 + ────────
# ⎢                                              2          2           2              2
# ⎢  0.03125⋅(3⋅cos(t) + 21⋅cos(3⋅t) + 32)                          sinh (χ)       sinh (χ)            2
# ⎢- ───────────────────────────────────── - ────────────────────────────────────────────── - 0.375⋅tan (t) + 1.75
# ⎢                    3                                           3
# ⎢                 cos (t)                                     cos (t)
# ⎢
# ⎢                                                                                                                       ⎛                                  ⎛
# ⎢                                                                                                                       ⎜                                  ⎜7⋅
# ⎢                                                                                                                       ⎜                                2⋅⎜──
# ⎢                                                                                                                       ⎜                                  ⎜
# ⎢                                                   -tan(t)                                                             ⎜  3⋅cos(t) + 21⋅cos(3⋅t) + 32     ⎝
# ⎢                                                   ────────                                                      - 0.5⋅⎜- ─────────────────────────── - ─────
# ⎢                                                   tanh(χ)                                                             ⎜                 3
# ⎢                                                                                                                       ⎝           16⋅cos (t)
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                       0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                       0
# ⎢
# ⎣
#
#
#
#
#
#                                 -tan(t)
#                                 ────────
#                                 tanh(χ)
#
#
#    3                                        ⎞                ⎞
# cos (t)   5⋅cos(t)    cos(t)           1    ⎟                ⎟
# ─────── - ──────── - ──────── + 2 + ────────⎟                ⎟
#   2          2           2              2   ⎟        2       ⎟                                   3
#                      sinh (χ)       sinh (χ)⎠   3⋅tan (t)   7⎟    3           2             9⋅cos (t)   3⋅cos(t)
# ───────────────────────────────────────────── + ───────── - ─⎟⋅cos (t) + 3⋅sin (t)⋅cos(t) - ───────── + ──────── - 2
#                    3                                4       2⎟                                  4          4
#                 cos (t)                                      ⎠
#
#                                                                                                                                                           ⎛
#                                                                                                                                                           ⎜
#                                                                                                                                                           ⎜
#                                                                                                                       ⎛     2            ⎞                ⎜
#                                                                                                                       ⎜3⋅sin (t)     1   ⎟     2          ⎜  3
#                                    0                                                                                  ⎜───────── - ──────⎟⋅sinh (χ) - 0.5⋅⎜- ─
#                                                                                                                       ⎝    2       cos(t)⎠                ⎜
#                                                                                                                                                           ⎝
#
#
#
#
#
#
#                                    0
#
#
#
#
#
#
#
#
#                                                               0
#
#
#
#
#
#
#
#
#                                                               0
#
#
#
#                                ⎛     3                                        ⎞                ⎞
#                                ⎜7⋅cos (t)   5⋅cos(t)    cos(t)           1    ⎟                ⎟
#                              2⋅⎜───────── - ──────── - ──────── + 2 + ────────⎟                ⎟
#                                ⎜    2          2           2              2   ⎟        2       ⎟
# ⋅cos(t) + 21⋅cos(3⋅t) + 32     ⎝                       sinh (χ)       sinh (χ)⎠   3⋅tan (t)   7⎟    2        2         2        2         2        2
# ────────────────────────── - ────────────────────────────────────────────────── + ───────── - ─⎟⋅cos (t)⋅sinh (χ) + sin (t)⋅sinh (χ) - cos (t)⋅sinh (χ) + 1 -
#               3                                      3                                4       2⎟
#         16⋅cos (t)                                cos (t)                                      ⎠
#
#
#
#
#
#
#                                                               0
#
#
#
#
#
#
#
#
#                                                                                                                                  0
#
#
#
#
#
#
#
#
#                                                                                                                                  0
#
#
#
#
#
#
#     2
# cosh (χ)
# ────────                                                                                                                         0
#  cos(t)
#
#
#                                                                                                   ⎛                                  ⎛     3
#                                                                                                   ⎜                                  ⎜7⋅cos (t)   5⋅cos(t)
#           ⎛     2        2   ⎞    2        2                                                      ⎜                                2⋅⎜───────── - ──────── - ─
#           ⎜3⋅sin (t) - ──────⎟⋅sin (θ)⋅sinh (χ)   ⎛                           2   ⎞               ⎜                                  ⎜    2          2
#           ⎝            cos(t)⎠                    ⎜   2        2          cosh (χ)⎟    2          ⎜  3⋅cos(t) + 21⋅cos(3⋅t) + 32     ⎝                       s
#           ───────────────────────────────────── + ⎜sin (t)⋅sinh (χ) + 1 - ────────⎟⋅sin (θ) - 0.5⋅⎜- ─────────────────────────── - ───────────────────────────
#                             2                     ⎝                        cos(t) ⎠               ⎜                 3                                      3
#                                                                                                   ⎝           16⋅cos (t)                                cos (t
#
#                                                                                             ⎤
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                                                                                             ⎥
#                       ⎞                ⎞                                                    ⎥
# cos(t)           1    ⎟                ⎟                                                    ⎥
# ─────── + 2 + ────────⎟                ⎟                                                    ⎥
#    2              2   ⎟        2       ⎟                                                    ⎥
# inh (χ)       sinh (χ)⎠   3⋅tan (t)   7⎟    2       2        2         2       2        2   ⎥
# ─────────────────────── + ───────── - ─⎟⋅sin (θ)⋅cos (t)⋅sinh (χ) - sin (θ)⋅cos (t)⋅sinh (χ)⎥
#                               4       2⎟                                                    ⎥
# )                                      ⎠                                                    ⎦
