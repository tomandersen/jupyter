# %% [markdown]
# # Schwarshild coordinates Einstein Tensor calculations using Symbolic module
# ## The nonlocal breather

# %%
import sympy
import matplotlib.pyplot as plt
import numpy as np

from sympy import symbols, sin, cos, sinh
from einsteinpy.symbolic import EinsteinTensor, MetricTensor, WeylTensor, RicciTensor, RicciScalar

sympy.init_printing()

# %% [markdown]
# ### Idea is to follow the Nov 1 2021 work where i used energy density to get a guess at a vacuum breather.
#
# ### Make time tick regular, waves get longer - example cos w (t - r/y*r/c) or similar, y is the length

# %% [markdown]
# ![alt-text](img/schwarschild.png "Schwarschild coords")

# %%
syms = sympy.symbols("t r theta phi")
G, M, c, a, w = sympy.symbols("G M c a w")
# time vary the mass
a = 2*M*(sin(w*syms[0])**2)

#a = 2*M
# using metric values of schwarschild space-time
# a is schwarzschild radius
list2d = [[0 for i in range(4)] for i in range(4)]
list2d[0][0] = -(1 - a/syms[1])
list2d[0][1] = 0
list2d[1][0] = 0
list2d[1][1] = 1/(1 - a/syms[1]) 
list2d[2][2] = (syms[1])**2
list2d[3][3] = (syms[1])**2*(sympy.sin(syms[2]) ** 2)
sch = MetricTensor(list2d, syms)
sch.tensor()
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_png function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_rgba function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The to_mask function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/IPython/lib/latextools.py:126: MatplotlibDeprecationWarning:
# The MathtextBackendBitmap class was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use mathtext.math_to_image instead.
#   mt.to_png(f, s, fontsize=12, dpi=dpi, color=color)
# ⎡       2                                              ⎤
# ⎢2⋅M⋅sin (t⋅w)                                         ⎥
# ⎢───────────── - 1           0           0       0     ⎥
# ⎢      r                                               ⎥
# ⎢                                                      ⎥
# ⎢                            1                         ⎥
# ⎢        0          ───────────────────  0       0     ⎥
# ⎢                            2                         ⎥
# ⎢                     2⋅M⋅sin (t⋅w)                    ⎥
# ⎢                   - ───────────── + 1                ⎥
# ⎢                           r                          ⎥
# ⎢                                                      ⎥
# ⎢                                         2            ⎥
# ⎢        0                   0           r       0     ⎥
# ⎢                                                      ⎥
# ⎢                                             2    2   ⎥
# ⎣        0                   0           0   r ⋅sin (θ)⎦

# %% [markdown]
# ### Calculating the Einstein Tensor (with both indices covariant)

# %%
einst = EinsteinTensor.from_metric(sch)
einst.simplify()
einst.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡                             2⋅M⋅w⋅sin(2⋅t⋅w)
# ⎢           0             ───────────────────────                                  0
# ⎢                           ⎛         2         ⎞
# ⎢                         r⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
# ⎢
# ⎢    2⋅M⋅w⋅sin(2⋅t⋅w)
# ⎢───────────────────────             0                                             0
# ⎢  ⎛         2         ⎞
# ⎢r⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
# ⎢
# ⎢                                                         3  2 ⎛         4               2               2         ⎞
# ⎢                                                  2.0⋅M⋅r ⋅w ⋅⎝- 4⋅M⋅sin (t⋅w) + 6⋅M⋅sin (t⋅w) - 2⋅r⋅sin (t⋅w) + r⎠
# ⎢           0                        0             ─────────────────────────────────────────────────────────────────
# ⎢                                                                                            3
# ⎢                                                                         ⎛       2         ⎞
# ⎢                                                                         ⎝2⋅M⋅sin (t⋅w) - r⎠
# ⎢
# ⎢                                                                                                                            3  2 ⎛
# ⎢                                                                                                                     2.0⋅M⋅r ⋅w ⋅⎝- 4
# ⎢           0                        0                                             0                                  ────────────────
# ⎢
# ⎢
# ⎣
#
#                                                          ⎤
#                     0                                    ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                     0                                    ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                     0                                    ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#                                                          ⎥
#       4               2               2         ⎞    2   ⎥
# ⋅M⋅sin (t⋅w) + 6⋅M⋅sin (t⋅w) - 2⋅r⋅sin (t⋅w) + r⎠⋅sin (θ)⎥
# ─────────────────────────────────────────────────────────⎥
#                               3                          ⎥
#            ⎛       2         ⎞                           ⎥
#            ⎝2⋅M⋅sin (t⋅w) - r⎠                           ⎦

# %%
ri = RicciTensor.from_metric(sch)
ri.simplify()
ri.tensor()
#components explanation EG https://physics.stackexchange.com/questions/366560/stress-energy-tensor-components-spherical-coordinates
# Out:
# ⎡     2 ⎛                      ⎛       2         ⎞           ⎞                                                                       ⎤
# ⎢2⋅M⋅w ⋅⎝-M⋅(1 - cos(4⋅t⋅w)) + ⎝2⋅M⋅sin (t⋅w) - r⎠⋅cos(2⋅t⋅w)⎠                          2⋅M⋅w⋅sin(2⋅t⋅w)                             ⎥
# ⎢─────────────────────────────────────────────────────────────                      ───────────────────────                      0  0⎥
# ⎢                                         2                                           ⎛         2         ⎞                          ⎥
# ⎢                    ⎛         2         ⎞                                          r⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                          ⎥
# ⎢                    ⎝- 2⋅M⋅sin (t⋅w) + r⎠                                                                                           ⎥
# ⎢                                                                                                                                    ⎥
# ⎢                                                                    2  2 ⎛         4               2               2         ⎞      ⎥
# ⎢                       2⋅M⋅w⋅sin(2⋅t⋅w)                        2⋅M⋅r ⋅w ⋅⎝- 4⋅M⋅sin (t⋅w) + 6⋅M⋅sin (t⋅w) - 2⋅r⋅sin (t⋅w) + r⎠      ⎥
# ⎢                   ───────────────────────                     ───────────────────────────────────────────────────────────────  0  0⎥
# ⎢                     ⎛         2         ⎞                                                               4                          ⎥
# ⎢                   r⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                                          ⎛         2         ⎞                           ⎥
# ⎢                                                                                    ⎝- 2⋅M⋅sin (t⋅w) + r⎠                           ⎥
# ⎢                                                                                                                                    ⎥
# ⎢                              0                                                               0                                 0  0⎥
# ⎢                                                                                                                                    ⎥
# ⎣                              0                                                               0                                 0  0⎦

# %% [markdown]
# #NOT Zero

# %%
# Ricci scalar
R = RicciScalar.from_riccitensor(ri)
R.simplify()
R.expr
# Out:
#        2 ⎛         4               2               2         ⎞
# 4⋅M⋅r⋅w ⋅⎝- 4⋅M⋅sin (t⋅w) + 6⋅M⋅sin (t⋅w) - 2⋅r⋅sin (t⋅w) + r⎠
# ──────────────────────────────────────────────────────────────
#                                          3
#                     ⎛         2         ⎞
#                     ⎝- 2⋅M⋅sin (t⋅w) + r⎠

# %%
# what is the Weyl tensor?
weyl = WeylTensor.from_metric(sch)
weyl.tensor() # all components!
# Out:
# ⎡
# ⎢
# ⎢                      ⎡0                                                                           0
# ⎢                      ⎢
# ⎢                      ⎢       ⎛     3    8            2      6             4  2    4             4  2    2             2    4           5  2    2         5
# ⎢                      ⎢   2⋅M⋅⎝- 8⋅M ⋅sin (t⋅w) + 12⋅M ⋅r⋅sin (t⋅w) - 4⋅M⋅r ⋅w ⋅sin (t⋅w) + 6⋅M⋅r ⋅w ⋅sin (t⋅w) - 6⋅M⋅r ⋅sin (t⋅w) - 2⋅r ⋅w ⋅sin (t⋅w) + r ⋅w
# ⎢                      ⎢0  ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢                      ⎢                                                                                        3
# ⎢                      ⎢                                                                 3 ⎛         2         ⎞
# ⎢                      ⎢                                                                r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢0                                                                           0
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢
# ⎢                      ⎢0                                                                           0
# ⎢                      ⎢
# ⎢                      ⎣
# ⎢
# ⎢
# ⎢
# ⎢⎡
# ⎢⎢                                                                                                                                                         M⋅r
# ⎢⎢                                                                           0                                                                             ───
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢  ⎛    3    8            2      6             4  2    4              4  2    2              2    4           5  2    2           5  2      3    2     ⎞
# ⎢⎢M⋅⎝48⋅M ⋅sin (t⋅w) - 72⋅M ⋅r⋅sin (t⋅w) + 8⋅M⋅r ⋅w ⋅sin (t⋅w) - 12⋅M⋅r ⋅w ⋅sin (t⋅w) + 36⋅M⋅r ⋅sin (t⋅w) + 4⋅r ⋅w ⋅sin (t⋅w) - 2⋅r ⋅w  - 6⋅r ⋅sin (t⋅w)⎠
# ⎢⎢───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢⎢                                                                                        3
# ⎢⎢                                                                 3 ⎛         2         ⎞
# ⎢⎢                                                              3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                                           0
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢
# ⎢⎢                                                                           0
# ⎢⎢
# ⎢⎣
# ⎢
# ⎢                          ⎡
# ⎢                          ⎢
# ⎢                          ⎢                                                                          0
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢                                                                          0
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢
# ⎢                          ⎢  ⎛      3    8            2      6             4  2    4             4  2    2              2    4           5  2    2         5
# ⎢                          ⎢M⋅⎝- 24⋅M ⋅sin (t⋅w) + 36⋅M ⋅r⋅sin (t⋅w) - 4⋅M⋅r ⋅w ⋅sin (t⋅w) + 6⋅M⋅r ⋅w ⋅sin (t⋅w) - 18⋅M⋅r ⋅sin (t⋅w) - 2⋅r ⋅w ⋅sin (t⋅w) + r ⋅
# ⎢                          ⎢──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢                          ⎢                                                                                       2
# ⎢                          ⎢                                                                2 ⎛         2         ⎞
# ⎢                          ⎢                                                             3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
# ⎢                          ⎢
# ⎢                          ⎣                                                                          0
# ⎢
# ⎢                  ⎡
# ⎢                  ⎢
# ⎢                  ⎢                                                                              0
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢                                                                              0
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢
# ⎢                  ⎢                                                                              0
# ⎢                  ⎢
# ⎢                  ⎢  ⎛      3    8            2      6             4  2    4             4  2    2              2    4           5  2    2         5  2
# ⎢                  ⎢M⋅⎝- 24⋅M ⋅sin (t⋅w) + 36⋅M ⋅r⋅sin (t⋅w) - 4⋅M⋅r ⋅w ⋅sin (t⋅w) + 6⋅M⋅r ⋅w ⋅sin (t⋅w) - 18⋅M⋅r ⋅sin (t⋅w) - 2⋅r ⋅w ⋅sin (t⋅w) + r ⋅w  + 3⋅r
# ⎢                  ⎢──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ⎢                  ⎢                                                                                           2
# ⎢                  ⎢                                                                    2 ⎛         2         ⎞
# ⎣                  ⎣                                                                 3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
#
#                                                                                                                     ⎡
#                                                                                                                     ⎢
#                                   0                                    0                   ⎤                        ⎢                              0
#                                                                                            ⎥                        ⎢
# 2    3    2     ⎞                                                                          ⎥                        ⎢
#   + r ⋅sin (t⋅w)⎠                                                                          ⎥                        ⎢
# ─────────────────                 0                                    0                   ⎥                        ⎢
#                                                                                            ⎥                        ⎢     2 ⎛        4                2
#                                                                                            ⎥                        ⎢M⋅r⋅w ⋅⎝16⋅M⋅sin (t⋅w) - 24⋅M⋅sin (t⋅w) +
#                                                                                            ⎥                        ⎢─────────────────────────────────────────
#                                                                                            ⎥                        ⎢
#                      ⎛       4             2     ⎞                                         ⎥                        ⎢                     ⎛         2
#                    M⋅⎝2⋅M⋅sin (t⋅w) - r⋅sin (t⋅w)⎠                                         ⎥                        ⎢                   3⋅⎝- 2⋅M⋅sin (t⋅w) + r
#                    ───────────────────────────────                     0                   ⎥                        ⎢
#                                    2                                                       ⎥                        ⎢
#                                   r                                                        ⎥                        ⎢                              0
#                                                                                            ⎥                        ⎢
#                                                       ⎛       2         ⎞    2       2     ⎥                        ⎢
#                                                     M⋅⎝2⋅M⋅sin (t⋅w) - r⎠⋅sin (θ)⋅sin (t⋅w)⎥                        ⎢
#                                   0                 ───────────────────────────────────────⎥                        ⎢
#                                                                         2                  ⎥                        ⎢
#                                                                        r                   ⎦                        ⎢                              0
#                                                                                                                     ⎢
#                                                                                                                     ⎣
#
#   2 ⎛        4                2               2           ⎞                                                      ⎤
# ⋅w ⋅⎝16⋅M⋅sin (t⋅w) - 24⋅M⋅sin (t⋅w) + 8⋅r⋅sin (t⋅w) - 4⋅r⎠                                                      ⎥
# ───────────────────────────────────────────────────────────          0                          0                ⎥
#                                        3                                                                         ⎥
#                   ⎛         2         ⎞                                                                          ⎥
#                 3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                                                                          ⎥
#                                                                                                                  ⎥
#                                                                                                                  ⎥
#                                                                                                                  ⎥
#                            0                                         0                          0                ⎥
#                                                                                                                  ⎥
#                                                                                                                  ⎥
#                                                                                                                  ⎥
#                                                                                                                  ⎥
#                                                               M⋅r⋅w⋅sin(2⋅t⋅w)                                   ⎥
#                            0                                 ─────────────────                  0                ⎥
#                                                                     2                                            ⎥
#                                                              2⋅M⋅sin (t⋅w) - r                                   ⎥
#                                                                                                                  ⎥
#                                                                                            2                     ⎥
#                                                                                 2⋅M⋅r⋅w⋅sin (θ)⋅sin(t⋅w)⋅cos(t⋅w)⎥
#                            0                                         0          ─────────────────────────────────⎥
#                                                                                                2                 ⎥
#                                                                                         2⋅M⋅sin (t⋅w) - r        ⎦
#
#                             2  2 ⎛       4               2               2         ⎞   ⎤                                                      ⎡
#                          M⋅r ⋅w ⋅⎝4⋅M⋅sin (t⋅w) - 6⋅M⋅sin (t⋅w) + 2⋅r⋅sin (t⋅w) - r⎠   ⎥                                                      ⎢0
#                       0  ───────────────────────────────────────────────────────────  0⎥                                                      ⎢
#                                                                   2                    ⎥                                                      ⎢
#                                              ⎛         2         ⎞                     ⎥                                                      ⎢
#                                            3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                     ⎥                                                      ⎢
#                                                                                        ⎥                                                      ⎢
#                                                M⋅r⋅w⋅sin(2⋅t⋅w)                        ⎥                                                      ⎢0
#                       0                      ───────────────────                      0⎥                                                      ⎢
#                                                       2                                ⎥                                                      ⎢
#                                              - 2⋅M⋅sin (t⋅w) + r                       ⎥                                                      ⎢
#                                                                                        ⎥                                                      ⎢
#  2      3    2     ⎞                                                                   ⎥                                                      ⎢     ⎛    3
# w  + 3⋅r ⋅sin (t⋅w)⎠                                                                   ⎥                                                      ⎢   M⋅⎝24⋅M ⋅sin
# ────────────────────  0                               0                               0⎥                                                      ⎢0  ────────────
#                                                                                        ⎥                                                      ⎢
#                                                                                        ⎥                                                      ⎢
#                                                                                        ⎥                                                      ⎢
#                                                                                        ⎥                                                      ⎢
#                       0                               0                               0⎦                                                      ⎣0
#
#                                2  2 ⎛       4               2               2         ⎞    2   ⎤                                      ⎡
#                             M⋅r ⋅w ⋅⎝4⋅M⋅sin (t⋅w) - 6⋅M⋅sin (t⋅w) + 2⋅r⋅sin (t⋅w) - r⎠⋅sin (θ)⎥                                      ⎢
#                       0  0  ───────────────────────────────────────────────────────────────────⎥                                      ⎢0
#                                                                          2                     ⎥                                      ⎢
#                                                     ⎛         2         ⎞                      ⎥                                      ⎢
#                                                   3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                      ⎥                                      ⎢
#                                                                                                ⎥                                      ⎢
#                                                           2                                    ⎥                                      ⎢
#                                                  M⋅r⋅w⋅sin (θ)⋅sin(2⋅t⋅w)                      ⎥                                      ⎢0
#                       0  0                       ────────────────────────                      ⎥                                      ⎢
#                                                             2                                  ⎥                                      ⎢
#                                                    - 2⋅M⋅sin (t⋅w) + r                         ⎥                                      ⎢
#                                                                                                ⎥                                      ⎢
#                       0  0                                   0                                 ⎥                                      ⎢0
#                                                                                                ⎥                                      ⎢
# 3    2     ⎞    2                                                                              ⎥                                      ⎢     ⎛    3    8
#  ⋅sin (t⋅w)⎠⋅sin (θ)                                                                           ⎥                                      ⎢   M⋅⎝24⋅M ⋅sin (t⋅w) -
# ────────────────────  0  0                                   0                                 ⎥                                      ⎢0  ────────────────────
#                                                                                                ⎥                                      ⎢
#                                                                                                ⎥                                      ⎢
#                                                                                                ⎦                                      ⎣
#
#                          ⎛    3    8            2      6             4  2    4              4  2    2              2    4           5  2    2           5  2
#                        M⋅⎝48⋅M ⋅sin (t⋅w) - 72⋅M ⋅r⋅sin (t⋅w) + 8⋅M⋅r ⋅w ⋅sin (t⋅w) - 12⋅M⋅r ⋅w ⋅sin (t⋅w) + 36⋅M⋅r ⋅sin (t⋅w) + 4⋅r ⋅w ⋅sin (t⋅w) - 2⋅r ⋅w  -
#                        ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                3
#                                                                                         3 ⎛         2         ⎞
#                                                                                      3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
#
#         2           ⎞
#  8⋅r⋅sin (t⋅w) - 4⋅r⎠
# ─────────────────────                                                                             0
#  3
# ⎞
# ⎠
#
#
#                                                                                                   0
#
#
#
#
#
#                                                                                                   0
#
#
#
#
#
#                    ⎡    ⎛                                                                                     3          ⎞
#                    ⎢    ⎜   4  2                     4  2 ⎛       2         ⎞              ⎛       2         ⎞     2     ⎟
#                    ⎢2⋅M⋅⎝M⋅r ⋅w ⋅(cos(4⋅t⋅w) - 1) + r ⋅w ⋅⎝2⋅M⋅sin (t⋅w) - r⎠⋅cos(2⋅t⋅w) + ⎝2⋅M⋅sin (t⋅w) - r⎠ ⋅sin (t⋅w)⎠
#                    ⎢──────────────────────────────────────────────────────────────────────────────────────────────────────  0           0                    0
#                    ⎢                                                             3
#                    ⎢                                        3 ⎛       2         ⎞
#                    ⎢                                       r ⋅⎝2⋅M⋅sin (t⋅w) - r⎠
#                    ⎢
#                    ⎢                                                  0                                                     0           0                    0
#                    ⎢
#                    ⎢                                                                                                                    2
#                    ⎢                                                                                                               M⋅sin (t⋅w)
#                    ⎢                                                  0                                                     0  ───────────────────           0
#                    ⎢                                                                                                                    2
#                    ⎢                                                                                                           - 2⋅M⋅sin (t⋅w) + r
#                    ⎢
#                    ⎢                                                                                                                                     2
#                    ⎢                                                                                                                                M⋅sin (θ)⋅
#                    ⎢                                                  0                                                     0           0           ──────────
#                    ⎢                                                                                                                                         2
#                    ⎣                                                                                                                                - 2⋅M⋅sin
#
#
#
#                                                              0
#
#
#
#                                                                                                                                              4  2 ⎛         4
#                                                                                                                                           M⋅r ⋅w ⋅⎝- 4⋅M⋅sin (
#                                                              0                                                                            ────────────────────
#
#
#                                                                                                                                                              3
#
# 8            2      6             4  2    4             4  2    2              2    4           5  2    2         5  2      3    2     ⎞
#  (t⋅w) - 36⋅M ⋅r⋅sin (t⋅w) + 4⋅M⋅r ⋅w ⋅sin (t⋅w) - 6⋅M⋅r ⋅w ⋅sin (t⋅w) + 18⋅M⋅r ⋅sin (t⋅w) + 2⋅r ⋅w ⋅sin (t⋅w) - r ⋅w  - 3⋅r ⋅sin (t⋅w)⎠
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                          4
#                                                     ⎛         2         ⎞
#                                                   3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
#
#                                                              0
#
#
#
#                                                          0                                                                                0
#
#
#
#                                                                                                                                                 4  2 ⎛
#                                                                                                                                              M⋅r ⋅w ⋅⎝- 4⋅M⋅si
#                                                          0                                                                                0  ─────────────────
#
#
#
#
#                                                          0                                                                                0
#
#      2      6             4  2    4             4  2    2              2    4           5  2    2         5  2      3    2     ⎞    2
#  36⋅M ⋅r⋅sin (t⋅w) + 4⋅M⋅r ⋅w ⋅sin (t⋅w) - 6⋅M⋅r ⋅w ⋅sin (t⋅w) + 18⋅M⋅r ⋅sin (t⋅w) + 2⋅r ⋅w ⋅sin (t⋅w) - r ⋅w  - 3⋅r ⋅sin (t⋅w)⎠⋅sin (θ)
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  0
#                                                                      4
#                                                 ⎛         2         ⎞
#                                               3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
#
#     3    2     ⎞                                                      ⎤
#  6⋅r ⋅sin (t⋅w)⎠                                                      ⎥
# ────────────────          0                          0                ⎥
#                                                                       ⎥
#                                                                       ⎥  ⎡
#                                                                       ⎥  ⎢                                                                                  M⋅
#                                                                       ⎥  ⎢                             0                                        0           ──
#                                                                       ⎥  ⎢
#                                                                       ⎥  ⎢
#                           0                          0                ⎥  ⎢
#                                                                       ⎥  ⎢
#                                                                       ⎥  ⎢                             0                                        0
#                                                                       ⎥  ⎢
#                                                                       ⎥  ⎢   2  2 ⎛       4               2               2         ⎞
#                    M⋅r⋅w⋅sin(2⋅t⋅w)                                   ⎥  ⎢M⋅r ⋅w ⋅⎝4⋅M⋅sin (t⋅w) - 6⋅M⋅sin (t⋅w) + 2⋅r⋅sin (t⋅w) - r⎠    M⋅r⋅w⋅sin(2⋅t⋅w)
#                   ─────────────────                  0                ⎥  ⎢───────────────────────────────────────────────────────────  ───────────────────
#                          2                                            ⎥  ⎢                                         2                            2
#                   2⋅M⋅sin (t⋅w) - r                                   ⎥  ⎢                    ⎛         2         ⎞                    - 2⋅M⋅sin (t⋅w) + r
#                                                                       ⎥  ⎢                  3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠
#                                                 2                     ⎥  ⎢
#                                      2⋅M⋅r⋅w⋅sin (θ)⋅sin(t⋅w)⋅cos(t⋅w)⎥  ⎣                             0                                        0
#                           0          ─────────────────────────────────⎥
#                                                     2                 ⎥
#                                              2⋅M⋅sin (t⋅w) - r        ⎦
#
# ...
#
#
#                               ⎡0  0                                     0
#                               ⎢
#                               ⎢0  0                                     0
#                               ⎢
#                               ⎢                                                                                   ⎛
#                               ⎢                                                                                   ⎜ 4  2 ⎛       4                2
#                               ⎢                                                                               M⋅r⋅⎝r ⋅w ⋅⎝8⋅M⋅sin (t⋅w) - 12⋅M⋅sin (t⋅w) + 4⋅r
#                               ⎢0  0                                     0                                     ────────────────────────────────────────────────
#                               ⎢
#                               ⎢                                                                                                                             ⎛
#                               ⎢                                                                                                                           3⋅⎝2
#                               ⎢
#                               ⎢           5  2 ⎛         4               2               2         ⎞    2
#                               ⎢      2⋅M⋅r ⋅w ⋅⎝- 4⋅M⋅sin (t⋅w) + 6⋅M⋅sin (t⋅w) - 2⋅r⋅sin (t⋅w) + r⎠⋅sin (θ)
#                               ⎢0  0  ───────────────────────────────────────────────────────────────────────
#                               ⎢                                                    3
#                               ⎢                                 ⎛       2         ⎞
#                               ⎣                               3⋅⎝2⋅M⋅sin (t⋅w) - r⎠
#
#
#
#
#                                                                              ⎡  ⎛       2         ⎞    2       2                2
#                                                                              ⎢M⋅⎝2⋅M⋅sin (t⋅w) - r⎠⋅sin (θ)⋅sin (t⋅w)  M⋅r⋅w⋅sin (θ)⋅sin(2⋅t⋅w)
#                                                                              ⎢───────────────────────────────────────  ────────────────────────             0
#                                                                              ⎢                    2                              2
#                                                                              ⎢                   r                        2⋅M⋅sin (t⋅w) - r
#                                                                              ⎢
#                                                                              ⎢                2                               2       2
#                                                                              ⎢       M⋅r⋅w⋅sin (θ)⋅sin(2⋅t⋅w)            M⋅sin (θ)⋅sin (t⋅w)
#                                                                              ⎢       ────────────────────────            ───────────────────                0
#                                                                              ⎢                 2                                  2
#                                                                              ⎢          2⋅M⋅sin (t⋅w) - r                - 2⋅M⋅sin (t⋅w) + r
#                                                                              ⎢
#                                                                              ⎢                                                                             2
#                                                                              ⎢                   0                                0              -2⋅M⋅r⋅sin (θ
#                                                                              ⎢
#                                                                              ⎣                   0                                0                         0
#
#
#
#
#                                                                                                 ⎤
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#        4  2    2              2    4           5  2    2         5  2      3    2     ⎞    2   ⎤⎥
# + 6⋅M⋅r ⋅w ⋅sin (t⋅w) - 18⋅M⋅r ⋅sin (t⋅w) - 2⋅r ⋅w ⋅sin (t⋅w) + r ⋅w  + 3⋅r ⋅sin (t⋅w)⎠⋅sin (θ)⎥⎥
# ───────────────────────────────────────────────────────────────────────────────────────────────⎥⎥
#                             2                                                                  ⎥⎥
#      2 ⎛         2         ⎞                                                                   ⎥⎥
#   3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                                                                   ⎥⎥
#                                                                                                ⎥⎥
#                0                                                                               ⎥⎥
#                                                                                                ⎥⎥
#                0                                                                               ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                0                                                                               ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎦⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                 0                                                                              ⎤⎥
#                                                                                                ⎥⎥
#        4  2    2              2    4           5  2    2         5  2      3    2     ⎞    2   ⎥⎥
# - 6⋅M⋅r ⋅w ⋅sin (t⋅w) + 18⋅M⋅r ⋅sin (t⋅w) + 2⋅r ⋅w ⋅sin (t⋅w) - r ⋅w  - 3⋅r ⋅sin (t⋅w)⎠⋅sin (θ)⎥⎥
# ───────────────────────────────────────────────────────────────────────────────────────────────⎥⎥
#                             4                                                                  ⎥⎥
#        ⎛         2         ⎞                                                                   ⎥⎥
#      3⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠                                                                   ⎥⎥
#                                                                                                ⎥⎥
#                 0                                                                              ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                 0                                                                              ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎥⎥
#                                                                                                ⎦⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#       0                                                      ⎤                                  ⎥
#                                                              ⎥                                  ⎥
#       0                                                      ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#                                          3          ⎞        ⎥                                  ⎥
#     2           ⎞     ⎛       2         ⎞     2     ⎟    2   ⎥                                  ⎥
# ⋅sin (t⋅w) - 2⋅r⎠ + 6⋅⎝2⋅M⋅sin (t⋅w) - r⎠ ⋅sin (t⋅w)⎠⋅sin (θ)⎥                                  ⎥
# ─────────────────────────────────────────────────────────────⎥                                  ⎥
#                  3                                           ⎥                                  ⎥
#       2         ⎞                                            ⎥                                  ⎥
# ⋅M⋅sin (t⋅w) - r⎠                                            ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#       0                                                      ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#                                                              ⎥                                  ⎥
#                                                              ⎦                                  ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#               ⎤                                                                                 ⎥
#               ⎥                                                                                 ⎥
#              0⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#              0⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#      2        ⎥                                                                                 ⎥
# )⋅sin (t⋅w)  0⎥                                                                                 ⎥
#               ⎥                                                                                 ⎥
#              0⎦                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎥
#                                                                                                 ⎦

# %%
weyl[0,1,0,1]
# Out:
#   ⎛    3    8            2      6             4  2    4              4  2    2              2    4           5  2    2           5  2      3    2     ⎞
# M⋅⎝48⋅M ⋅sin (t⋅w) - 72⋅M ⋅r⋅sin (t⋅w) + 8⋅M⋅r ⋅w ⋅sin (t⋅w) - 12⋅M⋅r ⋅w ⋅sin (t⋅w) + 36⋅M⋅r ⋅sin (t⋅w) + 4⋅r ⋅w ⋅sin (t⋅w) - 2⋅r ⋅w  - 6⋅r ⋅sin (t⋅w)⎠
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                         3
#                                                                  3 ⎛         2         ⎞
#                                                               3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠

# %%
weyl[0,2,0,2]
# Out:
#   ⎛      3    8            2      6             4  2    4             4  2    2              2    4           5  2    2         5  2      3    2     ⎞
# M⋅⎝- 24⋅M ⋅sin (t⋅w) + 36⋅M ⋅r⋅sin (t⋅w) - 4⋅M⋅r ⋅w ⋅sin (t⋅w) + 6⋅M⋅r ⋅w ⋅sin (t⋅w) - 18⋅M⋅r ⋅sin (t⋅w) - 2⋅r ⋅w ⋅sin (t⋅w) + r ⋅w  + 3⋅r ⋅sin (t⋅w)⎠
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                        2
#                                                                 2 ⎛         2         ⎞
#                                                              3⋅r ⋅⎝- 2⋅M⋅sin (t⋅w) + r⎠

# %%
###Plot something
# first make the tensor into a function, printing 
args, func = weyl.tensor_lambdify()
print(args) # these are the argument values 

#Make x values - which we will sub in for r 
x = np.arange(1.9, 20.0, 0.04)
func(0.5,x,0, 0, 1, 1)[0][1][0][1]

# Call the functions
y = func(1.0,x,1, 1, 1, 1)[0][1][0][1]
z = -func(1.0,x,1, 1, 1, 1)[0][2][0][2] # 0.1 to bring scale in
fig=plt.figure()
ax=fig.add_axes([0,2,1.0,1.0])
ax.plot(x,y)
ax.plot(x,z)
ax.set_title("T_01")
# Out:
# (t, r, theta, phi, M, w)
# Text(0.5, 1.0, 'T_01')
